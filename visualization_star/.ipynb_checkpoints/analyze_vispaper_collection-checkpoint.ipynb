# %%
import itertools

# %%
from pybtex.database import parse_file as pybtex_parse_file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
# %matplotlib inline

# %%
vispapers = pybtex_parse_file('groups-in-graphs.corinna-vehlow.com.bib')

# %%
G = nx.Graph()

# %%
from collections import Counter
all_keywords = {}
for name, entry in vispapers.entries.iteritems():
    keywords = entry.fields['keywords'].split(', ')
    for k in keywords:
        if ':' in k:
            k = k.split(':')
            if k[0] not in all_keywords:
                all_keywords[k[0]] = Counter()
            all_keywords[k[0]][k[1]] += 1
        else:
            if k not in all_keywords:
                all_keywords[k] = Counter()
            all_keywords[k]['_'] += 1
entry.fields['title']
entry.fields['keywords'].split(', ')
# Out:
# [u'paper_type:technique',
#  u'group_type:vertex-based',
#  u'graph_vis:node-link',
#  u'group_overlap:overlapping_crisp',
#  u'group_structure:flat',
#  u'graph:generic',
#  u'group_origin:categorical_attr',
#  u'application:social_network',
#  u'publication_channel:InfoVis_J',
#  u'edge-group_vis:none',
#  u'group_vis:juxtaposed',
#  u'visual_attr:!',
#  u'juxtaposed_vis:separate',
#  u'superimposed_vis:!',
#  u'embedded_vis:!',
#  u'implicit_vis:!',
#  u'evaluation:case_study',
#  u'radial']

# %%
for name, entry in vispapers.entries.iteritems():
    authors_this_paper = []
    this_paper = {'title': entry.fields['title'], 'year': entry.fields['year']}
    for author in entry.persons['author']:
        author_name = "{}, {}".format(author.get_part_as_text('last'), author.get_part_as_text('first'))
        author_name = author_name.replace('\\"', '')
        if G.has_node(author_name):
            G.node[author_name]['papers'].append(this_paper)
        else:
            G.add_node(author_name, attr_dict={'author_name': author_name, 'papers': [this_paper]})
        authors_this_paper.append(author_name)
    if len(authors_this_paper) > 1:
        for a1, a2 in itertools.combinations(authors_this_paper, 2):
            if G.has_edge(a1, a2):
                G[a1][a2]['weight'] += 1
            else:
                G.add_edge(a1, a2, weight=1)

# %%
components = list(nx.connected_components(G))

# %%
for a, b, data in sorted(G.edges(data=True), key=lambda x: x[2]['weight'], reverse=True):
    print('{a} | {b} | {w}'.format(a=a, b=b, w=data['weight']))
# Out:
# Weiskopf, Daniel | Vehlow, Corinna | 8
# Burch, Michael | Weiskopf, Daniel | 7
# Munzner, Tamara | Archambault, Daniel | 6
# Munzner, Tamara | Auber, David | 6
# Auber, David | Archambault, Daniel | 6
# Beck, Fabian | Diehl, Stephan | 6
# Burch, Michael | Diehl, Stephan | 5
# Didimo, Walter | Liotta, Giuseppe | 5
# Auber, David | Bourqui, Romain | 4
# Fekete, Jean-Daniel | Henry, Nathalie | 4
# Feng, Qing-Wen | Eades, Peter | 4
# Montecchiani, Fabrizio | Didimo, Walter | 4
# Hu, Yifan | Kobourov, Stephen | 4
# Byelas, Heorhiy | Telea, Alexandru | 4
# Marriott, Kim | Dwyer, Tim | 4
# Muelder, Chris | Ma, Kwan-Liu | 4
# Auber, David | Jourdan, Fabien | 3
# Nguyen, Quang | Huang, Mao | 3
# Beck, Fabian | Burch, Michael | 3
# Beck, Fabian | Vehlow, Corinna | 3
# Beck, Fabian | Weiskopf, Daniel | 3
# Burch, Michael | Vehlow, Corinna | 3
# Tal, Ayellet | Frishman, Yaniv | 3
# Wijk, Jarke | Pretorius, A. | 3
# Schmalstieg, Dieter | Streit, Marc | 3
# Schmalstieg, Dieter | Lex, Alexander | 3
# Lex, Alexander | Streit, Marc | 3
# Bourqui, Romain | Jourdan, Fabien | 3
# Nakazawa, Rina | Itoh, Takayuki | 2
# Zimmer, Bj{{o}}rn | Jusufi, Ilir | 2
# Zimmer, Bj{{o}}rn | Kerren, Andreas | 2
# Tanaka, Jiro | Misue, Kazuo | 2
# Mary, Patrick | Bourqui, Romain | 2
# Mary, Patrick | Auber, David | 2
# Auber, David | Lacroix, Vincent | 2
# Du, Xiaolin | Ye, Yunming | 2
# Du, Xiaolin | Lau, Raymond | 2
# Du, Xiaolin | Li, Yueping | 2
# Gansner, Emden | Kobourov, Stephen | 2
# Gansner, Emden | Hu, Yifan | 2
# Liu, Shixia | Cao, Nan | 2
# Liu, Shixia | Sun, Jimeng | 2
# Theis, Fabian | Vehlow, Corinna | 2
# Theis, Fabian | Weiskopf, Daniel | 2
# Theis, Fabian | Hasenauer, Jan | 2
# Xu, Panpan | Zhou, Hong | 2
# Xu, Panpan | Qu, Huamin | 2
# Lin, Yu-Ru | Cao, Nan | 2
# Klukas, Christian | Schreiber, Falk | 2
# Zhou, Hong | Qu, Huamin | 2
# Hong, Seok-Hee | Xu, Kai | 2
# Palladino, Pietro | Didimo, Walter | 2
# Palladino, Pietro | Liotta, Giuseppe | 2
# Hasenauer, Jan | Vehlow, Corinna | 2
# Hasenauer, Jan | Weiskopf, Daniel | 2
# Li, Yueping | Lau, Raymond | 2
# Li, Yueping | Ye, Yunming | 2
# Enright, Anton | Freeman, Tom | 2
# Enright, Anton | Dongen, Stijn | 2
# Itoh, Takayuki | Sese, Jun | 2
# Diehl, Stephan | Vehlow, Corinna | 2
# Diehl, Stephan | Weiskopf, Daniel | 2
# Freeman, Tom | Dongen, Stijn | 2
# Omote, Hiroki | Sugiyama, Kozo | 2
# Deussen, Oliver | Balzer, Michael | 2
# Abuthawabeh, Ala | Zeckzer, Dirk | 2
# Montecchiani, Fabrizio | Liotta, Giuseppe | 2
# Shneiderman, Ben | Dunne, Cody | 2
# Didimo, Walter | Di Giacomo, Emilio | 2
# Dinkla, Kasper | Westenberg, Michel | 2
# Jusufi, Ilir | Kerren, Andreas | 2
# Saket, Bahador | Kobourov, Stephen | 2
# Liotta, Giuseppe | Di Giacomo, Emilio | 2
# Hu, Zhenjun | DeLisi, Charles | 2
# Qu, Huamin | Cao, Nan | 2
# Ersoy, Ozan | Telea, Alexandru | 2
# Cao, Nan | Sun, Jimeng | 2
# Bourqui, Romain | Lacroix, Vincent | 2
# Bourqui, Romain | Lambert, Antoine | 2
# Lacroix, Vincent | Jourdan, Fabien | 2
# Ye, Yunming | Lau, Raymond | 2
# Dwyer, Tim | Henry Riche, Nathalie | 2
# Wu, Jie | Yamada, Takuji | 1
# Wu, Jie | DeLisi, Charles | 1
# Wu, Jie | Holloway, Dustin | 1
# Wu, Jie | Mellor, Joe | 1
# Wu, Jie | Hu, Zhenjun | 1
# Smith, Adam | Marai, G. | 1
# Smith, Adam | Xu, Wen | 1
# Smith, Adam | Faeder, James | 1
# Smith, Adam | Sun, Yao | 1
# Nakazawa, Rina | Sese, Jun | 1
# Nakazawa, Rina | Terada, Aika | 1
# Nakazawa, Rina | Saito, Takafumi | 1
# Hasco{e}t, Mountaz | Dragicevic, Pierre | 1
# Sangal, Neeraj | Jordan, Ev | 1
# Sangal, Neeraj | Sinha, Vineet | 1
# Sangal, Neeraj | Jackson, Daniel | 1
# Elmqvist, Niklas | Goodell, Howard | 1
# Elmqvist, Niklas | Fekete, Jean-Daniel | 1
# Elmqvist, Niklas | Tsigas, Philippas | 1
# Elmqvist, Niklas | Do, Thanh-Nghi | 1
# Elmqvist, Niklas | Henry, Nathalie | 1
# Zimmer, Bj{{o}}rn | Liu, Jiayi | 1
# Philippi, Stephan | Skusa, Andre | 1
# Philippi, Stephan | Verrier, Paul | 1
# Philippi, Stephan | K{o}hler, Jacob | 1
# Philippi, Stephan | Baumbach, Jan | 1
# Philippi, Stephan | Rawlings, Chris | 1
# Philippi, Stephan | R{u}egg, Alexander | 1
# Philippi, Stephan | Specht, Michael | 1
# Philippi, Stephan | Taubert, Jan | 1
# Vernik, Rudi | Phillips, Matthew | 1
# Vernik, Rudi | Pattison, Tim | 1
# Goesmann, Alexander | Haubrock, Martin | 1
# Goesmann, Alexander | Meyer, Folker | 1
# Goesmann, Alexander | Giegerich, Robert | 1
# Goesmann, Alexander | Kalinowski, Jorn | 1
# Tanaka, Jiro | Ito, Takao | 1
# Tanaka, Jiro | Gao, Jie | 1
# Mary, Patrick | Jourdan, Fabien | 1
# Mary, Patrick | Lacroix, Vincent | 1
# Mary, Patrick | Cottret, Ludovic | 1
# Mary, Patrick | Sagot, Marie-France | 1
# Nguyen, QuanHoang | Fu, Xiaoyan | 1
# Nguyen, QuanHoang | Hong, Seok-Hee | 1
# Nguyen, QuanHoang | Ahmed, Adel | 1
# Nguyen, QuanHoang | Xu, Kai | 1
# Schmauder, Hansj{{o}}rg | Weiskopf, Daniel | 1
# Schmauder, Hansj{{o}}rg | Burch, Michael | 1
# Schmauder, Hansj{{o}}rg | Vehlow, Corinna | 1
# Kramer, Andrei | Hug, Sabine | 1
# Kramer, Andrei | Vehlow, Corinna | 1
# Kramer, Andrei | Timmer, Jens | 1
# Kramer, Andrei | Weiskopf, Daniel | 1
# Kramer, Andrei | Radde, Nicole | 1
# Kramer, Andrei | Raue, Andreas | 1
# Kramer, Andrei | Theis, Fabian | 1
# Kramer, Andrei | Hasenauer, Jan | 1
# Jackson, Daniel | Jordan, Ev | 1
# Jackson, Daniel | Sinha, Vineet | 1
# Mellor, Joe | DeLisi, Charles | 1
# Mellor, Joe | Yamada, Takuji | 1
# Mellor, Joe | Holloway, Dustin | 1
# Mellor, Joe | Hu, Zhenjun | 1
# Sagot, Marie-France | Jourdan, Fabien | 1
# Sagot, Marie-France | Lacroix, Vincent | 1
# Sagot, Marie-France | Cottret, Ludovic | 1
# Sagot, Marie-France | Bourqui, Romain | 1
# Sagot, Marie-France | Auber, David | 1
# Roseman, Mark | Greenberg, Saul | 1
# Roseman, Mark | Bartram, Lyn | 1
# Roseman, Mark | Dubs, Shelli | 1
# Roseman, Mark | Dill, John | 1
# Roseman, Mark | Schaffer, Doug | 1
# Roseman, Mark | Zuo, Zhengping | 1
# Timmer, Jens | Vehlow, Corinna | 1
# Timmer, Jens | Weiskopf, Daniel | 1
# Timmer, Jens | Radde, Nicole | 1
# Timmer, Jens | Hug, Sabine | 1
# Timmer, Jens | Raue, Andreas | 1
# Timmer, Jens | Theis, Fabian | 1
# Timmer, Jens | Hasenauer, Jan | 1
# Eliassi-Rad, Tina | Ma, Kwan-Liu | 1
# Eliassi-Rad, Tina | Shen, Zeqian | 1
# Krishnan, Neeraj | Ham, Frank | 1
# Krishnan, Neeraj | Abello, James | 1
# Rucevskis, Peteris | Prusis, Krisjanis | 1
# Rucevskis, Peteris | Krebs, Valdis | 1
# Rucevskis, Peteris | Vihrovs, Jevgenijs | 1
# Rucevskis, Peteris | Freivalds, Karlis | 1
# Kalkofen, Denis | Streit, Marc | 1
# Kalkofen, Denis | Partl, Christian | 1
# Kalkofen, Denis | Kashofer, Karl | 1
# Kalkofen, Denis | Lex, Alexander | 1
# Kalkofen, Denis | Schmalstieg, Dieter | 1
# Rufiange, S{\'e}bastien | McGuffin, Michael | 1
# Rufiange, S{\'e}bastien | Fuhrman, Christopher | 1
# Termeer, Maurice | Lange, Christian | 1
# Termeer, Maurice | Telea, Alexandru | 1
# Termeer, Maurice | Chaudron, Michel | 1
# Ho, Joshua | Hong, Seok-Hee | 1
# Gilbert, Fr\'ed\'eric | Simonetto, Paolo | 1
# Gilbert, Fr\'ed\'eric | Bourqui, Romain | 1
# Gilbert, Fr\'ed\'eric | Jourdan, Fabien | 1
# Gilbert, Fr\'ed\'eric | Zaidi, Faraz | 1
# Taubert, Jan | Skusa, Andre | 1
# Taubert, Jan | Verrier, Paul | 1
# Taubert, Jan | K{o}hler, Jacob | 1
# Taubert, Jan | Baumbach, Jan | 1
# Taubert, Jan | Rawlings, Chris | 1
# Taubert, Jan | R{u}egg, Alexander | 1
# Taubert, Jan | Specht, Michael | 1
# Breitkreutz, Bobby-Joe | Stark, Chris | 1
# Breitkreutz, Bobby-Joe | Tyers, Mike | 1
# Lenhof, Hans-Peter | Niermann, Peter | 1
# Lenhof, Hans-Peter | Kuntzer, Jan | 1
# Lenhof, Hans-Peter | Faber, Daniel | 1
# Lenhof, Hans-Peter | Kaufmann, Michael | 1
# Lenhof, Hans-Peter | Kohlbacher, Oliver | 1
# Lenhof, Hans-Peter | Gerasch, Andreas | 1
# Zachariah, R. | Chaturvedi, S. | 1
# Zachariah, R. | Shneiderman, Ben | 1
# Zachariah, R. | Dunne, Cody | 1
# Zachariah, R. | Ashktorab, Zahra | 1
# Krause, Alexander | Hasselbring, Wilhelm | 1
# Krause, Alexander | Fittkau, Florian | 1
# Kruijff, Ernst | Streit, Marc | 1
# Kruijff, Ernst | Lex, Alexander | 1
# Kruijff, Ernst | Schmalstieg, Dieter | 1
# Faith, Joe | Gibson, Helen | 1
# Yan, Youliang | Wu, Yanhong | 1
# Yan, Youliang | Yang, Sixiao | 1
# Yan, Youliang | Wu, Wenbin | 1
# Yan, Youliang | Qu, Huamin | 1
# Bartram, Lyn | Greenberg, Saul | 1
# Bartram, Lyn | Dubs, Shelli | 1
# Bartram, Lyn | Dill, John | 1
# Bartram, Lyn | Schaffer, Doug | 1
# Bartram, Lyn | Zuo, Zhengping | 1
# Wu, Yanhong | Yang, Sixiao | 1
# Wu, Yanhong | Wu, Wenbin | 1
# Wu, Yanhong | Qu, Huamin | 1
# Greenberg, Saul | Dubs, Shelli | 1
# Greenberg, Saul | Dill, John | 1
# Greenberg, Saul | Schaffer, Doug | 1
# Greenberg, Saul | Zuo, Zhengping | 1
# Fritz, Peter | Burch, Michael | 1
# Fritz, Peter | Beck, Fabian | 1
# Fritz, Peter | Diehl, Stephan | 1
# Munzner, Tamara | Gardy, Jennifer | 1
# Munzner, Tamara | Barsky, Aaron | 1
# Munzner, Tamara | Kincaid, Robert | 1
# Munzner, Tamara | Melan\c{c}on, Guy | 1
# Munzner, Tamara | Renoust, Benjamin | 1
# Kalinowski, Jorn | Haubrock, Martin | 1
# Kalinowski, Jorn | Meyer, Folker | 1
# Kalinowski, Jorn | Giegerich, Robert | 1
# Chaturvedi, S. | Shneiderman, Ben | 1
# Chaturvedi, S. | Dunne, Cody | 1
# Chaturvedi, S. | Ashktorab, Zahra | 1
# Haubrock, Martin | Giegerich, Robert | 1
# Haubrock, Martin | Meyer, Folker | 1
# Auber, David | Sansen, Joris | 1
# Auber, David | Chiricota, Yves | 1
# Auber, David | Cottret, Ludovic | 1
# Auber, David | Lalanne, Fr\'ed\'eric | 1
# Auber, David | Melancon, Guy | 1
# Du, Xiaolin | Huang, Xiaohui | 1
# Nguyen, Quang | Hua, Jie | 1
# Niermann, Peter | Kuntzer, Jan | 1
# Niermann, Peter | Faber, Daniel | 1
# Niermann, Peter | Kaufmann, Michael | 1
# Niermann, Peter | Kohlbacher, Oliver | 1
# Niermann, Peter | Gerasch, Andreas | 1
# Zhou, Qi | Misue, Kazuo | 1
# Kao, David | G{o}rg, Carsten | 1
# Kao, David | Bristow, Michael | 1
# Kao, David | Hunter, Lawrence | 1
# Kao, David | Vehlow, Corinna | 1
# Kao, David | Weiskopf, Daniel | 1
# Gansner, Emden | Koren, Yehuda | 1
# Liu, Shixia | Lin, Yu-Ru | 1
# Liu, Shixia | Zhang, Xin | 1
# Liu, Shixia | Liu, Yujie | 1
# Liu, Shixia | Shi, Lei | 1
# Liu, Shixia | Qu, Huamin | 1
# Liu, Shixia | Barlowe, Scott | 1
# Liu, Shixia | Qian, Weihong | 1
# Liu, Shixia | Guo, Baining | 1
# Liu, Shixia | Gotz, David | 1
# Liu, Shixia | Chen, Jianfei | 1
# Liu, Shixia | Yuan, Xiaoru | 1
# Liu, Shixia | Tan, Li | 1
# Liu, Shixia | Zhao, Ye | 1
# Liu, Shixia | Zhu, Jun | 1
# Liu, Shixia | Wang, Guodong | 1
# Liu, Shixia | Wang, Xiting | 1
# Liu, Shixia | Lin, Ching-Yung | 1
# Liu, Shixia | Yang, Jing | 1
# Thornton, Janet | Enright, Anton | 1
# Thornton, Janet | Freeman, Tom | 1
# Thornton, Janet | Dongen, Stijn | 1
# Thornton, Janet | Mazi\'{e}re, Pierre | 1
# Thornton, Janet | Freilich, Shiri | 1
# Thornton, Janet | Goldovsky, Leon | 1
# Thornton, Janet | Brosch, Markus | 1
# Thornton, Janet | Grocock, Russell | 1
# Schmidt, Benjamin | Weiskopf, Daniel | 1
# Schmidt, Benjamin | Burch, Michael | 1
# Hlawatsch, Marcel | Weiskopf, Daniel | 1
# Hlawatsch, Marcel | Burch, Michael | 1
# Theis, Fabian | Radde, Nicole | 1
# Theis, Fabian | Hug, Sabine | 1
# Theis, Fabian | Raue, Andreas | 1
# Yuan, Xiaoru | Liu, Yujie | 1
# Yuan, Xiaoru | Zhang, Xin | 1
# Yuan, Xiaoru | Barlowe, Scott | 1
# Yuan, Xiaoru | Zhao, Ye | 1
# Yuan, Xiaoru | Yang, Jing | 1
# Xu, Panpan | Cao, Nan | 1
# Xu, Panpan | Shi, Conglei | 1
# Xu, Panpan | Du, Fan | 1
# Schulz, Hans-J{o}rg | Ham, Frank | 1
# Schulz, Hans-J{o}rg | John, Mathias | 1
# Schulz, Hans-J{o}rg | Dimicco, Joan | 1
# Schulz, Hans-J{o}rg | Unger, Andrea | 1
# Schulz, Hans-J{o}rg | Schumann, Heidrun | 1
# Royer, Loic | Reimann, Matthias | 1
# Royer, Loic | Andreopoulos, Bill | 1
# Royer, Loic | Schroeder, Michael | 1
# Buzluca, Feza | Erdemir, Ural | 1
# Buzluca, Feza | Tekin, Umut | 1
# Schaffer, Doug | Dill, John | 1
# Schaffer, Doug | Dubs, Shelli | 1
# Schaffer, Doug | Zuo, Zhengping | 1
# Grilli, Luca | Didimo, Walter | 1
# Grilli, Luca | Di Giacomo, Emilio | 1
# Grilli, Luca | Liotta, Giuseppe | 1
# Tan, Li | Wang, Guodong | 1
# Tan, Li | Cao, Nan | 1
# Tan, Li | Qian, Weihong | 1
# Tan, Li | Sun, Jimeng | 1
# Tan, Li | Shi, Lei | 1
# Tan, Li | Lin, Ching-Yung | 1
# Stark, Chris | Tyers, Mike | 1
# Chau, Duen | Goel, Aakash | 1
# Chau, Duen | Stolper, Charles | 1
# Chau, Duen | Kahng, Minsuk | 1
# Chau, Duen | Foerster, Florian | 1
# Chau, Duen | Stasko, John | 1
# Chau, Duen | Lin, Zhiyuan | 1
# Lin, Yu-Ru | Tong, Hanghang | 1
# Lin, Yu-Ru | Qu, Huamin | 1
# Lin, Yu-Ru | Gotz, David | 1
# Lin, Yu-Ru | Sun, Jimeng | 1
# Lin, Yu-Ru | Li, Liangyue | 1
# Klukas, Christian | Junker, Bjorn | 1
# Barsky, Aaron | Kincaid, Robert | 1
# Barsky, Aaron | Gardy, Jennifer | 1
# K{o}hler, Jacob | Skusa, Andre | 1
# K{o}hler, Jacob | Verrier, Paul | 1
# K{o}hler, Jacob | Baumbach, Jan | 1
# K{o}hler, Jacob | Rawlings, Chris | 1
# K{o}hler, Jacob | R{u}egg, Alexander | 1
# K{o}hler, Jacob | Specht, Michael | 1
# Wang, Taowei | Fekete, Jean-Daniel | 1
# Wang, Taowei | Dang, N. | 1
# Wang, Taowei | Plaisant, Catherine | 1
# Wang, Taowei | Aris, Aleks | 1
# Saito, Takafumi | Itoh, Takayuki | 1
# Jordan, Ev | Sinha, Vineet | 1
# Kasyanov, Victor | Lisitsyn, Ivan | 1
# Lange, Christian | Telea, Alexandru | 1
# Lange, Christian | Chaudron, Michel | 1
# Kahng, Minsuk | Goel, Aakash | 1
# Kahng, Minsuk | Stolper, Charles | 1
# Kahng, Minsuk | Foerster, Florian | 1
# Kahng, Minsuk | Stasko, John | 1
# Kahng, Minsuk | Lin, Zhiyuan | 1
# Zhang, Kang | Kumar, Pushpa | 1
# Zhang, Kang | Wang, Yuke | 1
# Sun, Yao | Marai, G. | 1
# Sun, Yao | Xu, Wen | 1
# Sun, Yao | Faeder, James | 1
# Beck, Fabian | Petkov, Radoslav | 1
# Beck, Fabian | Abuthawabeh, Ala | 1
# Beck, Fabian | Zeckzer, Dirk | 1
# Beck, Fabian | Auw{a}rter, Patrick | 1
# Saga, Ryosuke | Yamashita, Takafumi | 1
# Paduano, Francesco | Forbes, Angus | 1
# Huang, Xiaohui | Lau, Raymond | 1
# Huang, Xiaohui | Ye, Yunming | 1
# Huang, Xiaohui | Li, Yueping | 1
# Heer, Jeffrey | Boyd, Danah | 1
# Shi, Lei | Wang, Guodong | 1
# Shi, Lei | Cao, Nan | 1
# Shi, Lei | Qian, Weihong | 1
# Shi, Lei | Sun, Jimeng | 1
# Shi, Lei | Lin, Ching-Yung | 1
# Faris, Robert | Ma, Kwan-Liu | 1
# Faris, Robert | Muelder, Chris | 1
# Faris, Robert | Felmlee, Diane | 1
# Faris, Robert | Crnovrsanin, Tarik | 1
# Quigley, Aaron | Eades, Peter | 1
# Archambault, Daniel | Purchase, Helen | 1
# Archambault, Daniel | Pinaud, Bruno | 1
# Kumar, Pushpa | Wang, Yuke | 1
# Civril, Ali | Giral, Erhan | 1
# Civril, Ali | Dogrusoz, Ugur | 1
# Civril, Ali | Demir, Emek | 1
# Civril, Ali | Cetintas, Ahmet | 1
# Fischer, Michael | Ratzinger, Jacek | 1
# Fischer, Michael | Gall, Harald | 1
# Wang, Eric | Zou, Futai | 1
# Bach, Benjamin | Fekete, Jean-Daniel | 1
# Bach, Benjamin | Pietriga, Emmanuel | 1
# Zhou, Hong | Cao, Nan | 1
# Zhou, Hong | Shi, Conglei | 1
# Zhou, Hong | Du, Fan | 1
# Sallaberry, Arnaud | Zaidi, Faraz | 1
# Sallaberry, Arnaud | Ma, Kwan-Liu | 1
# Sallaberry, Arnaud | Muelder, Chris | 1
# Sallaberry, Arnaud | Pich, Christian | 1
# Sallaberry, Arnaud | Melancon, Guy | 1
# Liu, Qing | Zhang, Ji | 1
# Liu, Qing | Hong, Seok-Hee | 1
# Liu, Qing | Xu, Kai | 1
# Liu, Qing | Williams, Rohan | 1
# Collins, Christopher | Balakrishnan, Ravin | 1
# Collins, Christopher | Carpendale, Sheelagh | 1
# Collins, Christopher | Zhao, Jian | 1
# Collins, Christopher | Chevalier, Fanny | 1
# Fagnan, Justin | Zaiane, Osmar | 1
# Fagnan, Justin | Goebel, Randy | 1
# Marai, G. | Xu, Wen | 1
# Marai, G. | Faeder, James | 1
# Hong, Seok-Hee | Mader, Martin | 1
# Hong, Seok-Hee | Meidiana, Amyra | 1
# Hong, Seok-Hee | Fu, Xiaoyan | 1
# Hong, Seok-Hee | Zhang, Ji | 1
# Hong, Seok-Hee | Williams, Rohan | 1
# Hong, Seok-Hee | Ahmed, Adel | 1
# Queyroi, Francois | Lambert, Antoine | 1
# Queyroi, Francois | Bourqui, Romain | 1
# Goebel, Randy | Zaiane, Osmar | 1
# Palladino, Pietro | Di Giacomo, Emilio | 1
# Palladino, Pietro | Montecchiani, Fabrizio | 1
# Hasenauer, Jan | Hug, Sabine | 1
# Hasenauer, Jan | Radde, Nicole | 1
# Hasenauer, Jan | Raue, Andreas | 1
# Burch, Michael | Hoferlin, Markus | 1
# Burch, Michael | Greilich, Martin | 1
# Burch, Michael | Munz, Tanja | 1
# Krebs, Valdis | Prusis, Krisjanis | 1
# Krebs, Valdis | Vihrovs, Jevgenijs | 1
# Krebs, Valdis | Freivalds, Karlis | 1
# Yoghourdjian, Vahan | Kieffer, Steve | 1
# Yoghourdjian, Vahan | Dwyer, Tim | 1
# Yoghourdjian, Vahan | Gange, Graeme | 1
# Yoghourdjian, Vahan | Marriott, Kim | 1
# Yoghourdjian, Vahan | Klein, Karsten | 1
# Paulovich, Fernando | Telea, Alexandru | 1
# Paulovich, Fernando | Cantareiro, Gabriel | 1
# Paulovich, Fernando | Hurter, Christophe | 1
# Paulovich, Fernando | Ersoy, Ozan | 1
# Gratzl, Samuel | Stitz, Holger | 1
# Gratzl, Samuel | Krieger, Michael | 1
# Gratzl, Samuel | Streit, Marc | 1
# Liu, Yujie | Zhang, Xin | 1
# Liu, Yujie | Barlowe, Scott | 1
# Liu, Yujie | Zhao, Ye | 1
# Liu, Yujie | Yang, Jing | 1
# Rusu, Adrian | Taggart, Douglas | 1
# Rusu, Adrian | Jianu, Radu | 1
# Rusu, Adrian | Hu, Yifan | 1
# Chang, Chin-Lung | Chen, Ding-Yi | 1
# Chang, Chin-Lung | Chuang, Tyng-Ruey | 1
# Chang, Yi-Chien | Hung, Jui-Hung | 1
# Chang, Yi-Chien | Huyck, Matt | 1
# Chang, Yi-Chien | Wang, Yan | 1
# Chang, Yi-Chien | Huang, Chia-Ling | 1
# Chang, Yi-Chien | DeLisi, Charles | 1
# Chang, Yi-Chien | Hu, Zhenjun | 1
# Goodell, Howard | Fekete, Jean-Daniel | 1
# Goodell, Howard | Do, Thanh-Nghi | 1
# Goodell, Howard | Henry, Nathalie | 1
# Fekete, Jean-Daniel | Dang, N. | 1
# Fekete, Jean-Daniel | Aris, Aleks | 1
# Fekete, Jean-Daniel | Pietriga, Emmanuel | 1
# Fekete, Jean-Daniel | Ghoniem, Mohammad | 1
# Fekete, Jean-Daniel | McGuffin, Michael | 1
# Fekete, Jean-Daniel | Do, Thanh-Nghi | 1
# Fekete, Jean-Daniel | Bezerianos, Anastasia | 1
# Fekete, Jean-Daniel | Plaisant, Catherine | 1
# Henry, Nathalie | McGuffin, Michael | 1
# Henry, Nathalie | Do, Thanh-Nghi | 1
# Henry, Nathalie | Bezerianos, Anastasia | 1
# Enright, Anton | Theocharidis, Athanasios | 1
# Enright, Anton | Mazi\'{e}re, Pierre | 1
# Enright, Anton | Freilich, Shiri | 1
# Enright, Anton | Goldovsky, Leon | 1
# Enright, Anton | Brosch, Markus | 1
# Enright, Anton | Grocock, Russell | 1
# Itoh, Takayuki | Terada, Aika | 1
# Itoh, Takayuki | Ma, Kwan-Liu | 1
# Itoh, Takayuki | Muelder, Chris | 1
# Feng, Qing-Wen | Lin, Xuemin | 1
# Feng, Qing-Wen | Nagamochi, Hiroshi | 1
# Feng, Qing-Wen | Cohen, Robert | 1
# Cruz, Juan | Bothorel, C{\'e}cile | 1
# Cruz, Juan | Poulet, Fran\c{c}ois | 1
# Gou, Liang | Zhang, Xiaolong | 1
# Belviranli, Mehmet | Dogrusoz, Ugur | 1
# Belviranli, Mehmet | Dilek, Alptug | 1
# Liggesmeyer, Peter | Stal, Michael | 1
# Liggesmeyer, Peter | Sokolov, Konstantin | 1
# Liggesmeyer, Peter | Wuchner, Egon | 1
# Liggesmeyer, Peter | Daniel, Donny | 1
# Wuchner, Egon | Stal, Michael | 1
# Wuchner, Egon | Sokolov, Konstantin | 1
# Wuchner, Egon | Daniel, Donny | 1
# Staples, Mathew | Bieman, James | 1
# Tollis, Ioannis | Six, Janet | 1
# Pinaud, Bruno | Purchase, Helen | 1
# Xiang, Yang | Fuhry, David | 1
# Xiang, Yang | Dragan, Feodor | 1
# Xiang, Yang | Jin, Ruoming | 1
# Goldovsky, Leon | Freeman, Tom | 1
# Goldovsky, Leon | Dongen, Stijn | 1
# Goldovsky, Leon | Mazi\'{e}re, Pierre | 1
# Goldovsky, Leon | Freilich, Shiri | 1
# Goldovsky, Leon | Brosch, Markus | 1
# Goldovsky, Leon | Grocock, Russell | 1
# Sprenger, Thomas | Brunella, R | 1
# Sprenger, Thomas | Gross, Markus | 1
# Ramos, Gonzalo | Czerwinski, Mary | 1
# Ramos, Gonzalo | Henry Riche, Nathalie | 1
# Ramos, Gonzalo | Alper, Basak | 1
# Graham, M. | Kennedy, J.B. | 1
# Graham, M. | Melville, A.G. | 1
# Diehl, Stephan | Reitz, Florian | 1
# Diehl, Stephan | Petkov, Radoslav | 1
# Diehl, Stephan | Pohl, Mathias | 1
# Diehl, Stephan | Abuthawabeh, Ala | 1
# Diehl, Stephan | Zeckzer, Dirk | 1
# Diehl, Stephan | Greilich, Martin | 1
# Wang, Xiting | Zhu, Jun | 1
# Wang, Xiting | Chen, Jianfei | 1
# Wang, Xiting | Guo, Baining | 1
# Auw{a}rter, Patrick | Weiskopf, Daniel | 1
# Auw{a}rter, Patrick | Vehlow, Corinna | 1
# Freeman, Tom | Theocharidis, Athanasios | 1
# Freeman, Tom | Mazi\'{e}re, Pierre | 1
# Freeman, Tom | Freilich, Shiri | 1
# Freeman, Tom | Brosch, Markus | 1
# Freeman, Tom | Grocock, Russell | 1
# Mothe, Josiane | Dkaki, Taoufiq | 1
# Pattison, Tim | Phillips, Matthew | 1
# Bristow, Michael | G{o}rg, Carsten | 1
# Bristow, Michael | Hunter, Lawrence | 1
# Bristow, Michael | Vehlow, Corinna | 1
# Bristow, Michael | Weiskopf, Daniel | 1
# Weiskopf, Daniel | Raue, Andreas | 1
# Weiskopf, Daniel | Hug, Sabine | 1
# Weiskopf, Daniel | Hunter, Lawrence | 1
# Weiskopf, Daniel | Munz, Tanja | 1
# Weiskopf, Daniel | Radde, Nicole | 1
# Weiskopf, Daniel | Reinhardt, Thomas | 1
# Weiskopf, Daniel | Hoferlin, Markus | 1
# Weiskopf, Daniel | G{o}rg, Carsten | 1
# Poulet, Fran\c{c}ois | Bothorel, C{\'e}cile | 1
# Wijk, Jarke | Elzen, Stef | 1
# Wijk, Jarke | Holten, Danny | 1
# Wijk, Jarke | Ham, Frank | 1
# Wijk, Jarke | Cornelissen, Bas | 1
# Misue, Kazuo | Ito, Takao | 1
# Misue, Kazuo | Gao, Jie | 1
# Misue, Kazuo | Sugiyama, Kozo | 1
# Salomonis, Nathan | Pico, Alexander | 1
# Salomonis, Nathan | Kuchinsky, Allan | 1
# Salomonis, Nathan | Hanspers, Kristina | 1
# Salomonis, Nathan | Zhang, Chao | 1
# Salomonis, Nathan | Xu, Dong | 1
# Kwee, AgusTrisnajaya | Lim, Ee-Peng | 1
# Kwee, AgusTrisnajaya | Dai, Bing | 1
# Gall, Harald | Grafenhain, Katja | 1
# Gall, Harald | Pinzger, Martin | 1
# Gall, Harald | Ratzinger, Jacek | 1
# Gall, Harald | Knab, Patrick | 1
# Zhao, Ye | Zhang, Xin | 1
# Zhao, Ye | Barlowe, Scott | 1
# Zhao, Ye | Yang, Jing | 1
# Goel, Aakash | Stolper, Charles | 1
# Goel, Aakash | Foerster, Florian | 1
# Goel, Aakash | Stasko, John | 1
# Goel, Aakash | Lin, Zhiyuan | 1
# Fittkau, Florian | Hasselbring, Wilhelm | 1
# Noack, Andreas | Lewerentz, Claus | 1
# Gardy, Jennifer | Kincaid, Robert | 1
# Unger, Andrea | John, Mathias | 1
# Unger, Andrea | Schumann, Heidrun | 1
# Li, Liangyue | Tong, Hanghang | 1
# Li, Liangyue | Cao, Nan | 1
# Peng, Wu | Si-Kun, Li | 1
# Knab, Patrick | Grafenhain, Katja | 1
# Knab, Patrick | Pinzger, Martin | 1
# Guo, Baining | Zhu, Jun | 1
# Guo, Baining | Chen, Jianfei | 1
# Veeramoni, Sankar | Kobourov, Stephen | 1
# Veeramoni, Sankar | Hu, Yifan | 1
# Jin, Ruoming | Fuhry, David | 1
# Jin, Ruoming | Dragan, Feodor | 1
# Kottler, Stephan | Lehmann, Katharina | 1
# Lin, Zhiyuan | Stolper, Charles | 1
# Lin, Zhiyuan | Foerster, Florian | 1
# Lin, Zhiyuan | Stasko, John | 1
# Abello, James | Ham, Frank | 1
# Abello, James | Yusufov, Roman | 1
# Abello, James | Kobourov, Stephen | 1
# Dilek, Alptug | Dogrusoz, Ugur | 1
# Tong, Hanghang | Cao, Nan | 1
# Wu, Wenbin | Yang, Sixiao | 1
# Wu, Wenbin | Qu, Huamin | 1
# Smit, Martine | Siderius, Marco | 1
# Smit, Martine | Klau, Gunnar | 1
# Smit, Martine | Dinkla, Kasper | 1
# Smit, Martine | Bucur, Cristina-Iulia | 1
# Smit, Martine | Westenberg, Michel | 1
# Smit, Martine | El-Kebir, Mohammed | 1
# Radde, Nicole | Vehlow, Corinna | 1
# Radde, Nicole | Hug, Sabine | 1
# Radde, Nicole | Raue, Andreas | 1
# Shneiderman, Ben | Aris, Aleks | 1
# Shneiderman, Ben | Ashktorab, Zahra | 1
# Shneiderman, Ben | Perer, Adam | 1
# Wagner, Dorothea | Brandes, Ulrik | 1
# Krieger, Michael | Stitz, Holger | 1
# Krieger, Michael | Streit, Marc | 1
# Didimo, Walter | Romeo, Salvatore | 1
# Woodward, Michael | Stuckey, Peter | 1
# Woodward, Michael | Dwyer, Tim | 1
# Woodward, Michael | Schreiber, Falk | 1
# Woodward, Michael | Marriott, Kim | 1
# Woodward, Michael | Wybrow, Michael | 1
# Chaudron, Michel | Telea, Alexandru | 1
# Kalkusch, Michael | Zatloukal, Kurt | 1
# Kalkusch, Michael | Streit, Marc | 1
# Kalkusch, Michael | Lex, Alexander | 1
# Kalkusch, Michael | Schmalstieg, Dieter | 1
# Hu, Yifan | Taggart, Douglas | 1
# Hu, Yifan | Efrat, Alon | 1
# Hu, Yifan | Jianu, Radu | 1
# Hu, Yifan | Pupyrev, Sergey | 1
# Barlowe, Scott | Zhang, Xin | 1
# Barlowe, Scott | Yang, Jing | 1
# Faeder, James | Xu, Wen | 1
# Chen, Ding-Yi | Chuang, Tyng-Ruey | 1
# Williams, Rohan | Zhang, Ji | 1
# Williams, Rohan | Xu, Kai | 1
# Dai, Bing | Lim, Ee-Peng | 1
# Raue, Andreas | Vehlow, Corinna | 1
# Raue, Andreas | Hug, Sabine | 1
# Demir, Emek | Giral, Erhan | 1
# Demir, Emek | Dogrusoz, Ugur | 1
# Demir, Emek | Cetintas, Ahmet | 1
# Yamada, Takuji | Kanehisa, Minoru | 1
# Yamada, Takuji | Letunic, Ivica | 1
# Yamada, Takuji | Holloway, Dustin | 1
# Yamada, Takuji | Hu, Zhenjun | 1
# Yamada, Takuji | DeLisi, Charles | 1
# Yamada, Takuji | Bork, Peer | 1
# Giegerich, Robert | Meyer, Folker | 1
# Brosch, Markus | Dongen, Stijn | 1
# Brosch, Markus | Mazi\'{e}re, Pierre | 1
# Brosch, Markus | Freilich, Shiri | 1
# Brosch, Markus | Grocock, Russell | 1
# Reinhardt, Thomas | Vehlow, Corinna | 1
# Sokolov, Konstantin | Stal, Michael | 1
# Sokolov, Konstantin | Daniel, Donny | 1
# Hanspers, Kristina | Pico, Alexander | 1
# Hanspers, Kristina | Kuchinsky, Allan | 1
# Hanspers, Kristina | Zhang, Chao | 1
# Hanspers, Kristina | Xu, Dong | 1
# Fu, Xiaoyan | Ahmed, Adel | 1
# Fu, Xiaoyan | Xu, Kai | 1
# Dinkla, Kasper | Siderius, Marco | 1
# Dinkla, Kasper | Klau, Gunnar | 1
# Dinkla, Kasper | Bucur, Cristina-Iulia | 1
# Dinkla, Kasper | Kreveld, Marc | 1
# Dinkla, Kasper | Speckmann, Bettina | 1
# Dinkla, Kasper | El-Kebir, Mohammed | 1
# G{o}rg, Carsten | Hunter, Lawrence | 1
# G{o}rg, Carsten | Vehlow, Corinna | 1
# Chen, Jianfei | Zhu, Jun | 1
# Xu, Kai | Zhang, Ji | 1
# Xu, Kai | Ahmed, Adel | 1
# Jusufi, Ilir | Liu, Jiayi | 1
# Saket, Bahador | Scheidegger, Carlos | 1
# Saket, Bahador | Simonetto, Paolo | 1
# Saket, Bahador | Borner, Katy | 1
# Saket, Bahador | B{o}rner, Katy | 1
# Miyamoto, Isao | Wang, Xiaobo | 1
# Skusa, Andre | Verrier, Paul | 1
# Skusa, Andre | Baumbach, Jan | 1
# Skusa, Andre | Rawlings, Chris | 1
# Skusa, Andre | R{u}egg, Alexander | 1
# Skusa, Andre | Specht, Michael | 1
# Schmalstieg, Dieter | Kashofer, Karl | 1
# Schmalstieg, Dieter | Zatloukal, Kurt | 1
# Schmalstieg, Dieter | Partl, Christian | 1
# Zaidi, Faraz | Jourdan, Fabien | 1
# Zaidi, Faraz | Pich, Christian | 1
# Zaidi, Faraz | Simonetto, Paolo | 1
# Zaidi, Faraz | Bourqui, Romain | 1
# Zaidi, Faraz | Melancon, Guy | 1
# Mears, Christopher | Dwyer, Tim | 1
# Mears, Christopher | Marriott, Kim | 1
# Mears, Christopher | Henry Riche, Nathalie | 1
# Shen, Zeqian | Ma, Kwan-Liu | 1
# Schreiber, Falk | Dwyer, Tim | 1
# Schreiber, Falk | Hagen, Hans | 1
# Schreiber, Falk | Wybrow, Michael | 1
# Schreiber, Falk | Zeckzer, Dirk | 1
# Schreiber, Falk | Stuckey, Peter | 1
# Schreiber, Falk | Junker, Bjorn | 1
# Schreiber, Falk | B{o}rner, Katy | 1
# Schreiber, Falk | Kerren, Andreas | 1
# Schreiber, Falk | Marriott, Kim | 1
# B{o}rner, Katy | Kobourov, Stephen | 1
# B{o}rner, Katy | Zeckzer, Dirk | 1
# B{o}rner, Katy | Hagen, Hans | 1
# B{o}rner, Katy | Simonetto, Paolo | 1
# B{o}rner, Katy | Kerren, Andreas | 1
# Yang, Jing | Zhang, Xin | 1
# Sese, Jun | Muelder, Chris | 1
# Sese, Jun | Ma, Kwan-Liu | 1
# Sese, Jun | Terada, Aika | 1
# Reimann, Matthias | Andreopoulos, Bill | 1
# Reimann, Matthias | Schroeder, Michael | 1
# Melan\c{c}on, Guy | Renoust, Benjamin | 1
# Partl, Christian | Streit, Marc | 1
# Partl, Christian | Kashofer, Karl | 1
# Partl, Christian | Lex, Alexander | 1
# Kieffer, Steve | Gange, Graeme | 1
# Kieffer, Steve | Dwyer, Tim | 1
# Kieffer, Steve | Marriott, Kim | 1
# Kieffer, Steve | Klein, Karsten | 1
# Theocharidis, Athanasios | Dongen, Stijn | 1
# Yang, Sixiao | Qu, Huamin | 1
# Daniel, Donny | Stal, Michael | 1
# Ham, Frank | Dimicco, Joan | 1
# Ham, Frank | Wattenberg, Michael | 1
# Gerasch, Andreas | Kuntzer, Jan | 1
# Gerasch, Andreas | Faber, Daniel | 1
# Gerasch, Andreas | Kaufmann, Michael | 1
# Gerasch, Andreas | Kohlbacher, Oliver | 1
# Liotta, Giuseppe | Romeo, Salvatore | 1
# Ogawa, Michael | Ma, Kwan-Liu | 1
# Ogawa, Michael | McPherson, Jonathan | 1
# Dragan, Feodor | Fuhry, David | 1
# Efrat, Alon | Pupyrev, Sergey | 1
# Efrat, Alon | Kobourov, Stephen | 1
# R{u}egg, Alexander | Verrier, Paul | 1
# R{u}egg, Alexander | Baumbach, Jan | 1
# R{u}egg, Alexander | Rawlings, Chris | 1
# R{u}egg, Alexander | Specht, Michael | 1
# Lin, Xuemin | Eades, Peter | 1
# Jansson, Andreas | Jirstrand, Mats | 1
# Klein, Karsten | Gange, Graeme | 1
# Klein, Karsten | Dwyer, Tim | 1
# Klein, Karsten | Marriott, Kim | 1
# Gotz, David | Cao, Nan | 1
# Gotz, David | Sun, Jimeng | 1
# Gotz, David | Qu, Huamin | 1
# Carpendale, Sheelagh | Neumann, Petra | 1
# Carpendale, Sheelagh | Schlechtweg, Stefan | 1
# Byelas, Heorhiy | Bondarev, Egor | 1
# Hung, Jui-Hung | Wang, Yan | 1
# Hung, Jui-Hung | Huyck, Matt | 1
# Hung, Jui-Hung | Huang, Chia-Ling | 1
# Hung, Jui-Hung | DeLisi, Charles | 1
# Hung, Jui-Hung | Hu, Zhenjun | 1
# Hu, Zhenjun | Huyck, Matt | 1
# Hu, Zhenjun | Holloway, Dustin | 1
# Hu, Zhenjun | Wang, Yan | 1
# Hu, Zhenjun | Huang, Chia-Ling | 1
# Kumar, Gautam | Garland, Michael | 1
# Kobourov, Stephen | Borner, Katy | 1
# Kobourov, Stephen | Scheidegger, Carlos | 1
# Kobourov, Stephen | Yusufov, Roman | 1
# Kobourov, Stephen | Simonetto, Paolo | 1
# Kobourov, Stephen | Pupyrev, Sergey | 1
# Cetintas, Ahmet | Giral, Erhan | 1
# Cetintas, Ahmet | Dogrusoz, Ugur | 1
# Pinzger, Martin | Grafenhain, Katja | 1
# Qu, Huamin | Shi, Conglei | 1
# Qu, Huamin | Sun, Jimeng | 1
# Qu, Huamin | Du, Fan | 1
# Speckmann, Bettina | Westenberg, Michel | 1
# Speckmann, Bettina | Kreveld, Marc | 1
# Neumann, Petra | Schlechtweg, Stefan | 1
# Kerren, Andreas | Liu, Jiayi | 1
# Kerren, Andreas | Heine, Christian | 1
# Kerren, Andreas | Reichenbach, Andr{\'e} | 1
# Kerren, Andreas | Scheuermann, Gerik | 1
# Kerren, Andreas | Rohrschneider, Markus | 1
# Kerren, Andreas | Zeckzer, Dirk | 1
# Kerren, Andreas | Hagen, Hans | 1
# Jianu, Radu | Taggart, Douglas | 1
# Giral, Erhan | Dogrusoz, Ugur | 1
# Dunne, Cody | Ashktorab, Zahra | 1
# Foerster, Florian | Stolper, Charles | 1
# Foerster, Florian | Stasko, John | 1
# Kohlbacher, Oliver | Kuntzer, Jan | 1
# Kohlbacher, Oliver | Faber, Daniel | 1
# Kohlbacher, Oliver | Kaufmann, Michael | 1
# Ersoy, Ozan | Cantareiro, Gabriel | 1
# Ersoy, Ozan | Hurter, Christophe | 1
# Pico, Alexander | Xu, Dong | 1
# Pico, Alexander | Kuchinsky, Allan | 1
# Pico, Alexander | Zhang, Chao | 1
# Vihrovs, Jevgenijs | Prusis, Krisjanis | 1
# Vihrovs, Jevgenijs | Freivalds, Karlis | 1
# Lex, Alexander | Kashofer, Karl | 1
# Lex, Alexander | Zatloukal, Kurt | 1
# Davis, Darcy | Chawla, Nitesh | 1
# Vehlow, Corinna | Hug, Sabine | 1
# Vehlow, Corinna | Hunter, Lawrence | 1
# Hurter, Christophe | Cantareiro, Gabriel | 1
# Hurter, Christophe | Telea, Alexandru | 1
# Cao, Nan | Shi, Conglei | 1
# Cao, Nan | Du, Fan | 1
# Cao, Nan | Wang, Guodong | 1
# Cao, Nan | Qian, Weihong | 1
# Cao, Nan | Lin, Ching-Yung | 1
# DeLisi, Charles | Huyck, Matt | 1
# DeLisi, Charles | Holloway, Dustin | 1
# DeLisi, Charles | Wang, Yan | 1
# DeLisi, Charles | Huang, Chia-Ling | 1
# Schumann, Heidrun | John, Mathias | 1
# Telea, Alexandru | Cantareiro, Gabriel | 1
# Telea, Alexandru | Bondarev, Egor | 1
# Dill, John | Dubs, Shelli | 1
# Dill, John | Zuo, Zhengping | 1
# Stuckey, Peter | Wybrow, Michael | 1
# Stuckey, Peter | Dwyer, Tim | 1
# Stuckey, Peter | Marriott, Kim | 1
# Borner, Katy | Scheidegger, Carlos | 1
# Dinkla, K. | Westenberg, M.A. | 1
# Dinkla, K. | Riche, N. | 1
# Rohrschneider, Markus | Heine, Christian | 1
# Rohrschneider, Markus | Reichenbach, Andr{\'e} | 1
# Rohrschneider, Markus | Scheuermann, Gerik | 1
# Du, Fan | Shi, Conglei | 1
# Marriott, Kim | Henry Riche, Nathalie | 1
# Marriott, Kim | Koren, Yehuda | 1
# Marriott, Kim | Wybrow, Michael | 1
# Marriott, Kim | Gange, Graeme | 1
# Kanehisa, Minoru | Letunic, Ivica | 1
# Kanehisa, Minoru | Bork, Peer | 1
# McGuffin, Michael | Fuhrman, Christopher | 1
# Lalanne, Fr\'ed\'eric | Sansen, Joris | 1
# Lalanne, Fr\'ed\'eric | Bourqui, Romain | 1
# Dubois, Jonathan | Lambert, Antoine | 1
# Dubois, Jonathan | Bourqui, Romain | 1
# Nagamochi, Hiroshi | Eades, Peter | 1
# Huang, Mao | Hua, Jie | 1
# Huang, Mao | Eades, Peter | 1
# Yeang, Chen-Hsiang | Vingron, Martin | 1
# Dubs, Shelli | Zuo, Zhengping | 1
# Mazi\'{e}re, Pierre | Dongen, Stijn | 1
# Mazi\'{e}re, Pierre | Freilich, Shiri | 1
# Mazi\'{e}re, Pierre | Grocock, Russell | 1
# Cottret, Ludovic | Jourdan, Fabien | 1
# Cottret, Ludovic | Lacroix, Vincent | 1
# Cottret, Ludovic | Bourqui, Romain | 1
# Santamar\'ia, Rodrigo | Ther\'on, Roberto | 1
# Cohen, Robert | Eades, Peter | 1
# Tekin, Umut | Erdemir, Ural | 1
# Qian, Weihong | Wang, Guodong | 1
# Qian, Weihong | Sun, Jimeng | 1
# Qian, Weihong | Lin, Ching-Yung | 1
# Madden, Patrick | Madden, Brendan | 1
# Madden, Patrick | Dogrusoz, Ugur | 1
# Huyck, Matt | Wang, Yan | 1
# Huyck, Matt | Huang, Chia-Ling | 1
# Felmlee, Diane | Ma, Kwan-Liu | 1
# Felmlee, Diane | Muelder, Chris | 1
# Felmlee, Diane | Crnovrsanin, Tarik | 1
# Koren, Yehuda | Dwyer, Tim | 1
# Holten, Danny | Cornelissen, Bas | 1
# Streit, Marc | Stitz, Holger | 1
# Streit, Marc | Kashofer, Karl | 1
# Streit, Marc | Zatloukal, Kurt | 1
# Riche, N. | Westenberg, M.A. | 1
# Brunella, R | Gross, Markus | 1
# Kennedy, J.B. | Melville, A.G. | 1
# Karp, Peter | Paley, Suzanne | 1
# Czerwinski, Mary | Henry Riche, Nathalie | 1
# Czerwinski, Mary | Alper, Basak | 1
# Plaisant, Catherine | Dang, N. | 1
# Plaisant, Catherine | Aris, Aleks | 1
# McPherson, Jonathan | Ma, Kwan-Liu | 1
# Siderius, Marco | Klau, Gunnar | 1
# Siderius, Marco | Bucur, Cristina-Iulia | 1
# Siderius, Marco | Westenberg, Michel | 1
# Siderius, Marco | El-Kebir, Mohammed | 1
# Freilich, Shiri | Dongen, Stijn | 1
# Freilich, Shiri | Grocock, Russell | 1
# Bourqui, Romain | Sansen, Joris | 1
# Bourqui, Romain | Simonetto, Paolo | 1
# Zhao, Jian | Balakrishnan, Ravin | 1
# Zhao, Jian | Chevalier, Fanny | 1
# Xu, Dong | Kuchinsky, Allan | 1
# Xu, Dong | Zhang, Chao | 1
# Schroeder, Michael | Andreopoulos, Bill | 1
# AlTarawneh, Ragaad | Schultz, Johannes | 1
# AlTarawneh, Ragaad | Humayoun, Shah | 1
# Muelder, Chris | Crnovrsanin, Tarik | 1
# Verrier, Paul | Baumbach, Jan | 1
# Verrier, Paul | Rawlings, Chris | 1
# Verrier, Paul | Specht, Michael | 1
# Ma, Kwan-Liu | Crnovrsanin, Tarik | 1
# Prusis, Krisjanis | Freivalds, Karlis | 1
# Hagen, Hans | Zeckzer, Dirk | 1
# Sun, Jimeng | Wang, Guodong | 1
# Sun, Jimeng | Lin, Ching-Yung | 1
# Bork, Peer | Letunic, Ivica | 1
# Wang, Guodong | Lin, Ching-Yung | 1
# Alper, Basak | Henry Riche, Nathalie | 1
# Stolper, Charles | Stasko, John | 1
# Reichenbach, Andr{\'e} | Heine, Christian | 1
# Reichenbach, Andr{\'e} | Scheuermann, Gerik | 1
# Westenberg, Michel | Klau, Gunnar | 1
# Westenberg, Michel | Bucur, Cristina-Iulia | 1
# Westenberg, Michel | Kreveld, Marc | 1
# Westenberg, Michel | El-Kebir, Mohammed | 1
# Reitz, Florian | Pohl, Mathias | 1
# Madden, Brendan | Dogrusoz, Ugur | 1
# Schultz, Johannes | Humayoun, Shah | 1
# Bucur, Cristina-Iulia | Klau, Gunnar | 1
# Bucur, Cristina-Iulia | El-Kebir, Mohammed | 1
# Melancon, Guy | Jourdan, Fabien | 1
# Melancon, Guy | Pich, Christian | 1
# Melancon, Guy | Chiricota, Yves | 1
# Dwyer, Tim | Wybrow, Michael | 1
# Dwyer, Tim | Gange, Graeme | 1
# Rawlings, Chris | Baumbach, Jan | 1
# Rawlings, Chris | Specht, Michael | 1
# Chevalier, Fanny | Balakrishnan, Ravin | 1
# Dongen, Stijn | Grocock, Russell | 1
# Scheuermann, Gerik | Heine, Christian | 1
# Zhang, Chao | Kuchinsky, Allan | 1
# Aris, Aleks | Dang, N. | 1
# Kuntzer, Jan | Faber, Daniel | 1
# Kuntzer, Jan | Kaufmann, Michael | 1
# Baumbach, Jan | Specht, Michael | 1
# Faber, Daniel | Kaufmann, Michael | 1
# Chiricota, Yves | Jourdan, Fabien | 1
# Simonetto, Paolo | Jourdan, Fabien | 1
# Wang, Yan | Huang, Chia-Ling | 1
# El-Kebir, Mohammed | Klau, Gunnar | 1

# %%
import igraph

# %%
g2 = igraph.Graph.Adjacency((nx.to_numpy_matrix(G)).tolist())

# %%
g2.community_infomap()

# %%
# nx.write_pajek(G, 'coauthorship.net')

# %%
# # need to clean up the pajek file: only need, the number and name for the vertices
# with open('coauthorship.net', 'r') as f:
#     pjk_txt = f.readlines()
# this_line_is_vertex = False
# with open('coauthorship.net', 'w') as outf:
#     for line in pjk_txt:
#         if line[0] == '*':
#             if line[1].lower() == 'v':
#                 this_line_is_vertex = True
#             else:
#                 this_line_is_vertex = False
#         elif this_line_is_vertex:
#             line = line[:line.find(' 0.0')]
#             line = line + '\n'
#         outf.write(line)

# %%
with open('coauthorship.tree', 'r') as f:
    rows = []
    for line in f:
        if line[0] == '#':
            continue
        
        line = line.strip().split()
        author = line[2].strip('"')
        node = line[3]
        cl = line[0]
        flow = line[1]
        row = ( node, author, cl, flow )
        rows.append(row)

# %%
df = pd.DataFrame(rows, columns='node author cl flow'.split())

# %%
df = pd.read_csv('coauthorship.tree', skiprows=2, quotechar='"', delimiter=' ', names='cl flow author node'.split())

# %%
df['cl_bottom'] = df.cl.apply(lambda x: ':'.join(x.split(':')[:-1]))
df['cl_top'] = df.cl.apply(lambda x: x.split(':')[0])

# %%
df.set_index('author', inplace=True)

# %%
df
# Out:
#                                cl      flow  node cl_bottom cl_top
# author
# Weiskopf, Daniel          1:1:1:1  0.018467   145     1:1:1      1
# Vehlow, Corinna           1:1:1:2  0.014774   278     1:1:1      1
# Burch, Michael            1:1:1:3  0.011542   106     1:1:1      1
# Diehl, Stephan            1:1:1:4  0.010157   138     1:1:1      1
# Beck, Fabian              1:1:1:5  0.009234    80     1:1:1      1
# Schmauder, Hansj{{o}}rg   1:1:1:6  0.001385    14     1:1:1      1
# Fritz, Peter              1:1:1:7  0.001385    40     1:1:1      1
# Auw{a}rter, Patrick       1:1:1:8  0.001385   140     1:1:1      1
# Schmidt, Benjamin         1:1:1:9  0.000923    54     1:1:1      1
# Hlawatsch, Marcel        1:1:1:10  0.000923    55     1:1:1      1
# Petkov, Radoslav         1:1:1:11  0.000923   154     1:1:1      1
# Reinhardt, Thomas        1:1:1:12  0.000923   205     1:1:1      1
# Munz, Tanja              1:1:1:13  0.000923   348     1:1:1      1
# Hoferlin, Markus         1:1:1:14  0.000923   352     1:1:1      1
# Greilich, Martin         1:1:1:15  0.000923   447     1:1:1      1
# Theis, Fabian             1:1:2:1  0.005078    56     1:1:2      1
# Hasenauer, Jan            1:1:2:2  0.005078   105     1:1:2      1
# Kramer, Andrei            1:1:2:3  0.003693    15     1:1:2      1
# Timmer, Jens              1:1:2:4  0.003693    20     1:1:2      1
# Radde, Nicole             1:1:2:5  0.003693   181     1:1:2      1
# Raue, Andreas             1:1:2:6  0.003693   200     1:1:2      1
# Hug, Sabine               1:1:2:7  0.003693   313     1:1:2      1
# Kao, David                1:1:3:1  0.002308    50     1:1:3      1
# Bristow, Michael          1:1:3:2  0.002308   144     1:1:3      1
# G{o}rg, Carsten           1:1:3:3  0.002308   211     1:1:3      1
# Hunter, Lawrence          1:1:3:4  0.002308   457     1:1:3      1
# Reitz, Florian            1:1:4:1  0.000923   376     1:1:4      1
# Pohl, Mathias             1:1:4:2  0.000923   437     1:1:4      1
# Dwyer, Tim                  1:2:1  0.007387   388       1:2      1
# Marriott, Kim               1:2:2  0.006925   298       1:2      1
# ...                           ...       ...   ...       ...    ...
# Six, Janet                   54:2  0.000462   265        54     54
# Mothe, Josiane               55:1  0.000462   142        55     55
# Dkaki, Taoufiq               55:2  0.000462   195        55     55
# Noack, Andreas               56:1  0.000462   161        56     56
# Lewerentz, Claus             56:2  0.000462   414        56     56
# Peng, Wu                     57:1  0.000462   168        57     57
# Si-Kun, Li                   57:2  0.000462   356        57     57
# Kottler, Stephan             58:1  0.000462   173        58     58
# Lehmann, Katharina           58:2  0.000462   363        58     58
# Wagner, Dorothea             59:1  0.000462   184        59     59
# Brandes, Ulrik               59:2  0.000462   326        59     59
# Miyamoto, Isao               60:1  0.000462   216        60     60
# Wang, Xiaobo                 60:2  0.000462   408        60     60
# Jansson, Andreas             61:1  0.000462   244        61     61
# Jirstrand, Mats              61:2  0.000462   415        61     61
# Kumar, Gautam                62:1  0.000462   252        62     62
# Garland, Michael             62:2  0.000462   307        62     62
# Davis, Darcy                 63:1  0.000462   276        63     63
# Chawla, Nitesh               63:2  0.000462   335        63     63
# Yeang, Chen-Hsiang           64:1  0.000462   305        64     64
# Vingron, Martin              64:2  0.000462   320        64     64
# Santamar\'ia, Rodrigo        65:1  0.000462   312        65     65
# Ther\'on, Roberto            65:2  0.000462   341        65     65
# Karp, Peter                  66:1  0.000462   333        66     66
# Paley, Suzanne               66:2  0.000462   456        66     66
# Raitner, Marcus              67:1  0.000000    76        67     67
# Forster, Michael             68:1  0.000000    87        68     68
# Kitano, Hiroaki              69:1  0.000000   182        69     69
# Dekker, Anthony              70:1  0.000000   217        70     70
# Paris, Gilles                71:1  0.000000   432        71     71
#
# [457 rows x 5 columns]

# %%
from collections import Counter
c = Counter()
for comp in components:
    c[len(comp)] += 1

# %%
c
# Out:
# Counter({1: 5,
#          2: 24,
#          3: 13,
#          4: 3,
#          5: 5,
#          6: 2,
#          7: 6,
#          9: 4,
#          10: 2,
#          11: 1,
#          12: 1,
#          14: 1,
#          23: 1,
#          31: 1,
#          127: 1})

# %%
nx.set_node_attributes(G, 'cl_bottom', df.cl_bottom.to_dict())
nx.set_node_attributes(G, 'cl_top', df.cl_top.to_dict())
nx.set_node_attributes(G, 'flow', df.flow.to_dict())

# %%
G.nodes(data=True)
# Out:
# [('Wu, Jie',
#   {'author_name': 'Wu, Jie',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{VisANT}: data-integrating visual framework for biological networks and modules',
#      'year': u'2005'}]}),
#  ('Smith, Adam',
#   {'author_name': 'Smith, Adam',
#    'cl_bottom': '20',
#    'cl_top': '20',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{RuleBender}: integrated modeling, simulation and visualization for rule-based intracellular biochemistry',
#      'year': u'2012'}]}),
#  ('Nakazawa, Rina',
#   {'author_name': 'Nakazawa, Rina',
#    'cl_bottom': '2:1:2:2',
#    'cl_top': '2',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Integrated Visualization of Gene Network and Ontology Applying a Hierarchical Graph Visualization Technique',
#      'year': u'2012'},
#     {'title': u'A Visualization of Research Papers Based on the Topics and Citation Network',
#      'year': u'2015'}]}),
#  ('Hasco{e}t, Mountaz',
#   {'author_name': 'Hasco{e}t, Mountaz',
#    'cl_bottom': '45',
#    'cl_top': '45',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Interactive Graph Matching and Visual Comparison of Graphs and Clustered Graphs',
#      'year': u'2012'}]}),
#  ('Sangal, Neeraj',
#   {'author_name': 'Sangal, Neeraj',
#    'cl_bottom': '27',
#    'cl_top': '27',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Using Dependency Models to Manage Complex Software Architecture',
#      'year': u'2005'}]}),
#  ('Elmqvist, Niklas',
#   {'author_name': 'Elmqvist, Niklas',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{CiteWiz}: a tool for the visualization of scientific citation networks',
#      'year': u'2007'},
#     {'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'}]}),
#  ('Zimmer, Bj{{o}}rn',
#   {'author_name': 'Zimmer, Bj{{o}}rn',
#    'cl_bottom': '1:3',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Multivariate Network Exploration with JauntyNets',
#      'year': u'2013'},
#     {'title': u'Visual Exploration of Relationships between Document Clusters',
#      'year': u'2014'}]}),
#  ('Philippi, Stephan',
#   {'author_name': 'Philippi, Stephan',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  ('Vernik, Rudi',
#   {'author_name': 'Vernik, Rudi',
#    'cl_bottom': '30',
#    'cl_top': '30',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Information Visualisation Using Composable Layouts and Visual Sets',
#      'year': u'2001'}]}),
#  ('Goesmann, Alexander',
#   {'author_name': 'Goesmann, Alexander',
#    'cl_bottom': '21',
#    'cl_top': '21',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{PathFinder}: reconstruction and dynamic visualization of metabolic pathways',
#      'year': u'2002'}]}),
#  ('Tanaka, Jiro',
#   {'author_name': 'Tanaka, Jiro',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.00184672,
#    'papers': [{'title': u'A Multiple-Aspects Visualization Tool for Exploring Social Networks',
#      'year': u'2009'},
#     {'title': u'Drawing Clustered Bipartite Graphs in Multi-circular Style',
#      'year': u'2010'}]}),
#  ('Mary, Patrick',
#   {'author_name': 'Mary, Patrick',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'How to Draw Clustered Weighted Graphs using a Multilevel Force-Directed Graph Drawing Algorithm',
#      'year': u'2007'},
#     {'title': u'Metabolic network visualization eliminating node redundance and preserving metabolic pathways',
#      'year': u'2007'}]}),
#  ('Nguyen, QuanHoang',
#   {'author_name': 'Nguyen, QuanHoang',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Visual Analysis of History of World Cup: A Dynamic Network with Dynamic Hierarchy and Geographic Clustering',
#      'year': u'2010'}]}),
#  ('Schmauder, Hansj{{o}}rg',
#   {'author_name': 'Schmauder, Hansj{{o}}rg',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Radial Layered Matrix Visualization of Dynamic Graphs',
#      'year': u'2013'}]}),
#  ('Kramer, Andrei',
#   {'author_name': 'Kramer, Andrei',
#    'cl_bottom': '1:1:2',
#    'cl_top': '1',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'}]}),
#  ('Jackson, Daniel',
#   {'author_name': 'Jackson, Daniel',
#    'cl_bottom': '27',
#    'cl_top': '27',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Using Dependency Models to Manage Complex Software Architecture',
#      'year': u'2005'}]}),
#  ('Mellor, Joe',
#   {'author_name': 'Mellor, Joe',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{VisANT}: data-integrating visual framework for biological networks and modules',
#      'year': u'2005'}]}),
#  ('Sagot, Marie-France',
#   {'author_name': 'Sagot, Marie-France',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Metabolic network visualization eliminating node redundance and preserving metabolic pathways',
#      'year': u'2007'}]}),
#  ('Roseman, Mark',
#   {'author_name': 'Roseman, Mark',
#    'cl_bottom': '13',
#    'cl_top': '13',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Navigating Hierarchically Clustered Networks Through Fisheye and Full-zoom Methods',
#      'year': u'1996'}]}),
#  ('Timmer, Jens',
#   {'author_name': 'Timmer, Jens',
#    'cl_bottom': '1:1:2',
#    'cl_top': '1',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'}]}),
#  ('Eliassi-Rad, Tina',
#   {'author_name': 'Eliassi-Rad, Tina',
#    'cl_bottom': '2:1:2:1',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visual Analysis of Large Heterogeneous Social Networks by Semantic and Structural Abstraction',
#      'year': u'2006'}]}),
#  ('Krishnan, Neeraj',
#   {'author_name': 'Krishnan, Neeraj',
#    'cl_bottom': '2:2:3',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{ASK-GraphView}: A Large Scale Graph Visualization System',
#      'year': u'2006'}]}),
#  ('Rucevskis, Peteris',
#   {'author_name': 'Rucevskis, Peteris',
#    'cl_bottom': '23',
#    'cl_top': '23',
#    'flow': 0.00184672,
#    'papers': [{'title': u'An Inverse Distance-based Potential Field Function for Overlapping Point Set Visualization.',
#      'year': u'2014'}]}),
#  ('Kalkofen, Denis',
#   {'author_name': 'Kalkofen, Denis',
#    'cl_bottom': '7:1',
#    'cl_top': '7',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{enRoute:} dynamic path extraction from biological pathway maps for exploring heterogeneous experimental datasets',
#      'year': u'2013'}]}),
#  ("Rufiange, S{\\'e}bastien",
#   {'author_name': "Rufiange, S{\\'e}bastien",
#    'cl_bottom': '4:4',
#    'cl_top': '4',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{TreeMatrix}: A hybrid visualization of compound graphs',
#      'year': u'2012'}]}),
#  ('Termeer, Maurice',
#   {'author_name': 'Termeer, Maurice',
#    'cl_bottom': '11:2',
#    'cl_top': '11',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Visual Exploration of Combined Architectural and Metric Information',
#      'year': u'2005'}]}),
#  ('Ho, Joshua',
#   {'author_name': 'Ho, Joshua',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Drawing Clustered Graphs in Three Dimensions',
#      'year': u'2006'}]}),
#  ("Gilbert, Fr\\'ed\\'eric",
#   {'author_name': "Gilbert, Fr\\'ed\\'eric",
#    'cl_bottom': '2:1:1:3',
#    'cl_top': '2',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Communities and hierarchical structures in dynamic social networks: analysis and visualization',
#      'year': u'2011'}]}),
#  ('Taubert, Jan',
#   {'author_name': 'Taubert, Jan',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  ('Breitkreutz, Bobby-Joe',
#   {'author_name': 'Breitkreutz, Bobby-Joe',
#    'cl_bottom': '31',
#    'cl_top': '31',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Osprey: a network visualization system.',
#      'year': u'2003'}]}),
#  ('Lenhof, Hans-Peter',
#   {'author_name': 'Lenhof, Hans-Peter',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  ('Zachariah, R.',
#   {'author_name': 'Zachariah, R.',
#    'cl_bottom': '4:2',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Group-in-a-Box Meta-Layouts for Topological Clusters and Attribute-Based Groups: Space-Efficient Visualizations of Network Communities and Their Ties',
#      'year': u'2014'}]}),
#  ('Krause, Alexander',
#   {'author_name': 'Krause, Alexander',
#    'cl_bottom': '32',
#    'cl_top': '32',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Hierarchical Software Landscape Visualization for System Comprehension: A Controlled Experiment',
#      'year': u'2015'}]}),
#  ('Kruijff, Ernst',
#   {'author_name': 'Kruijff, Ernst',
#    'cl_bottom': '7:1',
#    'cl_top': '7',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Caleydo: Design and Evaluation of a Visual Analysis Framework for Gene Expression Data in its Biological Context',
#      'year': u'2010'}]}),
#  ('Faith, Joe',
#   {'author_name': 'Faith, Joe',
#    'cl_bottom': '46',
#    'cl_top': '46',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Node-attribute Graph Layout for Small-World Networks',
#      'year': u'2011'}]}),
#  ('Yan, Youliang',
#   {'author_name': 'Yan, Youliang',
#    'cl_bottom': '3:4',
#    'cl_top': '3',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Interactive visual summary of major communities in a large network',
#      'year': u'2015'}]}),
#  ('Bartram, Lyn',
#   {'author_name': 'Bartram, Lyn',
#    'cl_bottom': '13',
#    'cl_top': '13',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Navigating Hierarchically Clustered Networks Through Fisheye and Full-zoom Methods',
#      'year': u'1996'}]}),
#  ('Wu, Yanhong',
#   {'author_name': 'Wu, Yanhong',
#    'cl_bottom': '3:4',
#    'cl_top': '3',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Interactive visual summary of major communities in a large network',
#      'year': u'2015'}]}),
#  ('Greenberg, Saul',
#   {'author_name': 'Greenberg, Saul',
#    'cl_bottom': '13',
#    'cl_top': '13',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Navigating Hierarchically Clustered Networks Through Fisheye and Full-zoom Methods',
#      'year': u'1996'}]}),
#  ('Fritz, Peter',
#   {'author_name': 'Fritz, Peter',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{TimeSpiderTrees}: A Novel Visual Metaphor for Dynamic Compound Graphs',
#      'year': u'2010'}]}),
#  ('Munzner, Tamara',
#   {'author_name': 'Munzner, Tamara',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0069252100000000002,
#    'papers': [{'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'{TopoLayout}: Multilevel Graph Layout by Topological Features',
#      'year': u'2007'},
#     {'title': u'{GrouseFlocks}: Steerable Exploration of Graph Hierarchy Space',
#      'year': u'2008'},
#     {'title': u'{TugGraph}: Path-preserving hierarchies for browsing proximity and paths in graphs',
#      'year': u'2009'},
#     {'title': u'Tugging Graphs Faster: Efficiently Modifying Path-Preserving Hierarchies for Browsing Paths',
#      'year': u'2011'},
#     {'title': u'Cerebral: Visualizing Multiple Experimental Conditions on a Graph with Biological Context',
#      'year': u'2008'},
#     {'title': u'{Detangler}: Visual Analytics for Multiplex Networks',
#      'year': u'2015'}]}),
#  ('Kalinowski, Jorn',
#   {'author_name': 'Kalinowski, Jorn',
#    'cl_bottom': '21',
#    'cl_top': '21',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{PathFinder}: reconstruction and dynamic visualization of metabolic pathways',
#      'year': u'2002'}]}),
#  ('Chaturvedi, S.',
#   {'author_name': 'Chaturvedi, S.',
#    'cl_bottom': '4:2',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Group-in-a-Box Meta-Layouts for Topological Clusters and Attribute-Based Groups: Space-Efficient Visualizations of Network Communities and Their Ties',
#      'year': u'2014'}]}),
#  ('Haubrock, Martin',
#   {'author_name': 'Haubrock, Martin',
#    'cl_bottom': '21',
#    'cl_top': '21',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{PathFinder}: reconstruction and dynamic visualization of metabolic pathways',
#      'year': u'2002'}]}),
#  ('Auber, David',
#   {'author_name': 'Auber, David',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0124654,
#    'papers': [{'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'{TopoLayout}: Multilevel Graph Layout by Topological Features',
#      'year': u'2007'},
#     {'title': u'{GrouseFlocks}: Steerable Exploration of Graph Hierarchy Space',
#      'year': u'2008'},
#     {'title': u'{TugGraph}: Path-preserving hierarchies for browsing proximity and paths in graphs',
#      'year': u'2009'},
#     {'title': u'Tugging Graphs Faster: Efficiently Modifying Path-Preserving Hierarchies for Browsing Paths',
#      'year': u'2011'},
#     {'title': u'Multiscale visualization of small world networks',
#      'year': u'2003'},
#     {'title': u'{Tulip}: A huge graph visualization framework',
#      'year': u'2003'},
#     {'title': u'Metabolic network visualization using constraint planar graph drawing algorithm',
#      'year': u'2006'},
#     {'title': u'How to Draw Clustered Weighted Graphs using a Multilevel Force-Directed Graph Drawing Algorithm',
#      'year': u'2007'},
#     {'title': u'Metabolic network visualization eliminating node redundance and preserving metabolic pathways',
#      'year': u'2007'},
#     {'title': u'{Adjasankey}: Visualization of huge hierarchical weighted and directed graphs',
#      'year': u'2015'}]}),
#  ('Du, Xiaolin',
#   {'author_name': 'Du, Xiaolin',
#    'cl_bottom': '17',
#    'cl_top': '17',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Multi-opinion Ring: visualizing and predicting multiple opinion orientations in online social media',
#      'year': u'2015'},
#     {'title': u'{OpinionRings}: Inferring and visualizing the opinion tendency of socially connected users',
#      'year': u'2015'}]}),
#  ('Nguyen, Quang',
#   {'author_name': 'Nguyen, Quang',
#    'cl_bottom': '16:2',
#    'cl_top': '16',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Drawing Large Weighted Graphs Using Clustered Force-Directed Algorithm',
#      'year': u'2014'},
#     {'title': u'A Space Efficient Clustered Visualization of Large Graphs',
#      'year': u'2007'},
#     {'title': u'Navigating Large Clustered Graphs with Triple-Layer Display',
#      'year': u'2007'}]}),
#  ('Niermann, Peter',
#   {'author_name': 'Niermann, Peter',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  ('Zhou, Qi',
#   {'author_name': 'Zhou, Qi',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Drawing Semi-bipartite Graphs in Anchor+Matrix Style',
#      'year': u'2011'}]}),
#  ('Kao, David',
#   {'author_name': 'Kao, David',
#    'cl_bottom': '1:1:3',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual analysis of biological data-knowledge networks',
#      'year': u'2015'}]}),
#  ('Gansner, Emden',
#   {'author_name': 'Gansner, Emden',
#    'cl_bottom': '2:2:1',
#    'cl_top': '2',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Improved Circular Layouts', 'year': u'2007'},
#     {'title': u'{GMap}: Visualizing graphs and clusters as maps',
#      'year': u'2010'},
#     {'title': u'Visualizing Graphs and Clusters as Maps', 'year': u'2010'}]}),
#  ('Liu, Shixia',
#   {'author_name': 'Liu, Shixia',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.010156999999999999,
#    'papers': [{'title': u'{FacetAtlas}: Multifaceted Visualization for Rich Text Corpora',
#      'year': u'2010'},
#     {'title': u'{TopicPanorama}: a full picture of relevant topics',
#      'year': u'2014'},
#     {'title': u'{HiMap}: Adaptive visualization of large-scale online social networks',
#      'year': u'2009'},
#     {'title': u'{PIWI}: Visually Exploring Graphs Based on Their Community Structure',
#      'year': u'2013'}]}),
#  ('Thornton, Janet',
#   {'author_name': 'Thornton, Janet',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'}]}),
#  ('Schmidt, Benjamin',
#   {'author_name': 'Schmidt, Benjamin',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'A Matrix-Based Visualization for Exploring Dynamic Compound Digraphs',
#      'year': u'2013'}]}),
#  ('Hlawatsch, Marcel',
#   {'author_name': 'Hlawatsch, Marcel',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visual Adjacency Lists for Dynamic Graphs',
#      'year': u'2014'}]}),
#  ('Theis, Fabian',
#   {'author_name': 'Theis, Fabian',
#    'cl_bottom': '1:1:2',
#    'cl_top': '1',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Visualizing edge-edge relations in graphs',
#      'year': u'2013'},
#     {'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'}]}),
#  ('Yuan, Xiaoru',
#   {'author_name': 'Yuan, Xiaoru',
#    'cl_bottom': '3:3',
#    'cl_top': '3',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{PIWI}: Visually Exploring Graphs Based on Their Community Structure',
#      'year': u'2013'}]}),
#  ('Xu, Panpan',
#   {'author_name': 'Xu, Panpan',
#    'cl_bottom': '3:2',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Visual Analysis of Set Relations in a Graph',
#      'year': u'2013'},
#     {'title': u'Visualization of bipartite relations between graphs and sets',
#      'year': u'2015'}]}),
#  ('Schulz, Hans-J{o}rg',
#   {'author_name': 'Schulz, Hans-J{o}rg',
#    'cl_bottom': '2:2:2',
#    'cl_top': '2',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual Analysis of Bipartite Biological Networks',
#      'year': u'2008'},
#     {'title': u'{Honeycomb}: Visual Analysis of Large Scale Social Networks',
#      'year': u'2009'}]}),
#  ('Royer, Loic',
#   {'author_name': 'Royer, Loic',
#    'cl_bottom': '28',
#    'cl_top': '28',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Unraveling Protein Networks with Power Graph Analysis',
#      'year': u'2008'}]}),
#  ('Buzluca, Feza',
#   {'author_name': 'Buzluca, Feza',
#    'cl_bottom': '33',
#    'cl_top': '33',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{E-Quality}: A graph based object oriented software quality visualization tool',
#      'year': u'2011'}]}),
#  ('Schaffer, Doug',
#   {'author_name': 'Schaffer, Doug',
#    'cl_bottom': '13',
#    'cl_top': '13',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Navigating Hierarchically Clustered Networks Through Fisheye and Full-zoom Methods',
#      'year': u'1996'}]}),
#  ('Grilli, Luca',
#   {'author_name': 'Grilli, Luca',
#    'cl_bottom': '10',
#    'cl_top': '10',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Graph Visualization Techniques for Web Clustering Engines',
#      'year': u'2007'}]}),
#  ('Tan, Li',
#   {'author_name': 'Tan, Li',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'{HiMap}: Adaptive visualization of large-scale online social networks',
#      'year': u'2009'}]}),
#  ('Stark, Chris',
#   {'author_name': 'Stark, Chris',
#    'cl_bottom': '31',
#    'cl_top': '31',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Osprey: a network visualization system.',
#      'year': u'2003'}]}),
#  ('Chau, Duen',
#   {'author_name': 'Chau, Duen',
#    'cl_bottom': '15',
#    'cl_top': '15',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{GLO-STIX}: Graph-Level Operations for Specifying Techniques and Interactive eXploration',
#      'year': u'2014'}]}),
#  ('Lin, Yu-Ru',
#   {'author_name': 'Lin, Yu-Ru',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'{FacetAtlas}: Multifaceted Visualization for Rich Text Corpora',
#      'year': u'2010'},
#     {'title': u'{g-Miner}: Interactive Visual Group Mining on Multivariate Graphs',
#      'year': u'2015'}]}),
#  ('Klukas, Christian',
#   {'author_name': 'Klukas, Christian',
#    'cl_bottom': '1:5',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{VANTED}: A system for advanced data analysis and visualization in the context of biological networks',
#      'year': u'2006'},
#     {'title': u'Dynamic exploration and editing of KEGG pathway diagrams',
#      'year': u'2007'}]}),
#  ('Barsky, Aaron',
#   {'author_name': 'Barsky, Aaron',
#    'cl_bottom': '2:1:1:4',
#    'cl_top': '2',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Cerebral: Visualizing Multiple Experimental Conditions on a Graph with Biological Context',
#      'year': u'2008'}]}),
#  ('K{o}hler, Jacob',
#   {'author_name': 'K{o}hler, Jacob',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  ('Wang, Taowei',
#   {'author_name': 'Wang, Taowei',
#    'cl_bottom': '4:3',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Overlaying Graph Links on Treemaps',
#      'year': u'2003'}]}),
#  ('Saito, Takafumi',
#   {'author_name': 'Saito, Takafumi',
#    'cl_bottom': '2:1:2:2',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'A Visualization of Research Papers Based on the Topics and Citation Network',
#      'year': u'2015'}]}),
#  ('Jordan, Ev',
#   {'author_name': 'Jordan, Ev',
#    'cl_bottom': '27',
#    'cl_top': '27',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Using Dependency Models to Manage Complex Software Architecture',
#      'year': u'2005'}]}),
#  ('Kasyanov, Victor',
#   {'author_name': 'Kasyanov, Victor',
#    'cl_bottom': '47',
#    'cl_top': '47',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Higres - Visualization System for Clustered Graphs and Graph Algorithms',
#      'year': u'1999'}]}),
#  ('Lange, Christian',
#   {'author_name': 'Lange, Christian',
#    'cl_bottom': '11:2',
#    'cl_top': '11',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Visual Exploration of Combined Architectural and Metric Information',
#      'year': u'2005'}]}),
#  ('Raitner, Marcus',
#   {'author_name': 'Raitner, Marcus',
#    'cl_bottom': '67',
#    'cl_top': '67',
#    'flow': 0.0,
#    'papers': [{'title': u'Visual Navigation of Compound Graphs',
#      'year': u'2005'}]}),
#  ('Kahng, Minsuk',
#   {'author_name': 'Kahng, Minsuk',
#    'cl_bottom': '15',
#    'cl_top': '15',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{GLO-STIX}: Graph-Level Operations for Specifying Techniques and Interactive eXploration',
#      'year': u'2014'}]}),
#  ('Zhang, Kang',
#   {'author_name': 'Zhang, Kang',
#    'cl_bottom': '34',
#    'cl_top': '34',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualization of Clustered Directed Acyclic Graphs without Node Overlapping',
#      'year': u'2008'}]}),
#  ('Sun, Yao',
#   {'author_name': 'Sun, Yao',
#    'cl_bottom': '20',
#    'cl_top': '20',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{RuleBender}: integrated modeling, simulation and visualization for rule-based intracellular biochemistry',
#      'year': u'2012'}]}),
#  ('Beck, Fabian',
#   {'author_name': 'Beck, Fabian',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0092336099999999997,
#    'papers': [{'title': u'Finding Structures in Multi-Type Code Couplings with Node-Link and Matrix Visualizations',
#      'year': u'2013'},
#     {'title': u'Visually Exploring Multi-Dimensional Code Couplings',
#      'year': u'2011'},
#     {'title': u'Rapid Serial Visual Presentation in Dynamic Graph Visualization',
#      'year': u'2012'},
#     {'title': u'Visual Comparison of Software Architectures', 'year': u'2013'},
#     {'title': u'{TimeSpiderTrees}: A Novel Visual Metaphor for Dynamic Compound Graphs',
#      'year': u'2010'},
#     {'title': u'Parallel Edge Splatting for Scalable Dynamic Graph Visualization',
#      'year': u'2011'},
#     {'title': u'Visualizing the Evolution of Communities in Dynamic Graphs',
#      'year': u'2015'}]}),
#  ('Saga, Ryosuke',
#   {'author_name': 'Saga, Ryosuke',
#    'cl_bottom': '48',
#    'cl_top': '48',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Edge Bundling in Multi-attributed Graphs',
#      'year': u'2015'}]}),
#  ('Paduano, Francesco',
#   {'author_name': 'Paduano, Francesco',
#    'cl_bottom': '49',
#    'cl_top': '49',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{Extended LineSets}: a visualization technique for the interactive inspection of biological pathways',
#      'year': u'2015'}]}),
#  ('Huang, Xiaohui',
#   {'author_name': 'Huang, Xiaohui',
#    'cl_bottom': '17',
#    'cl_top': '17',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Multi-opinion Ring: visualizing and predicting multiple opinion orientations in online social media',
#      'year': u'2015'}]}),
#  ('Heer, Jeffrey',
#   {'author_name': 'Heer, Jeffrey',
#    'cl_bottom': '50',
#    'cl_top': '50',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{Vizster}: visualizing online social networks',
#      'year': u'2005'}]}),
#  ('Shi, Lei',
#   {'author_name': 'Shi, Lei',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'{HiMap}: Adaptive visualization of large-scale online social networks',
#      'year': u'2009'}]}),
#  ('Faris, Robert',
#   {'author_name': 'Faris, Robert',
#    'cl_bottom': '2:1:2:1',
#    'cl_top': '2',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Visualization Techniques for Categorical Analysis of Social Networks with Multiple Edge Sets',
#      'year': u'2014'}]}),
#  ('Forster, Michael',
#   {'author_name': 'Forster, Michael',
#    'cl_bottom': '68',
#    'cl_top': '68',
#    'flow': 0.0,
#    'papers': [{'title': u'Applying Crossing Reduction Strategies to Layered Compound Graphs',
#      'year': u'2002'}]}),
#  ('Quigley, Aaron',
#   {'author_name': 'Quigley, Aaron',
#    'cl_bottom': '16:1',
#    'cl_top': '16',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{FADE:} Graph Drawing, Clustering, and Visual Abstraction',
#      'year': u'2001'}]}),
#  ('Archambault, Daniel',
#   {'author_name': 'Archambault, Daniel',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0055401699999999996,
#    'papers': [{'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'{TopoLayout}: Multilevel Graph Layout by Topological Features',
#      'year': u'2007'},
#     {'title': u'{GrouseFlocks}: Steerable Exploration of Graph Hierarchy Space',
#      'year': u'2008'},
#     {'title': u'{TugGraph}: Path-preserving hierarchies for browsing proximity and paths in graphs',
#      'year': u'2009'},
#     {'title': u'Tugging Graphs Faster: Efficiently Modifying Path-Preserving Hierarchies for Browsing Paths',
#      'year': u'2011'},
#     {'title': u'The Readability of Path-Preserving Clusterings of Graphs',
#      'year': u'2010'}]}),
#  ('Kumar, Pushpa',
#   {'author_name': 'Kumar, Pushpa',
#    'cl_bottom': '34',
#    'cl_top': '34',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualization of Clustered Directed Acyclic Graphs without Node Overlapping',
#      'year': u'2008'}]}),
#  ('Civril, Ali',
#   {'author_name': 'Civril, Ali',
#    'cl_bottom': '18',
#    'cl_top': '18',
#    'flow': 0.00184672,
#    'papers': [{'title': u'A Compound Graph Layout Algorithm for Biological Pathways',
#      'year': u'2005'}]}),
#  ('Fischer, Michael',
#   {'author_name': 'Fischer, Michael',
#    'cl_bottom': '26',
#    'cl_top': '26',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{EvoLens}: lens-view visualizations of evolution data',
#      'year': u'2005'}]}),
#  ('Wang, Eric',
#   {'author_name': 'Wang, Eric',
#    'cl_bottom': '51',
#    'cl_top': '51',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'A New Graph Drawing Scheme for Social Network',
#      'year': u'2014'}]}),
#  ('Bach, Benjamin',
#   {'author_name': 'Bach, Benjamin',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{GraphDiaries}: Animated Transitions and Temporal Navigation for Dynamic Networks',
#      'year': u'2014'}]}),
#  ('Zhou, Hong',
#   {'author_name': 'Zhou, Hong',
#    'cl_bottom': '3:2',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Visual Analysis of Set Relations in a Graph',
#      'year': u'2013'},
#     {'title': u'Visualization of bipartite relations between graphs and sets',
#      'year': u'2015'}]}),
#  ('Sallaberry, Arnaud',
#   {'author_name': 'Sallaberry, Arnaud',
#    'cl_bottom': '2:1:1:2',
#    'cl_top': '2',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Interactive Visualization and Navigation of Web Search Results Revealing Community Structures and Bridges',
#      'year': u'2010'},
#     {'title': u'Clustering, Visualizing, and Navigating for Large Dynamic Graphs',
#      'year': u'2013'}]}),
#  ('Liu, Qing',
#   {'author_name': 'Liu, Qing',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Semi-bipartite Graph Visualization for Gene Ontology Networks',
#      'year': u'2010'}]}),
#  ('Collins, Christopher',
#   {'author_name': 'Collins, Christopher',
#    'cl_bottom': '24:1',
#    'cl_top': '24',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{VisLink}: Revealing Relationships Amongst Visualizations',
#      'year': u'2007'},
#     {'title': u'Interactive Exploration of Implicit and Explicit Relations in Faceted Datasets',
#      'year': u'2013'}]}),
#  ('Fagnan, Justin',
#   {'author_name': 'Fagnan, Justin',
#    'cl_bottom': '35',
#    'cl_top': '35',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualizing community centric network layouts',
#      'year': u'2012'}]}),
#  ('Marai, G.',
#   {'author_name': 'Marai, G.',
#    'cl_bottom': '20',
#    'cl_top': '20',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{RuleBender}: integrated modeling, simulation and visualization for rule-based intracellular biochemistry',
#      'year': u'2012'}]}),
#  ('Hong, Seok-Hee',
#   {'author_name': 'Hong, Seok-Hee',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Visual Analysis of History of World Cup: A Dynamic Network with Dynamic Hierarchy and Geographic Clustering',
#      'year': u'2010'},
#     {'title': u'Drawing Clustered Graphs in Three Dimensions',
#      'year': u'2006'},
#     {'title': u'Drawing planar clustered graphs in 2.5 dimensions',
#      'year': u'2007'},
#     {'title': u'{MultiStory}: Visual analytics of dynamic multi-relational networks',
#      'year': u'2015'},
#     {'title': u'Semi-bipartite Graph Visualization for Gene Ontology Networks',
#      'year': u'2010'}]}),
#  ('Queyroi, Francois',
#   {'author_name': 'Queyroi, Francois',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualizing Patterns in Node-link Diagrams',
#      'year': u'2012'}]}),
#  ('Goebel, Randy',
#   {'author_name': 'Goebel, Randy',
#    'cl_bottom': '35',
#    'cl_top': '35',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualizing community centric network layouts',
#      'year': u'2012'}]}),
#  ('Palladino, Pietro',
#   {'author_name': 'Palladino, Pietro',
#    'cl_bottom': '10',
#    'cl_top': '10',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'An advanced network visualization system for financial crime detection',
#      'year': u'2011'},
#     {'title': u'Visual Analysis of One-to-Many Matched Graphs',
#      'year': u'2009'}]}),
#  ('Hasenauer, Jan',
#   {'author_name': 'Hasenauer, Jan',
#    'cl_bottom': '1:1:2',
#    'cl_top': '1',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Visualizing edge-edge relations in graphs',
#      'year': u'2013'},
#     {'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'}]}),
#  ('Burch, Michael',
#   {'author_name': 'Burch, Michael',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.011542,
#    'papers': [{'title': u'Rapid Serial Visual Presentation in Dynamic Graph Visualization',
#      'year': u'2012'},
#     {'title': u'{TimeRadarTrees}: Visualizing Dynamic Compound Digraphs',
#      'year': u'2008'},
#     {'title': u'{TimeSpiderTrees}: A Novel Visual Metaphor for Dynamic Compound Graphs',
#      'year': u'2010'},
#     {'title': u'Parallel Edge Splatting for Scalable Dynamic Graph Visualization',
#      'year': u'2011'},
#     {'title': u'Layered {TimeRadarTrees}', 'year': u'2011'},
#     {'title': u'A Matrix-Based Visualization for Exploring Dynamic Compound Digraphs',
#      'year': u'2013'},
#     {'title': u'Edge-Stacked Timelines for Visualizing Dynamic Weighted Digraphs',
#      'year': u'2015'},
#     {'title': u'Visualizing the Evolution of Compound Digraphs with {TimeArcTrees}',
#      'year': u'2009'},
#     {'title': u'Visual Adjacency Lists for Dynamic Graphs', 'year': u'2014'},
#     {'title': u'Radial Layered Matrix Visualization of Dynamic Graphs',
#      'year': u'2013'}]}),
#  ('Gibson, Helen',
#   {'author_name': 'Gibson, Helen',
#    'cl_bottom': '46',
#    'cl_top': '46',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Node-attribute Graph Layout for Small-World Networks',
#      'year': u'2011'}]}),
#  ('Krebs, Valdis',
#   {'author_name': 'Krebs, Valdis',
#    'cl_bottom': '23',
#    'cl_top': '23',
#    'flow': 0.00184672,
#    'papers': [{'title': u'An Inverse Distance-based Potential Field Function for Overlapping Point Set Visualization.',
#      'year': u'2014'}]}),
#  ('Yoghourdjian, Vahan',
#   {'author_name': 'Yoghourdjian, Vahan',
#    'cl_bottom': '1:2',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'High-Quality Ultra-Compact Grid Layout of Grouped Networks',
#      'year': u'2015'}]}),
#  ('Paulovich, Fernando',
#   {'author_name': 'Paulovich, Fernando',
#    'cl_bottom': '11:1',
#    'cl_top': '11',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Skeleton-Based Edge Bundling for Graph Visualization',
#      'year': u'2011'}]}),
#  ('Gratzl, Samuel',
#   {'author_name': 'Gratzl, Samuel',
#    'cl_bottom': '7:2',
#    'cl_top': '7',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{CloudGazer}: A divide-and-conquer approach to monitoring and optimizing cloud-based networks',
#      'year': u'2015'}]}),
#  ('Liu, Yujie',
#   {'author_name': 'Liu, Yujie',
#    'cl_bottom': '3:3',
#    'cl_top': '3',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{PIWI}: Visually Exploring Graphs Based on Their Community Structure',
#      'year': u'2013'}]}),
#  ('Rusu, Adrian',
#   {'author_name': 'Rusu, Adrian',
#    'cl_bottom': '2:2:5',
#    'cl_top': '2',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'How to Display Group Information on Node-Link Diagrams: an Evaluation',
#      'year': u'2014'}]}),
#  ('Chang, Chin-Lung',
#   {'author_name': 'Chang, Chin-Lung',
#    'cl_bottom': '36',
#    'cl_top': '36',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Browsing Newsgroups with A Social Network Analyzer',
#      'year': u'2002'}]}),
#  ('Chang, Yi-Chien',
#   {'author_name': 'Chang, Yi-Chien',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{VisANT} 3.5: multi-scale network visualization, analysis and inference based on the gene ontology',
#      'year': u'2009'}]}),
#  ('Li, Yueping',
#   {'author_name': 'Li, Yueping',
#    'cl_bottom': '17',
#    'cl_top': '17',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Multi-opinion Ring: visualizing and predicting multiple opinion orientations in online social media',
#      'year': u'2015'},
#     {'title': u'{OpinionRings}: Inferring and visualizing the opinion tendency of socially connected users',
#      'year': u'2015'}]}),
#  ('Goodell, Howard',
#   {'author_name': 'Goodell, Howard',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'}]}),
#  ('Fekete, Jean-Daniel',
#   {'author_name': 'Fekete, Jean-Daniel',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.0073868900000000001,
#    'papers': [{'title': u'{GraphDiaries}: Animated Transitions and Temporal Navigation for Dynamic Networks',
#      'year': u'2014'},
#     {'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'},
#     {'title': u'Overlaying Graph Links on Treemaps', 'year': u'2003'},
#     {'title': u'Matrix View of Graphs and Direct Manipulation of Cluster Hierarchies',
#      'year': u'2003'},
#     {'title': u'{MatrixExplorer}: a Dual-Representation System to Explore Social Networks',
#      'year': u'2006'},
#     {'title': u'{NodeTrix}: a Hybrid Visualization of Social Networks',
#      'year': u'2007'},
#     {'title': u'Improving the Readability of Clustered Social Networks Using Node Duplication',
#      'year': u'2008'}]}),
#  ('Henry, Nathalie',
#   {'author_name': 'Henry, Nathalie',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.00415512,
#    'papers': [{'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'},
#     {'title': u'{MatrixExplorer}: a Dual-Representation System to Explore Social Networks',
#      'year': u'2006'},
#     {'title': u'{NodeTrix}: a Hybrid Visualization of Social Networks',
#      'year': u'2007'},
#     {'title': u'Improving the Readability of Clustered Social Networks Using Node Duplication',
#      'year': u'2008'}]}),
#  ('Enright, Anton',
#   {'author_name': 'Enright, Anton',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'},
#     {'title': u'Network visualization and analysis of gene expression data using {BioLayout Express(3D)}',
#      'year': u'2009'}]}),
#  ('Itoh, Takayuki',
#   {'author_name': 'Itoh, Takayuki',
#    'cl_bottom': '2:1:2:2',
#    'cl_top': '2',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'A hybrid space-filling and force-directed layout method for visualizing multiple-category graphs',
#      'year': u'2009'},
#     {'title': u'Integrated Visualization of Gene Network and Ontology Applying a Hierarchical Graph Visualization Technique',
#      'year': u'2012'},
#     {'title': u'A Visualization of Research Papers Based on the Topics and Citation Network',
#      'year': u'2015'}]}),
#  ('Feng, Qing-Wen',
#   {'author_name': 'Feng, Qing-Wen',
#    'cl_bottom': '16:1',
#    'cl_top': '16',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Multilevel Visualization of Clustered Graphs',
#      'year': u'1997'},
#     {'title': u'Straight-Line Drawing Algorithms for Hierarchical Graphs and Clustered Graphs',
#      'year': u'1997'},
#     {'title': u'Drawing Clustered Graphs on an Orthogonal Grid',
#      'year': u'1999'},
#     {'title': u'How to draw a planar clustered graph', 'year': u'1995'}]}),
#  ('Tal, Ayellet',
#   {'author_name': 'Tal, Ayellet',
#    'cl_bottom': '37',
#    'cl_top': '37',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Dynamic Drawing of Clustered Graphs',
#      'year': u'2004'},
#     {'title': u'Multi-Level Graph Layout on the GPU', 'year': u'2007'},
#     {'title': u'{MOVIS}: A system for visualizing distributed mobile object environments',
#      'year': u'2008'}]}),
#  ('Cruz, Juan',
#   {'author_name': 'Cruz, Juan',
#    'cl_bottom': '38',
#    'cl_top': '38',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Community Detection and Visualization in Social Networks: Integrating Structural and Semantic Information',
#      'year': u'2014'}]}),
#  ('Gou, Liang',
#   {'author_name': 'Gou, Liang',
#    'cl_bottom': '52',
#    'cl_top': '52',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{TreeNetViz}: Revealing Patterns of Networks over Tree Structures',
#      'year': u'2011'}]}),
#  ('Belviranli, Mehmet',
#   {'author_name': 'Belviranli, Mehmet',
#    'cl_bottom': '18',
#    'cl_top': '18',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{CiSE}: A Circular Spring Embedder Layout Algorithm',
#      'year': u'2013'}]}),
#  ('Liggesmeyer, Peter',
#   {'author_name': 'Liggesmeyer, Peter',
#    'cl_bottom': '25',
#    'cl_top': '25',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Polyptychon: A Hierarchically-constrained Classified Dependencies Visualization',
#      'year': u'2014'}]}),
#  ('Wuchner, Egon',
#   {'author_name': 'Wuchner, Egon',
#    'cl_bottom': '25',
#    'cl_top': '25',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Polyptychon: A Hierarchically-constrained Classified Dependencies Visualization',
#      'year': u'2014'}]}),
#  ('Lisitsyn, Ivan',
#   {'author_name': 'Lisitsyn, Ivan',
#    'cl_bottom': '47',
#    'cl_top': '47',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Higres - Visualization System for Clustered Graphs and Graph Algorithms',
#      'year': u'1999'}]}),
#  ('Staples, Mathew',
#   {'author_name': 'Staples, Mathew',
#    'cl_bottom': '53',
#    'cl_top': '53',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{3-D} Visualization of Software Structure',
#      'year': u'1999'}]}),
#  ('Tollis, Ioannis',
#   {'author_name': 'Tollis, Ioannis',
#    'cl_bottom': '54',
#    'cl_top': '54',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'A Framework for User-Grouped Circular Drawings',
#      'year': u'2004'}]}),
#  ('Pinaud, Bruno',
#   {'author_name': 'Pinaud, Bruno',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'The Readability of Path-Preserving Clusterings of Graphs',
#      'year': u'2010'}]}),
#  ('Xiang, Yang',
#   {'author_name': 'Xiang, Yang',
#    'cl_bottom': '29',
#    'cl_top': '29',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Overlapping Matrix Pattern Visualization: A Hypergraph Approach',
#      'year': u'2008'}]}),
#  ('Goldovsky, Leon',
#   {'author_name': 'Goldovsky, Leon',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'}]}),
#  ('Sprenger, Thomas',
#   {'author_name': 'Sprenger, Thomas',
#    'cl_bottom': '39',
#    'cl_top': '39',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{H-BLOB}: a hierarchical visual clustering method using implicit surfaces',
#      'year': u'2000'}]}),
#  ('Ramos, Gonzalo',
#   {'author_name': 'Ramos, Gonzalo',
#    'cl_bottom': '1:6',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Design Study of LineSets, a Novel Set Visualization Technique',
#      'year': u'2011'}]}),
#  ('Graham, M.',
#   {'author_name': 'Graham, M.',
#    'cl_bottom': '40',
#    'cl_top': '40',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Combined vs. Separate Views in Matrix-based Graph Analysis and Comparison',
#      'year': u'2011'}]}),
#  ('Diehl, Stephan',
#   {'author_name': 'Diehl, Stephan',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.010156999999999999,
#    'papers': [{'title': u'Finding Structures in Multi-Type Code Couplings with Node-Link and Matrix Visualizations',
#      'year': u'2013'},
#     {'title': u'Visually Exploring Multi-Dimensional Code Couplings',
#      'year': u'2011'},
#     {'title': u'Rapid Serial Visual Presentation in Dynamic Graph Visualization',
#      'year': u'2012'},
#     {'title': u'Visual Comparison of Software Architectures', 'year': u'2013'},
#     {'title': u'{TimeRadarTrees}: Visualizing Dynamic Compound Digraphs',
#      'year': u'2008'},
#     {'title': u'{TimeSpiderTrees}: A Novel Visual Metaphor for Dynamic Compound Graphs',
#      'year': u'2010'},
#     {'title': u'Parallel Edge Splatting for Scalable Dynamic Graph Visualization',
#      'year': u'2011'},
#     {'title': u'Visualizing the Evolution of Compound Digraphs with {TimeArcTrees}',
#      'year': u'2009'},
#     {'title': u'Focused Animation of Dynamic Compound Graphs',
#      'year': u'2009'}]}),
#  ('Wang, Xiting',
#   {'author_name': 'Wang, Xiting',
#    'cl_bottom': '3:5',
#    'cl_top': '3',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{TopicPanorama}: a full picture of relevant topics',
#      'year': u'2014'}]}),
#  ('Auw{a}rter, Patrick',
#   {'author_name': 'Auw{a}rter, Patrick',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Visualizing the Evolution of Communities in Dynamic Graphs',
#      'year': u'2015'}]}),
#  ('Freeman, Tom',
#   {'author_name': 'Freeman, Tom',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'},
#     {'title': u'Network visualization and analysis of gene expression data using {BioLayout Express(3D)}',
#      'year': u'2009'}]}),
#  ('Mothe, Josiane',
#   {'author_name': 'Mothe, Josiane',
#    'cl_bottom': '55',
#    'cl_top': '55',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'An energy-based model to optimize cluster visualization',
#      'year': u'2014'}]}),
#  ('Pattison, Tim',
#   {'author_name': 'Pattison, Tim',
#    'cl_bottom': '30',
#    'cl_top': '30',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Information Visualisation Using Composable Layouts and Visual Sets',
#      'year': u'2001'}]}),
#  ('Bristow, Michael',
#   {'author_name': 'Bristow, Michael',
#    'cl_bottom': '1:1:3',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual analysis of biological data-knowledge networks',
#      'year': u'2015'}]}),
#  ('Weiskopf, Daniel',
#   {'author_name': 'Weiskopf, Daniel',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0184672,
#    'papers': [{'title': u'Rapid Serial Visual Presentation in Dynamic Graph Visualization',
#      'year': u'2012'},
#     {'title': u'Parallel Edge Splatting for Scalable Dynamic Graph Visualization',
#      'year': u'2011'},
#     {'title': u'Layered {TimeRadarTrees}', 'year': u'2011'},
#     {'title': u'A Matrix-Based Visualization for Exploring Dynamic Compound Digraphs',
#      'year': u'2013'},
#     {'title': u'Edge-Stacked Timelines for Visualizing Dynamic Weighted Digraphs',
#      'year': u'2015'},
#     {'title': u'Visual Adjacency Lists for Dynamic Graphs', 'year': u'2014'},
#     {'title': u'Visualizing edge-edge relations in graphs', 'year': u'2013'},
#     {'title': u'Visualizing Fuzzy Overlapping Communities in Networks',
#      'year': u'2013'},
#     {'title': u'Radial Layered Matrix Visualization of Dynamic Graphs',
#      'year': u'2013'},
#     {'title': u'Visualizing the Evolution of Communities in Dynamic Graphs',
#      'year': u'2015'},
#     {'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'},
#     {'title': u'Visual analysis of biological data-knowledge networks',
#      'year': u'2015'}]}),
#  ('Poulet, Fran\\c{c}ois',
#   {'author_name': 'Poulet, Fran\\c{c}ois',
#    'cl_bottom': '38',
#    'cl_top': '38',
# ...
#      'year': u'2014'}]}),
#  ('Zhang, Chao',
#   {'author_name': 'Zhang, Chao',
#    'cl_bottom': '19',
#    'cl_top': '19',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Mosaic: making biological sense of complex networks.',
#      'year': u'2012'}]}),
#  ('Westenberg, M.A.',
#   {'author_name': 'Westenberg, M.A.',
#    'cl_bottom': '42',
#    'cl_top': '42',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{Dual Adjacency Matrix}: Exploring Link Groups in Dense Networks',
#      'year': u'2015'}]}),
#  ('Aris, Aleks',
#   {'author_name': 'Aris, Aleks',
#    'cl_bottom': '4:3',
#    'cl_top': '4',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Overlaying Graph Links on Treemaps',
#      'year': u'2003'},
#     {'title': u'Network Visualization by Semantic Substrates',
#      'year': u'2006'}]}),
#  ('Kashofer, Karl',
#   {'author_name': 'Kashofer, Karl',
#    'cl_bottom': '7:1',
#    'cl_top': '7',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{enRoute:} dynamic path extraction from biological pathway maps for exploring heterogeneous experimental datasets',
#      'year': u'2013'}]}),
#  ('Kuntzer, Jan',
#   {'author_name': 'Kuntzer, Jan',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  ('Zhang, Ji',
#   {'author_name': 'Zhang, Ji',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Semi-bipartite Graph Visualization for Gene Ontology Networks',
#      'year': u'2010'}]}),
#  ('Gange, Graeme',
#   {'author_name': 'Gange, Graeme',
#    'cl_bottom': '1:2',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'High-Quality Ultra-Compact Grid Layout of Grouped Networks',
#      'year': u'2015'}]}),
#  ('Bondarev, Egor',
#   {'author_name': 'Bondarev, Egor',
#    'cl_bottom': '11:1',
#    'cl_top': '11',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualization of Areas of Interest in Component-Based System Architectures',
#      'year': u'2006'}]}),
#  ('Henry Riche, Nathalie',
#   {'author_name': 'Henry Riche, Nathalie',
#    'cl_bottom': '1:6',
#    'cl_top': '1',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Design Study of LineSets, a Novel Set Visualization Technique',
#      'year': u'2011'},
#     {'title': u'Edge Compression Techniques for Visualization of Dense Directed Graphs',
#      'year': u'2013'},
#     {'title': u'Untangling {Euler} diagrams', 'year': u'2010'}]}),
#  ('Wang, Xiaobo',
#   {'author_name': 'Wang, Xiaobo',
#    'cl_bottom': '60',
#    'cl_top': '60',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Generating customized layouts', 'year': u'1996'}]}),
#  ('Dragicevic, Pierre',
#   {'author_name': 'Dragicevic, Pierre',
#    'cl_bottom': '45',
#    'cl_top': '45',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Interactive Graph Matching and Visual Comparison of Graphs and Clustered Graphs',
#      'year': u'2012'}]}),
#  ('Junker, Bjorn',
#   {'author_name': 'Junker, Bjorn',
#    'cl_bottom': '1:5',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{VANTED}: A system for advanced data analysis and visualization in the context of biological networks',
#      'year': u'2006'}]}),
#  ('Cantareiro, Gabriel',
#   {'author_name': 'Cantareiro, Gabriel',
#    'cl_bottom': '11:1',
#    'cl_top': '11',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Skeleton-Based Edge Bundling for Graph Visualization',
#      'year': u'2011'}]}),
#  ('Hua, Jie',
#   {'author_name': 'Hua, Jie',
#    'cl_bottom': '16:2',
#    'cl_top': '16',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Drawing Large Weighted Graphs Using Clustered Force-Directed Algorithm',
#      'year': u'2014'}]}),
#  ('John, Mathias',
#   {'author_name': 'John, Mathias',
#    'cl_bottom': '2:2:2',
#    'cl_top': '2',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Visual Analysis of Bipartite Biological Networks',
#      'year': u'2008'}]}),
#  ('Lewerentz, Claus',
#   {'author_name': 'Lewerentz, Claus',
#    'cl_bottom': '56',
#    'cl_top': '56',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'A space of layout styles for hierarchical graph models of software systems',
#      'year': u'2005'}]}),
#  ('Jirstrand, Mats',
#   {'author_name': 'Jirstrand, Mats',
#    'cl_bottom': '61',
#    'cl_top': '61',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Biochemical modeling with Systems Biology Graphical Notation',
#      'year': u'2010'}]}),
#  ('Heine, Christian',
#   {'author_name': 'Heine, Christian',
#    'cl_bottom': '1:3',
#    'cl_top': '1',
#    'flow': 0.00184672,
#    'papers': [{'title': u'A Novel Grid-based Visualization Approach for Metabolic Networks with Advanced Focus\\&Context View',
#      'year': u'2010'}]}),
#  ('Baumbach, Jan',
#   {'author_name': 'Baumbach, Jan',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  ('Kreveld, Marc',
#   {'author_name': 'Kreveld, Marc',
#    'cl_bottom': '9',
#    'cl_top': '9',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{Kelp Diagrams}: Point Set Membership Visualization',
#      'year': u'2012'}]}),
#  ('Faber, Daniel',
#   {'author_name': 'Faber, Daniel',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  ('Kaufmann, Michael',
#   {'author_name': 'Kaufmann, Michael',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  ('Chiricota, Yves',
#   {'author_name': 'Chiricota, Yves',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Multiscale visualization of small world networks',
#      'year': u'2003'}]}),
#  ('Simonetto, Paolo',
#   {'author_name': 'Simonetto, Paolo',
#    'cl_bottom': '2:1:1:3',
#    'cl_top': '2',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Communities and hierarchical structures in dynamic social networks: analysis and visualization',
#      'year': u'2011'},
#     {'title': u'Node, Node-Link, and Node-Link-Group Diagrams: An Evaluation',
#      'year': u'2014'}]}),
#  ('Letunic, Ivica',
#   {'author_name': 'Letunic, Ivica',
#    'cl_bottom': '5:2',
#    'cl_top': '5',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{iPath}: interactive exploration of biochemical pathways and networks',
#      'year': u'2008'}]}),
#  ('Fuhry, David',
#   {'author_name': 'Fuhry, David',
#    'cl_bottom': '29',
#    'cl_top': '29',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Overlapping Matrix Pattern Visualization: A Hypergraph Approach',
#      'year': u'2008'}]}),
#  ('Romeo, Salvatore',
#   {'author_name': 'Romeo, Salvatore',
#    'cl_bottom': '10',
#    'cl_top': '10',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Graph visualization techniques for conceptual Web site traffic analysis',
#      'year': u'2010'}]}),
#  ('Crnovrsanin, Tarik',
#   {'author_name': 'Crnovrsanin, Tarik',
#    'cl_bottom': '2:1:2:1',
#    'cl_top': '2',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Visualization Techniques for Categorical Analysis of Social Networks with Multiple Edge Sets',
#      'year': u'2014'}]}),
#  ('Elzen, Stef',
#   {'author_name': 'Elzen, Stef',
#    'cl_bottom': '2:2:4',
#    'cl_top': '2',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Multivariate Network Exploration and Presentation: From Detail to Overview via Selections and Aggregations',
#      'year': u'2014'}]}),
#  ('Phillips, Matthew',
#   {'author_name': 'Phillips, Matthew',
#    'cl_bottom': '30',
#    'cl_top': '30',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Information Visualisation Using Composable Layouts and Visual Sets',
#      'year': u'2001'}]}),
#  ('Grocock, Russell',
#   {'author_name': 'Grocock, Russell',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'}]}),
#  ('Kuchinsky, Allan',
#   {'author_name': 'Kuchinsky, Allan',
#    'cl_bottom': '19',
#    'cl_top': '19',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Mosaic: making biological sense of complex networks.',
#      'year': u'2012'}]}),
#  ('Lambert, Antoine',
#   {'author_name': 'Lambert, Antoine',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Pathway Preserving Representation of Metabolic Networks',
#      'year': u'2011'},
#     {'title': u'Visualizing Patterns in Node-link Diagrams',
#      'year': u'2012'}]}),
#  ('Paris, Gilles',
#   {'author_name': 'Paris, Gilles',
#    'cl_bottom': '71',
#    'cl_top': '71',
#    'flow': 0.0,
#    'papers': [{'title': u'Automatic Drawing of Compound Digraphs for a Real-Time Power System Simulator',
#      'year': u'1996'}]}),
#  ('Dang, N.',
#   {'author_name': 'Dang, N.',
#    'cl_bottom': '4:3',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Overlaying Graph Links on Treemaps',
#      'year': u'2003'}]}),
#  ('Shi, Conglei',
#   {'author_name': 'Shi, Conglei',
#    'cl_bottom': '3:2',
#    'cl_top': '3',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual Analysis of Set Relations in a Graph',
#      'year': u'2013'}]}),
#  ('Jourdan, Fabien',
#   {'author_name': 'Jourdan, Fabien',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0073868900000000001,
#    'papers': [{'title': u'Multiscale visualization of small world networks',
#      'year': u'2003'},
#     {'title': u'Metabolic network visualization using constraint planar graph drawing algorithm',
#      'year': u'2006'},
#     {'title': u'Metabolic network visualization eliminating node redundance and preserving metabolic pathways',
#      'year': u'2007'},
#     {'title': u'Communities and hierarchical structures in dynamic social networks: analysis and visualization',
#      'year': u'2011'}]}),
#  ('Wybrow, Michael',
#   {'author_name': 'Wybrow, Michael',
#    'cl_bottom': '1:2',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Exploration of Networks Using Overview+Detail with Constraint-based Cooperative Layout',
#      'year': u'2008'}]}),
#  ('Pohl, Mathias',
#   {'author_name': 'Pohl, Mathias',
#    'cl_bottom': '1:1:4',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Focused Animation of Dynamic Compound Graphs',
#      'year': u'2009'}]}),
#  ('Sugiyama, Kozo',
#   {'author_name': 'Sugiyama, Kozo',
#    'cl_bottom': '22:2',
#    'cl_top': '22',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Method for drawing intersecting clustered graphs and its application to web ontology language',
#      'year': u'2006'},
#     {'title': u'Force-directed drawing method for intersecting clustered graphs',
#      'year': u'2007'},
#     {'title': u'Visualization of structural information: automatic drawing of compound digraphs',
#      'year': u'1991'}]}),
#  ('Wang, Yan',
#   {'author_name': 'Wang, Yan',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{VisANT} 3.5: multi-scale network visualization, analysis and inference based on the gene ontology',
#      'year': u'2009'}]}),
#  ('Specht, Michael',
#   {'author_name': 'Specht, Michael',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  ('Stasko, John',
#   {'author_name': 'Stasko, John',
#    'cl_bottom': '15',
#    'cl_top': '15',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{GLO-STIX}: Graph-Level Operations for Specifying Techniques and Interactive eXploration',
#      'year': u'2014'}]}),
#  ('Zhu, Jun',
#   {'author_name': 'Zhu, Jun',
#    'cl_bottom': '3:5',
#    'cl_top': '3',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{TopicPanorama}: a full picture of relevant topics',
#      'year': u'2014'}]}),
#  ('Humayoun, Shah',
#   {'author_name': 'Humayoun, Shah',
#    'cl_bottom': '43',
#    'cl_top': '43',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{CluE}: An Algorithm for Expanding Clustered Graphs',
#      'year': u'2014'}]}),
#  ('Gao, Jie',
#   {'author_name': 'Gao, Jie',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'A Multiple-Aspects Visualization Tool for Exploring Social Networks',
#      'year': u'2009'}]}),
#  ('Do, Thanh-Nghi',
#   {'author_name': 'Do, Thanh-Nghi',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'}]}),
#  ('El-Kebir, Mohammed',
#   {'author_name': 'El-Kebir, Mohammed',
#    'cl_bottom': '9',
#    'cl_top': '9',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{eXamine}: Exploring annotated modules in networks',
#      'year': u'2014'}]}),
#  ('Greilich, Martin',
#   {'author_name': 'Greilich, Martin',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualizing the Evolution of Compound Digraphs with {TimeArcTrees}',
#      'year': u'2009'}]}),
#  ('Huang, Chia-Ling',
#   {'author_name': 'Huang, Chia-Ling',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{VisANT} 3.5: multi-scale network visualization, analysis and inference based on the gene ontology',
#      'year': u'2009'}]}),
#  ('Melville, A.G.',
#   {'author_name': 'Melville, A.G.',
#    'cl_bottom': '40',
#    'cl_top': '40',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Combined vs. Separate Views in Matrix-based Graph Analysis and Comparison',
#      'year': u'2011'}]}),
#  ('Ahmed, Adel',
#   {'author_name': 'Ahmed, Adel',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Visual Analysis of History of World Cup: A Dynamic Network with Dynamic Hierarchy and Geographic Clustering',
#      'year': u'2010'}]}),
#  ('Lin, Ching-Yung',
#   {'author_name': 'Lin, Ching-Yung',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'{HiMap}: Adaptive visualization of large-scale online social networks',
#      'year': u'2009'}]}),
#  ('Hasselbring, Wilhelm',
#   {'author_name': 'Hasselbring, Wilhelm',
#    'cl_bottom': '32',
#    'cl_top': '32',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Hierarchical Software Landscape Visualization for System Comprehension: A Controlled Experiment',
#      'year': u'2015'}]}),
#  ('Klau, Gunnar',
#   {'author_name': 'Klau, Gunnar',
#    'cl_bottom': '9',
#    'cl_top': '9',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{eXamine}: Exploring annotated modules in networks',
#      'year': u'2014'}]}),
#  ('Balakrishnan, Ravin',
#   {'author_name': 'Balakrishnan, Ravin',
#    'cl_bottom': '24:1',
#    'cl_top': '24',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Interactive Exploration of Implicit and Explicit Relations in Faceted Datasets',
#      'year': u'2013'}]}),
#  ('Ito, Takao',
#   {'author_name': 'Ito, Takao',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Drawing Clustered Bipartite Graphs in Multi-circular Style',
#      'year': u'2010'}]}),
#  ('Paley, Suzanne',
#   {'author_name': 'Paley, Suzanne',
#    'cl_bottom': '66',
#    'cl_top': '66',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'The Pathway Tools cellular overview diagram and Omics Viewer',
#      'year': u'2006'}]}),
#  ('Hunter, Lawrence',
#   {'author_name': 'Hunter, Lawrence',
#    'cl_bottom': '1:1:3',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual analysis of biological data-knowledge networks',
#      'year': u'2015'}]})]

# %%
G = nx.relabel_nodes(G, df.node.to_dict())

# %%
G.nodes(data=True)
# Out:
# [(1,
#   {'author_name': 'Wu, Jie',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{VisANT}: data-integrating visual framework for biological networks and modules',
#      'year': u'2005'}]}),
#  (2,
#   {'author_name': 'Smith, Adam',
#    'cl_bottom': '20',
#    'cl_top': '20',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{RuleBender}: integrated modeling, simulation and visualization for rule-based intracellular biochemistry',
#      'year': u'2012'}]}),
#  (3,
#   {'author_name': 'Nakazawa, Rina',
#    'cl_bottom': '2:1:2:2',
#    'cl_top': '2',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Integrated Visualization of Gene Network and Ontology Applying a Hierarchical Graph Visualization Technique',
#      'year': u'2012'},
#     {'title': u'A Visualization of Research Papers Based on the Topics and Citation Network',
#      'year': u'2015'}]}),
#  (4,
#   {'author_name': 'Hasco{e}t, Mountaz',
#    'cl_bottom': '45',
#    'cl_top': '45',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Interactive Graph Matching and Visual Comparison of Graphs and Clustered Graphs',
#      'year': u'2012'}]}),
#  (5,
#   {'author_name': 'Sangal, Neeraj',
#    'cl_bottom': '27',
#    'cl_top': '27',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Using Dependency Models to Manage Complex Software Architecture',
#      'year': u'2005'}]}),
#  (6,
#   {'author_name': 'Elmqvist, Niklas',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{CiteWiz}: a tool for the visualization of scientific citation networks',
#      'year': u'2007'},
#     {'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'}]}),
#  (7,
#   {'author_name': 'Zimmer, Bj{{o}}rn',
#    'cl_bottom': '1:3',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Multivariate Network Exploration with JauntyNets',
#      'year': u'2013'},
#     {'title': u'Visual Exploration of Relationships between Document Clusters',
#      'year': u'2014'}]}),
#  (8,
#   {'author_name': 'Philippi, Stephan',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  (9,
#   {'author_name': 'Vernik, Rudi',
#    'cl_bottom': '30',
#    'cl_top': '30',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Information Visualisation Using Composable Layouts and Visual Sets',
#      'year': u'2001'}]}),
#  (10,
#   {'author_name': 'Goesmann, Alexander',
#    'cl_bottom': '21',
#    'cl_top': '21',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{PathFinder}: reconstruction and dynamic visualization of metabolic pathways',
#      'year': u'2002'}]}),
#  (11,
#   {'author_name': 'Tanaka, Jiro',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.00184672,
#    'papers': [{'title': u'A Multiple-Aspects Visualization Tool for Exploring Social Networks',
#      'year': u'2009'},
#     {'title': u'Drawing Clustered Bipartite Graphs in Multi-circular Style',
#      'year': u'2010'}]}),
#  (12,
#   {'author_name': 'Mary, Patrick',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'How to Draw Clustered Weighted Graphs using a Multilevel Force-Directed Graph Drawing Algorithm',
#      'year': u'2007'},
#     {'title': u'Metabolic network visualization eliminating node redundance and preserving metabolic pathways',
#      'year': u'2007'}]}),
#  (13,
#   {'author_name': 'Nguyen, QuanHoang',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Visual Analysis of History of World Cup: A Dynamic Network with Dynamic Hierarchy and Geographic Clustering',
#      'year': u'2010'}]}),
#  (14,
#   {'author_name': 'Schmauder, Hansj{{o}}rg',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Radial Layered Matrix Visualization of Dynamic Graphs',
#      'year': u'2013'}]}),
#  (15,
#   {'author_name': 'Kramer, Andrei',
#    'cl_bottom': '1:1:2',
#    'cl_top': '1',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'}]}),
#  (16,
#   {'author_name': 'Jackson, Daniel',
#    'cl_bottom': '27',
#    'cl_top': '27',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Using Dependency Models to Manage Complex Software Architecture',
#      'year': u'2005'}]}),
#  (17,
#   {'author_name': 'Mellor, Joe',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{VisANT}: data-integrating visual framework for biological networks and modules',
#      'year': u'2005'}]}),
#  (18,
#   {'author_name': 'Sagot, Marie-France',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Metabolic network visualization eliminating node redundance and preserving metabolic pathways',
#      'year': u'2007'}]}),
#  (19,
#   {'author_name': 'Roseman, Mark',
#    'cl_bottom': '13',
#    'cl_top': '13',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Navigating Hierarchically Clustered Networks Through Fisheye and Full-zoom Methods',
#      'year': u'1996'}]}),
#  (20,
#   {'author_name': 'Timmer, Jens',
#    'cl_bottom': '1:1:2',
#    'cl_top': '1',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'}]}),
#  (21,
#   {'author_name': 'Eliassi-Rad, Tina',
#    'cl_bottom': '2:1:2:1',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visual Analysis of Large Heterogeneous Social Networks by Semantic and Structural Abstraction',
#      'year': u'2006'}]}),
#  (22,
#   {'author_name': 'Krishnan, Neeraj',
#    'cl_bottom': '2:2:3',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{ASK-GraphView}: A Large Scale Graph Visualization System',
#      'year': u'2006'}]}),
#  (23,
#   {'author_name': 'Rucevskis, Peteris',
#    'cl_bottom': '23',
#    'cl_top': '23',
#    'flow': 0.00184672,
#    'papers': [{'title': u'An Inverse Distance-based Potential Field Function for Overlapping Point Set Visualization.',
#      'year': u'2014'}]}),
#  (24,
#   {'author_name': 'Kalkofen, Denis',
#    'cl_bottom': '7:1',
#    'cl_top': '7',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{enRoute:} dynamic path extraction from biological pathway maps for exploring heterogeneous experimental datasets',
#      'year': u'2013'}]}),
#  (25,
#   {'author_name': "Rufiange, S{\\'e}bastien",
#    'cl_bottom': '4:4',
#    'cl_top': '4',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{TreeMatrix}: A hybrid visualization of compound graphs',
#      'year': u'2012'}]}),
#  (26,
#   {'author_name': 'Termeer, Maurice',
#    'cl_bottom': '11:2',
#    'cl_top': '11',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Visual Exploration of Combined Architectural and Metric Information',
#      'year': u'2005'}]}),
#  (27,
#   {'author_name': 'Ho, Joshua',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Drawing Clustered Graphs in Three Dimensions',
#      'year': u'2006'}]}),
#  (28,
#   {'author_name': "Gilbert, Fr\\'ed\\'eric",
#    'cl_bottom': '2:1:1:3',
#    'cl_top': '2',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Communities and hierarchical structures in dynamic social networks: analysis and visualization',
#      'year': u'2011'}]}),
#  (29,
#   {'author_name': 'Taubert, Jan',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  (30,
#   {'author_name': 'Breitkreutz, Bobby-Joe',
#    'cl_bottom': '31',
#    'cl_top': '31',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Osprey: a network visualization system.',
#      'year': u'2003'}]}),
#  (31,
#   {'author_name': 'Lenhof, Hans-Peter',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  (32,
#   {'author_name': 'Zachariah, R.',
#    'cl_bottom': '4:2',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Group-in-a-Box Meta-Layouts for Topological Clusters and Attribute-Based Groups: Space-Efficient Visualizations of Network Communities and Their Ties',
#      'year': u'2014'}]}),
#  (33,
#   {'author_name': 'Krause, Alexander',
#    'cl_bottom': '32',
#    'cl_top': '32',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Hierarchical Software Landscape Visualization for System Comprehension: A Controlled Experiment',
#      'year': u'2015'}]}),
#  (34,
#   {'author_name': 'Kruijff, Ernst',
#    'cl_bottom': '7:1',
#    'cl_top': '7',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Caleydo: Design and Evaluation of a Visual Analysis Framework for Gene Expression Data in its Biological Context',
#      'year': u'2010'}]}),
#  (35,
#   {'author_name': 'Faith, Joe',
#    'cl_bottom': '46',
#    'cl_top': '46',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Node-attribute Graph Layout for Small-World Networks',
#      'year': u'2011'}]}),
#  (36,
#   {'author_name': 'Yan, Youliang',
#    'cl_bottom': '3:4',
#    'cl_top': '3',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Interactive visual summary of major communities in a large network',
#      'year': u'2015'}]}),
#  (37,
#   {'author_name': 'Bartram, Lyn',
#    'cl_bottom': '13',
#    'cl_top': '13',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Navigating Hierarchically Clustered Networks Through Fisheye and Full-zoom Methods',
#      'year': u'1996'}]}),
#  (38,
#   {'author_name': 'Wu, Yanhong',
#    'cl_bottom': '3:4',
#    'cl_top': '3',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Interactive visual summary of major communities in a large network',
#      'year': u'2015'}]}),
#  (39,
#   {'author_name': 'Greenberg, Saul',
#    'cl_bottom': '13',
#    'cl_top': '13',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Navigating Hierarchically Clustered Networks Through Fisheye and Full-zoom Methods',
#      'year': u'1996'}]}),
#  (40,
#   {'author_name': 'Fritz, Peter',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{TimeSpiderTrees}: A Novel Visual Metaphor for Dynamic Compound Graphs',
#      'year': u'2010'}]}),
#  (41,
#   {'author_name': 'Munzner, Tamara',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0069252100000000002,
#    'papers': [{'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'{TopoLayout}: Multilevel Graph Layout by Topological Features',
#      'year': u'2007'},
#     {'title': u'{GrouseFlocks}: Steerable Exploration of Graph Hierarchy Space',
#      'year': u'2008'},
#     {'title': u'{TugGraph}: Path-preserving hierarchies for browsing proximity and paths in graphs',
#      'year': u'2009'},
#     {'title': u'Tugging Graphs Faster: Efficiently Modifying Path-Preserving Hierarchies for Browsing Paths',
#      'year': u'2011'},
#     {'title': u'Cerebral: Visualizing Multiple Experimental Conditions on a Graph with Biological Context',
#      'year': u'2008'},
#     {'title': u'{Detangler}: Visual Analytics for Multiplex Networks',
#      'year': u'2015'}]}),
#  (42,
#   {'author_name': 'Kalinowski, Jorn',
#    'cl_bottom': '21',
#    'cl_top': '21',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{PathFinder}: reconstruction and dynamic visualization of metabolic pathways',
#      'year': u'2002'}]}),
#  (43,
#   {'author_name': 'Chaturvedi, S.',
#    'cl_bottom': '4:2',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Group-in-a-Box Meta-Layouts for Topological Clusters and Attribute-Based Groups: Space-Efficient Visualizations of Network Communities and Their Ties',
#      'year': u'2014'}]}),
#  (44,
#   {'author_name': 'Haubrock, Martin',
#    'cl_bottom': '21',
#    'cl_top': '21',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{PathFinder}: reconstruction and dynamic visualization of metabolic pathways',
#      'year': u'2002'}]}),
#  (45,
#   {'author_name': 'Auber, David',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0124654,
#    'papers': [{'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'{TopoLayout}: Multilevel Graph Layout by Topological Features',
#      'year': u'2007'},
#     {'title': u'{GrouseFlocks}: Steerable Exploration of Graph Hierarchy Space',
#      'year': u'2008'},
#     {'title': u'{TugGraph}: Path-preserving hierarchies for browsing proximity and paths in graphs',
#      'year': u'2009'},
#     {'title': u'Tugging Graphs Faster: Efficiently Modifying Path-Preserving Hierarchies for Browsing Paths',
#      'year': u'2011'},
#     {'title': u'Multiscale visualization of small world networks',
#      'year': u'2003'},
#     {'title': u'{Tulip}: A huge graph visualization framework',
#      'year': u'2003'},
#     {'title': u'Metabolic network visualization using constraint planar graph drawing algorithm',
#      'year': u'2006'},
#     {'title': u'How to Draw Clustered Weighted Graphs using a Multilevel Force-Directed Graph Drawing Algorithm',
#      'year': u'2007'},
#     {'title': u'Metabolic network visualization eliminating node redundance and preserving metabolic pathways',
#      'year': u'2007'},
#     {'title': u'{Adjasankey}: Visualization of huge hierarchical weighted and directed graphs',
#      'year': u'2015'}]}),
#  (46,
#   {'author_name': 'Du, Xiaolin',
#    'cl_bottom': '17',
#    'cl_top': '17',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Multi-opinion Ring: visualizing and predicting multiple opinion orientations in online social media',
#      'year': u'2015'},
#     {'title': u'{OpinionRings}: Inferring and visualizing the opinion tendency of socially connected users',
#      'year': u'2015'}]}),
#  (47,
#   {'author_name': 'Nguyen, Quang',
#    'cl_bottom': '16:2',
#    'cl_top': '16',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Drawing Large Weighted Graphs Using Clustered Force-Directed Algorithm',
#      'year': u'2014'},
#     {'title': u'A Space Efficient Clustered Visualization of Large Graphs',
#      'year': u'2007'},
#     {'title': u'Navigating Large Clustered Graphs with Triple-Layer Display',
#      'year': u'2007'}]}),
#  (48,
#   {'author_name': 'Niermann, Peter',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  (49,
#   {'author_name': 'Zhou, Qi',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Drawing Semi-bipartite Graphs in Anchor+Matrix Style',
#      'year': u'2011'}]}),
#  (50,
#   {'author_name': 'Kao, David',
#    'cl_bottom': '1:1:3',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual analysis of biological data-knowledge networks',
#      'year': u'2015'}]}),
#  (51,
#   {'author_name': 'Gansner, Emden',
#    'cl_bottom': '2:2:1',
#    'cl_top': '2',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Improved Circular Layouts', 'year': u'2007'},
#     {'title': u'{GMap}: Visualizing graphs and clusters as maps',
#      'year': u'2010'},
#     {'title': u'Visualizing Graphs and Clusters as Maps', 'year': u'2010'}]}),
#  (52,
#   {'author_name': 'Liu, Shixia',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.010156999999999999,
#    'papers': [{'title': u'{FacetAtlas}: Multifaceted Visualization for Rich Text Corpora',
#      'year': u'2010'},
#     {'title': u'{TopicPanorama}: a full picture of relevant topics',
#      'year': u'2014'},
#     {'title': u'{HiMap}: Adaptive visualization of large-scale online social networks',
#      'year': u'2009'},
#     {'title': u'{PIWI}: Visually Exploring Graphs Based on Their Community Structure',
#      'year': u'2013'}]}),
#  (53,
#   {'author_name': 'Thornton, Janet',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'}]}),
#  (54,
#   {'author_name': 'Schmidt, Benjamin',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'A Matrix-Based Visualization for Exploring Dynamic Compound Digraphs',
#      'year': u'2013'}]}),
#  (55,
#   {'author_name': 'Hlawatsch, Marcel',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visual Adjacency Lists for Dynamic Graphs',
#      'year': u'2014'}]}),
#  (56,
#   {'author_name': 'Theis, Fabian',
#    'cl_bottom': '1:1:2',
#    'cl_top': '1',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Visualizing edge-edge relations in graphs',
#      'year': u'2013'},
#     {'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'}]}),
#  (57,
#   {'author_name': 'Yuan, Xiaoru',
#    'cl_bottom': '3:3',
#    'cl_top': '3',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{PIWI}: Visually Exploring Graphs Based on Their Community Structure',
#      'year': u'2013'}]}),
#  (58,
#   {'author_name': 'Xu, Panpan',
#    'cl_bottom': '3:2',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Visual Analysis of Set Relations in a Graph',
#      'year': u'2013'},
#     {'title': u'Visualization of bipartite relations between graphs and sets',
#      'year': u'2015'}]}),
#  (59,
#   {'author_name': 'Schulz, Hans-J{o}rg',
#    'cl_bottom': '2:2:2',
#    'cl_top': '2',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual Analysis of Bipartite Biological Networks',
#      'year': u'2008'},
#     {'title': u'{Honeycomb}: Visual Analysis of Large Scale Social Networks',
#      'year': u'2009'}]}),
#  (60,
#   {'author_name': 'Royer, Loic',
#    'cl_bottom': '28',
#    'cl_top': '28',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Unraveling Protein Networks with Power Graph Analysis',
#      'year': u'2008'}]}),
#  (61,
#   {'author_name': 'Buzluca, Feza',
#    'cl_bottom': '33',
#    'cl_top': '33',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{E-Quality}: A graph based object oriented software quality visualization tool',
#      'year': u'2011'}]}),
#  (62,
#   {'author_name': 'Schaffer, Doug',
#    'cl_bottom': '13',
#    'cl_top': '13',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'Navigating Hierarchically Clustered Networks Through Fisheye and Full-zoom Methods',
#      'year': u'1996'}]}),
#  (63,
#   {'author_name': 'Grilli, Luca',
#    'cl_bottom': '10',
#    'cl_top': '10',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Graph Visualization Techniques for Web Clustering Engines',
#      'year': u'2007'}]}),
#  (64,
#   {'author_name': 'Tan, Li',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'{HiMap}: Adaptive visualization of large-scale online social networks',
#      'year': u'2009'}]}),
#  (65,
#   {'author_name': 'Stark, Chris',
#    'cl_bottom': '31',
#    'cl_top': '31',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Osprey: a network visualization system.',
#      'year': u'2003'}]}),
#  (66,
#   {'author_name': 'Chau, Duen',
#    'cl_bottom': '15',
#    'cl_top': '15',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{GLO-STIX}: Graph-Level Operations for Specifying Techniques and Interactive eXploration',
#      'year': u'2014'}]}),
#  (67,
#   {'author_name': 'Lin, Yu-Ru',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'{FacetAtlas}: Multifaceted Visualization for Rich Text Corpora',
#      'year': u'2010'},
#     {'title': u'{g-Miner}: Interactive Visual Group Mining on Multivariate Graphs',
#      'year': u'2015'}]}),
#  (68,
#   {'author_name': 'Klukas, Christian',
#    'cl_bottom': '1:5',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{VANTED}: A system for advanced data analysis and visualization in the context of biological networks',
#      'year': u'2006'},
#     {'title': u'Dynamic exploration and editing of KEGG pathway diagrams',
#      'year': u'2007'}]}),
#  (69,
#   {'author_name': 'Barsky, Aaron',
#    'cl_bottom': '2:1:1:4',
#    'cl_top': '2',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Cerebral: Visualizing Multiple Experimental Conditions on a Graph with Biological Context',
#      'year': u'2008'}]}),
#  (70,
#   {'author_name': 'K{o}hler, Jacob',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  (71,
#   {'author_name': 'Wang, Taowei',
#    'cl_bottom': '4:3',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Overlaying Graph Links on Treemaps',
#      'year': u'2003'}]}),
#  (72,
#   {'author_name': 'Saito, Takafumi',
#    'cl_bottom': '2:1:2:2',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'A Visualization of Research Papers Based on the Topics and Citation Network',
#      'year': u'2015'}]}),
#  (73,
#   {'author_name': 'Jordan, Ev',
#    'cl_bottom': '27',
#    'cl_top': '27',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Using Dependency Models to Manage Complex Software Architecture',
#      'year': u'2005'}]}),
#  (74,
#   {'author_name': 'Kasyanov, Victor',
#    'cl_bottom': '47',
#    'cl_top': '47',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Higres - Visualization System for Clustered Graphs and Graph Algorithms',
#      'year': u'1999'}]}),
#  (75,
#   {'author_name': 'Lange, Christian',
#    'cl_bottom': '11:2',
#    'cl_top': '11',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Visual Exploration of Combined Architectural and Metric Information',
#      'year': u'2005'}]}),
#  (76,
#   {'author_name': 'Raitner, Marcus',
#    'cl_bottom': '67',
#    'cl_top': '67',
#    'flow': 0.0,
#    'papers': [{'title': u'Visual Navigation of Compound Graphs',
#      'year': u'2005'}]}),
#  (77,
#   {'author_name': 'Kahng, Minsuk',
#    'cl_bottom': '15',
#    'cl_top': '15',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{GLO-STIX}: Graph-Level Operations for Specifying Techniques and Interactive eXploration',
#      'year': u'2014'}]}),
#  (78,
#   {'author_name': 'Zhang, Kang',
#    'cl_bottom': '34',
#    'cl_top': '34',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualization of Clustered Directed Acyclic Graphs without Node Overlapping',
#      'year': u'2008'}]}),
#  (79,
#   {'author_name': 'Sun, Yao',
#    'cl_bottom': '20',
#    'cl_top': '20',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{RuleBender}: integrated modeling, simulation and visualization for rule-based intracellular biochemistry',
#      'year': u'2012'}]}),
#  (80,
#   {'author_name': 'Beck, Fabian',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0092336099999999997,
#    'papers': [{'title': u'Finding Structures in Multi-Type Code Couplings with Node-Link and Matrix Visualizations',
#      'year': u'2013'},
#     {'title': u'Visually Exploring Multi-Dimensional Code Couplings',
#      'year': u'2011'},
#     {'title': u'Rapid Serial Visual Presentation in Dynamic Graph Visualization',
#      'year': u'2012'},
#     {'title': u'Visual Comparison of Software Architectures', 'year': u'2013'},
#     {'title': u'{TimeSpiderTrees}: A Novel Visual Metaphor for Dynamic Compound Graphs',
#      'year': u'2010'},
#     {'title': u'Parallel Edge Splatting for Scalable Dynamic Graph Visualization',
#      'year': u'2011'},
#     {'title': u'Visualizing the Evolution of Communities in Dynamic Graphs',
#      'year': u'2015'}]}),
#  (81,
#   {'author_name': 'Saga, Ryosuke',
#    'cl_bottom': '48',
#    'cl_top': '48',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Edge Bundling in Multi-attributed Graphs',
#      'year': u'2015'}]}),
#  (82,
#   {'author_name': 'Paduano, Francesco',
#    'cl_bottom': '49',
#    'cl_top': '49',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{Extended LineSets}: a visualization technique for the interactive inspection of biological pathways',
#      'year': u'2015'}]}),
#  (83,
#   {'author_name': 'Huang, Xiaohui',
#    'cl_bottom': '17',
#    'cl_top': '17',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Multi-opinion Ring: visualizing and predicting multiple opinion orientations in online social media',
#      'year': u'2015'}]}),
#  (84,
#   {'author_name': 'Heer, Jeffrey',
#    'cl_bottom': '50',
#    'cl_top': '50',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{Vizster}: visualizing online social networks',
#      'year': u'2005'}]}),
#  (85,
#   {'author_name': 'Shi, Lei',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'{HiMap}: Adaptive visualization of large-scale online social networks',
#      'year': u'2009'}]}),
#  (86,
#   {'author_name': 'Faris, Robert',
#    'cl_bottom': '2:1:2:1',
#    'cl_top': '2',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Visualization Techniques for Categorical Analysis of Social Networks with Multiple Edge Sets',
#      'year': u'2014'}]}),
#  (87,
#   {'author_name': 'Forster, Michael',
#    'cl_bottom': '68',
#    'cl_top': '68',
#    'flow': 0.0,
#    'papers': [{'title': u'Applying Crossing Reduction Strategies to Layered Compound Graphs',
#      'year': u'2002'}]}),
#  (88,
#   {'author_name': 'Quigley, Aaron',
#    'cl_bottom': '16:1',
#    'cl_top': '16',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{FADE:} Graph Drawing, Clustering, and Visual Abstraction',
#      'year': u'2001'}]}),
#  (89,
#   {'author_name': 'Archambault, Daniel',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0055401699999999996,
#    'papers': [{'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'Grouse: Feature-based, Steerable Graph Hierarchy Exploration',
#      'year': u'2007'},
#     {'title': u'{TopoLayout}: Multilevel Graph Layout by Topological Features',
#      'year': u'2007'},
#     {'title': u'{GrouseFlocks}: Steerable Exploration of Graph Hierarchy Space',
#      'year': u'2008'},
#     {'title': u'{TugGraph}: Path-preserving hierarchies for browsing proximity and paths in graphs',
#      'year': u'2009'},
#     {'title': u'Tugging Graphs Faster: Efficiently Modifying Path-Preserving Hierarchies for Browsing Paths',
#      'year': u'2011'},
#     {'title': u'The Readability of Path-Preserving Clusterings of Graphs',
#      'year': u'2010'}]}),
#  (90,
#   {'author_name': 'Kumar, Pushpa',
#    'cl_bottom': '34',
#    'cl_top': '34',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualization of Clustered Directed Acyclic Graphs without Node Overlapping',
#      'year': u'2008'}]}),
#  (91,
#   {'author_name': 'Civril, Ali',
#    'cl_bottom': '18',
#    'cl_top': '18',
#    'flow': 0.00184672,
#    'papers': [{'title': u'A Compound Graph Layout Algorithm for Biological Pathways',
#      'year': u'2005'}]}),
#  (92,
#   {'author_name': 'Fischer, Michael',
#    'cl_bottom': '26',
#    'cl_top': '26',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{EvoLens}: lens-view visualizations of evolution data',
#      'year': u'2005'}]}),
#  (93,
#   {'author_name': 'Wang, Eric',
#    'cl_bottom': '51',
#    'cl_top': '51',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'A New Graph Drawing Scheme for Social Network',
#      'year': u'2014'}]}),
#  (94,
#   {'author_name': 'Bach, Benjamin',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{GraphDiaries}: Animated Transitions and Temporal Navigation for Dynamic Networks',
#      'year': u'2014'}]}),
#  (95,
#   {'author_name': 'Zhou, Hong',
#    'cl_bottom': '3:2',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Visual Analysis of Set Relations in a Graph',
#      'year': u'2013'},
#     {'title': u'Visualization of bipartite relations between graphs and sets',
#      'year': u'2015'}]}),
#  (96,
#   {'author_name': 'Sallaberry, Arnaud',
#    'cl_bottom': '2:1:1:2',
#    'cl_top': '2',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Interactive Visualization and Navigation of Web Search Results Revealing Community Structures and Bridges',
#      'year': u'2010'},
#     {'title': u'Clustering, Visualizing, and Navigating for Large Dynamic Graphs',
#      'year': u'2013'}]}),
#  (97,
#   {'author_name': 'Liu, Qing',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Semi-bipartite Graph Visualization for Gene Ontology Networks',
#      'year': u'2010'}]}),
#  (98,
#   {'author_name': 'Collins, Christopher',
#    'cl_bottom': '24:1',
#    'cl_top': '24',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{VisLink}: Revealing Relationships Amongst Visualizations',
#      'year': u'2007'},
#     {'title': u'Interactive Exploration of Implicit and Explicit Relations in Faceted Datasets',
#      'year': u'2013'}]}),
#  (99,
#   {'author_name': 'Fagnan, Justin',
#    'cl_bottom': '35',
#    'cl_top': '35',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualizing community centric network layouts',
#      'year': u'2012'}]}),
#  (100,
#   {'author_name': 'Marai, G.',
#    'cl_bottom': '20',
#    'cl_top': '20',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{RuleBender}: integrated modeling, simulation and visualization for rule-based intracellular biochemistry',
#      'year': u'2012'}]}),
#  (101,
#   {'author_name': 'Hong, Seok-Hee',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Visual Analysis of History of World Cup: A Dynamic Network with Dynamic Hierarchy and Geographic Clustering',
#      'year': u'2010'},
#     {'title': u'Drawing Clustered Graphs in Three Dimensions',
#      'year': u'2006'},
#     {'title': u'Drawing planar clustered graphs in 2.5 dimensions',
#      'year': u'2007'},
#     {'title': u'{MultiStory}: Visual analytics of dynamic multi-relational networks',
#      'year': u'2015'},
#     {'title': u'Semi-bipartite Graph Visualization for Gene Ontology Networks',
#      'year': u'2010'}]}),
#  (102,
#   {'author_name': 'Queyroi, Francois',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualizing Patterns in Node-link Diagrams',
#      'year': u'2012'}]}),
#  (103,
#   {'author_name': 'Goebel, Randy',
#    'cl_bottom': '35',
#    'cl_top': '35',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualizing community centric network layouts',
#      'year': u'2012'}]}),
#  (104,
#   {'author_name': 'Palladino, Pietro',
#    'cl_bottom': '10',
#    'cl_top': '10',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'An advanced network visualization system for financial crime detection',
#      'year': u'2011'},
#     {'title': u'Visual Analysis of One-to-Many Matched Graphs',
#      'year': u'2009'}]}),
#  (105,
#   {'author_name': 'Hasenauer, Jan',
#    'cl_bottom': '1:1:2',
#    'cl_top': '1',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Visualizing edge-edge relations in graphs',
#      'year': u'2013'},
#     {'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'}]}),
#  (106,
#   {'author_name': 'Burch, Michael',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.011542,
#    'papers': [{'title': u'Rapid Serial Visual Presentation in Dynamic Graph Visualization',
#      'year': u'2012'},
#     {'title': u'{TimeRadarTrees}: Visualizing Dynamic Compound Digraphs',
#      'year': u'2008'},
#     {'title': u'{TimeSpiderTrees}: A Novel Visual Metaphor for Dynamic Compound Graphs',
#      'year': u'2010'},
#     {'title': u'Parallel Edge Splatting for Scalable Dynamic Graph Visualization',
#      'year': u'2011'},
#     {'title': u'Layered {TimeRadarTrees}', 'year': u'2011'},
#     {'title': u'A Matrix-Based Visualization for Exploring Dynamic Compound Digraphs',
#      'year': u'2013'},
#     {'title': u'Edge-Stacked Timelines for Visualizing Dynamic Weighted Digraphs',
#      'year': u'2015'},
#     {'title': u'Visualizing the Evolution of Compound Digraphs with {TimeArcTrees}',
#      'year': u'2009'},
#     {'title': u'Visual Adjacency Lists for Dynamic Graphs', 'year': u'2014'},
#     {'title': u'Radial Layered Matrix Visualization of Dynamic Graphs',
#      'year': u'2013'}]}),
#  (107,
#   {'author_name': 'Gibson, Helen',
#    'cl_bottom': '46',
#    'cl_top': '46',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Node-attribute Graph Layout for Small-World Networks',
#      'year': u'2011'}]}),
#  (108,
#   {'author_name': 'Krebs, Valdis',
#    'cl_bottom': '23',
#    'cl_top': '23',
#    'flow': 0.00184672,
#    'papers': [{'title': u'An Inverse Distance-based Potential Field Function for Overlapping Point Set Visualization.',
#      'year': u'2014'}]}),
#  (109,
#   {'author_name': 'Yoghourdjian, Vahan',
#    'cl_bottom': '1:2',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'High-Quality Ultra-Compact Grid Layout of Grouped Networks',
#      'year': u'2015'}]}),
#  (110,
#   {'author_name': 'Paulovich, Fernando',
#    'cl_bottom': '11:1',
#    'cl_top': '11',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Skeleton-Based Edge Bundling for Graph Visualization',
#      'year': u'2011'}]}),
#  (111,
#   {'author_name': 'Gratzl, Samuel',
#    'cl_bottom': '7:2',
#    'cl_top': '7',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{CloudGazer}: A divide-and-conquer approach to monitoring and optimizing cloud-based networks',
#      'year': u'2015'}]}),
#  (112,
#   {'author_name': 'Liu, Yujie',
#    'cl_bottom': '3:3',
#    'cl_top': '3',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{PIWI}: Visually Exploring Graphs Based on Their Community Structure',
#      'year': u'2013'}]}),
#  (113,
#   {'author_name': 'Rusu, Adrian',
#    'cl_bottom': '2:2:5',
#    'cl_top': '2',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'How to Display Group Information on Node-Link Diagrams: an Evaluation',
#      'year': u'2014'}]}),
#  (114,
#   {'author_name': 'Chang, Chin-Lung',
#    'cl_bottom': '36',
#    'cl_top': '36',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Browsing Newsgroups with A Social Network Analyzer',
#      'year': u'2002'}]}),
#  (115,
#   {'author_name': 'Chang, Yi-Chien',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{VisANT} 3.5: multi-scale network visualization, analysis and inference based on the gene ontology',
#      'year': u'2009'}]}),
#  (116,
#   {'author_name': 'Li, Yueping',
#    'cl_bottom': '17',
#    'cl_top': '17',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Multi-opinion Ring: visualizing and predicting multiple opinion orientations in online social media',
#      'year': u'2015'},
#     {'title': u'{OpinionRings}: Inferring and visualizing the opinion tendency of socially connected users',
#      'year': u'2015'}]}),
#  (117,
#   {'author_name': 'Goodell, Howard',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'}]}),
#  (118,
#   {'author_name': 'Fekete, Jean-Daniel',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.0073868900000000001,
#    'papers': [{'title': u'{GraphDiaries}: Animated Transitions and Temporal Navigation for Dynamic Networks',
#      'year': u'2014'},
#     {'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'},
#     {'title': u'Overlaying Graph Links on Treemaps', 'year': u'2003'},
#     {'title': u'Matrix View of Graphs and Direct Manipulation of Cluster Hierarchies',
#      'year': u'2003'},
#     {'title': u'{MatrixExplorer}: a Dual-Representation System to Explore Social Networks',
#      'year': u'2006'},
#     {'title': u'{NodeTrix}: a Hybrid Visualization of Social Networks',
#      'year': u'2007'},
#     {'title': u'Improving the Readability of Clustered Social Networks Using Node Duplication',
#      'year': u'2008'}]}),
#  (119,
#   {'author_name': 'Henry, Nathalie',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.00415512,
#    'papers': [{'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'},
#     {'title': u'{MatrixExplorer}: a Dual-Representation System to Explore Social Networks',
#      'year': u'2006'},
#     {'title': u'{NodeTrix}: a Hybrid Visualization of Social Networks',
#      'year': u'2007'},
#     {'title': u'Improving the Readability of Clustered Social Networks Using Node Duplication',
#      'year': u'2008'}]}),
#  (120,
#   {'author_name': 'Enright, Anton',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'},
#     {'title': u'Network visualization and analysis of gene expression data using {BioLayout Express(3D)}',
#      'year': u'2009'}]}),
#  (121,
#   {'author_name': 'Itoh, Takayuki',
#    'cl_bottom': '2:1:2:2',
#    'cl_top': '2',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'A hybrid space-filling and force-directed layout method for visualizing multiple-category graphs',
#      'year': u'2009'},
#     {'title': u'Integrated Visualization of Gene Network and Ontology Applying a Hierarchical Graph Visualization Technique',
#      'year': u'2012'},
#     {'title': u'A Visualization of Research Papers Based on the Topics and Citation Network',
#      'year': u'2015'}]}),
#  (122,
#   {'author_name': 'Feng, Qing-Wen',
#    'cl_bottom': '16:1',
#    'cl_top': '16',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Multilevel Visualization of Clustered Graphs',
#      'year': u'1997'},
#     {'title': u'Straight-Line Drawing Algorithms for Hierarchical Graphs and Clustered Graphs',
#      'year': u'1997'},
#     {'title': u'Drawing Clustered Graphs on an Orthogonal Grid',
#      'year': u'1999'},
#     {'title': u'How to draw a planar clustered graph', 'year': u'1995'}]}),
#  (123,
#   {'author_name': 'Tal, Ayellet',
#    'cl_bottom': '37',
#    'cl_top': '37',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Dynamic Drawing of Clustered Graphs',
#      'year': u'2004'},
#     {'title': u'Multi-Level Graph Layout on the GPU', 'year': u'2007'},
#     {'title': u'{MOVIS}: A system for visualizing distributed mobile object environments',
#      'year': u'2008'}]}),
#  (124,
#   {'author_name': 'Cruz, Juan',
#    'cl_bottom': '38',
#    'cl_top': '38',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Community Detection and Visualization in Social Networks: Integrating Structural and Semantic Information',
#      'year': u'2014'}]}),
#  (125,
#   {'author_name': 'Gou, Liang',
#    'cl_bottom': '52',
#    'cl_top': '52',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{TreeNetViz}: Revealing Patterns of Networks over Tree Structures',
#      'year': u'2011'}]}),
#  (126,
#   {'author_name': 'Belviranli, Mehmet',
#    'cl_bottom': '18',
#    'cl_top': '18',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{CiSE}: A Circular Spring Embedder Layout Algorithm',
#      'year': u'2013'}]}),
#  (127,
#   {'author_name': 'Liggesmeyer, Peter',
#    'cl_bottom': '25',
#    'cl_top': '25',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Polyptychon: A Hierarchically-constrained Classified Dependencies Visualization',
#      'year': u'2014'}]}),
#  (128,
#   {'author_name': 'Wuchner, Egon',
#    'cl_bottom': '25',
#    'cl_top': '25',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Polyptychon: A Hierarchically-constrained Classified Dependencies Visualization',
#      'year': u'2014'}]}),
#  (129,
#   {'author_name': 'Lisitsyn, Ivan',
#    'cl_bottom': '47',
#    'cl_top': '47',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Higres - Visualization System for Clustered Graphs and Graph Algorithms',
#      'year': u'1999'}]}),
#  (130,
#   {'author_name': 'Staples, Mathew',
#    'cl_bottom': '53',
#    'cl_top': '53',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'{3-D} Visualization of Software Structure',
#      'year': u'1999'}]}),
#  (131,
#   {'author_name': 'Tollis, Ioannis',
#    'cl_bottom': '54',
#    'cl_top': '54',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'A Framework for User-Grouped Circular Drawings',
#      'year': u'2004'}]}),
#  (132,
#   {'author_name': 'Pinaud, Bruno',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'The Readability of Path-Preserving Clusterings of Graphs',
#      'year': u'2010'}]}),
#  (133,
#   {'author_name': 'Xiang, Yang',
#    'cl_bottom': '29',
#    'cl_top': '29',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Overlapping Matrix Pattern Visualization: A Hypergraph Approach',
#      'year': u'2008'}]}),
#  (134,
#   {'author_name': 'Goldovsky, Leon',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'}]}),
#  (135,
#   {'author_name': 'Sprenger, Thomas',
#    'cl_bottom': '39',
#    'cl_top': '39',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{H-BLOB}: a hierarchical visual clustering method using implicit surfaces',
#      'year': u'2000'}]}),
#  (136,
#   {'author_name': 'Ramos, Gonzalo',
#    'cl_bottom': '1:6',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Design Study of LineSets, a Novel Set Visualization Technique',
#      'year': u'2011'}]}),
#  (137,
#   {'author_name': 'Graham, M.',
#    'cl_bottom': '40',
#    'cl_top': '40',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Combined vs. Separate Views in Matrix-based Graph Analysis and Comparison',
#      'year': u'2011'}]}),
#  (138,
#   {'author_name': 'Diehl, Stephan',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.010156999999999999,
#    'papers': [{'title': u'Finding Structures in Multi-Type Code Couplings with Node-Link and Matrix Visualizations',
#      'year': u'2013'},
#     {'title': u'Visually Exploring Multi-Dimensional Code Couplings',
#      'year': u'2011'},
#     {'title': u'Rapid Serial Visual Presentation in Dynamic Graph Visualization',
#      'year': u'2012'},
#     {'title': u'Visual Comparison of Software Architectures', 'year': u'2013'},
#     {'title': u'{TimeRadarTrees}: Visualizing Dynamic Compound Digraphs',
#      'year': u'2008'},
#     {'title': u'{TimeSpiderTrees}: A Novel Visual Metaphor for Dynamic Compound Graphs',
#      'year': u'2010'},
#     {'title': u'Parallel Edge Splatting for Scalable Dynamic Graph Visualization',
#      'year': u'2011'},
#     {'title': u'Visualizing the Evolution of Compound Digraphs with {TimeArcTrees}',
#      'year': u'2009'},
#     {'title': u'Focused Animation of Dynamic Compound Graphs',
#      'year': u'2009'}]}),
#  (139,
#   {'author_name': 'Wang, Xiting',
#    'cl_bottom': '3:5',
#    'cl_top': '3',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{TopicPanorama}: a full picture of relevant topics',
#      'year': u'2014'}]}),
#  (140,
#   {'author_name': 'Auw{a}rter, Patrick',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Visualizing the Evolution of Communities in Dynamic Graphs',
#      'year': u'2015'}]}),
#  (141,
#   {'author_name': 'Freeman, Tom',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0050784899999999997,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'},
#     {'title': u'Network visualization and analysis of gene expression data using {BioLayout Express(3D)}',
#      'year': u'2009'}]}),
#  (142,
#   {'author_name': 'Mothe, Josiane',
#    'cl_bottom': '55',
#    'cl_top': '55',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'An energy-based model to optimize cluster visualization',
#      'year': u'2014'}]}),
#  (143,
#   {'author_name': 'Pattison, Tim',
#    'cl_bottom': '30',
#    'cl_top': '30',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Information Visualisation Using Composable Layouts and Visual Sets',
#      'year': u'2001'}]}),
#  (144,
#   {'author_name': 'Bristow, Michael',
#    'cl_bottom': '1:1:3',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual analysis of biological data-knowledge networks',
#      'year': u'2015'}]}),
#  (145,
#   {'author_name': 'Weiskopf, Daniel',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.0184672,
#    'papers': [{'title': u'Rapid Serial Visual Presentation in Dynamic Graph Visualization',
#      'year': u'2012'},
#     {'title': u'Parallel Edge Splatting for Scalable Dynamic Graph Visualization',
#      'year': u'2011'},
#     {'title': u'Layered {TimeRadarTrees}', 'year': u'2011'},
#     {'title': u'A Matrix-Based Visualization for Exploring Dynamic Compound Digraphs',
#      'year': u'2013'},
#     {'title': u'Edge-Stacked Timelines for Visualizing Dynamic Weighted Digraphs',
#      'year': u'2015'},
#     {'title': u'Visual Adjacency Lists for Dynamic Graphs', 'year': u'2014'},
#     {'title': u'Visualizing edge-edge relations in graphs', 'year': u'2013'},
#     {'title': u'Visualizing Fuzzy Overlapping Communities in Networks',
#      'year': u'2013'},
#     {'title': u'Radial Layered Matrix Visualization of Dynamic Graphs',
#      'year': u'2013'},
#     {'title': u'Visualizing the Evolution of Communities in Dynamic Graphs',
#      'year': u'2015'},
#     {'title': u'{iVUN}: interactive Visualization of Uncertain biochemical reaction Networks',
#      'year': u'2013'},
#     {'title': u'Visual analysis of biological data-knowledge networks',
#      'year': u'2015'}]}),
#  (146,
#   {'author_name': 'Poulet, Fran\\c{c}ois',
#    'cl_bottom': '38',
#    'cl_top': '38',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Community Detection and Visualization in Social Networks: Integrating Structural and Semantic Information',
#      'year': u'2014'}]}),
#  (147,
#   {'author_name': 'Wijk, Jarke',
#    'cl_bottom': '2:2:4',
#    'cl_top': '2',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Trace Visualization Using Hierarchical Edge Bundles and Massive Sequence Views',
#      'year': u'2007'},
#     {'title': u'Visual Analysis of Multivariate State Transition Graphs',
#      'year': u'2006'},
#     {'title': u'Bridging the Semantic Gap: Visualizing Transition Graphs with User-Defined Diagrams',
#      'year': u'2007'},
#     {'title': u'Visual Inspection of Multivariate Graphs', 'year': u'2008'},
#     {'title': u'Multivariate Network Exploration and Presentation: From Detail to Overview via Selections and Aggregations',
#      'year': u'2014'},
#     {'title': u'Interactive Visualization of Small World Graphs',
#      'year': u'2004'}]}),
#  (148,
#   {'author_name': 'Sinha, Vineet',
#    'cl_bottom': '27',
#    'cl_top': '27',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Using Dependency Models to Manage Complex Software Architecture',
#      'year': u'2005'}]}),
#  (149,
#   {'author_name': 'Frishman, Yaniv',
#    'cl_bottom': '37',
#    'cl_top': '37',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Dynamic Drawing of Clustered Graphs',
#      'year': u'2004'},
#     {'title': u'Multi-Level Graph Layout on the GPU', 'year': u'2007'},
#     {'title': u'{MOVIS}: A system for visualizing distributed mobile object environments',
#      'year': u'2008'}]}),
#  (150,
#   {'author_name': 'Misue, Kazuo',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'A Multiple-Aspects Visualization Tool for Exploring Social Networks',
#      'year': u'2009'},
#     {'title': u'Drawing Clustered Bipartite Graphs in Multi-circular Style',
#      'year': u'2010'},
#     {'title': u'Drawing Semi-bipartite Graphs in Anchor+Matrix Style',
# ...
#      'year': u'2007'},
#     {'title': u'Network visualization and analysis of gene expression data using {BioLayout Express(3D)}',
#      'year': u'2009'}]}),
#  (397,
#   {'author_name': 'Scheuermann, Gerik',
#    'cl_bottom': '1:3',
#    'cl_top': '1',
#    'flow': 0.00184672,
#    'papers': [{'title': u'A Novel Grid-based Visualization Approach for Metabolic Networks with Advanced Focus\\&Context View',
#      'year': u'2010'}]}),
#  (398,
#   {'author_name': 'Freivalds, Karlis',
#    'cl_bottom': '23',
#    'cl_top': '23',
#    'flow': 0.00184672,
#    'papers': [{'title': u'An Inverse Distance-based Potential Field Function for Overlapping Point Set Visualization.',
#      'year': u'2014'}]}),
#  (399,
#   {'author_name': 'Zhang, Chao',
#    'cl_bottom': '19',
#    'cl_top': '19',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Mosaic: making biological sense of complex networks.',
#      'year': u'2012'}]}),
#  (400,
#   {'author_name': 'Westenberg, M.A.',
#    'cl_bottom': '42',
#    'cl_top': '42',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{Dual Adjacency Matrix}: Exploring Link Groups in Dense Networks',
#      'year': u'2015'}]}),
#  (401,
#   {'author_name': 'Aris, Aleks',
#    'cl_bottom': '4:3',
#    'cl_top': '4',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Overlaying Graph Links on Treemaps',
#      'year': u'2003'},
#     {'title': u'Network Visualization by Semantic Substrates',
#      'year': u'2006'}]}),
#  (402,
#   {'author_name': 'Kashofer, Karl',
#    'cl_bottom': '7:1',
#    'cl_top': '7',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'{enRoute:} dynamic path extraction from biological pathway maps for exploring heterogeneous experimental datasets',
#      'year': u'2013'}]}),
#  (403,
#   {'author_name': 'Kuntzer, Jan',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  (404,
#   {'author_name': 'Zhang, Ji',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Semi-bipartite Graph Visualization for Gene Ontology Networks',
#      'year': u'2010'}]}),
#  (405,
#   {'author_name': 'Gange, Graeme',
#    'cl_bottom': '1:2',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'High-Quality Ultra-Compact Grid Layout of Grouped Networks',
#      'year': u'2015'}]}),
#  (406,
#   {'author_name': 'Bondarev, Egor',
#    'cl_bottom': '11:1',
#    'cl_top': '11',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualization of Areas of Interest in Component-Based System Architectures',
#      'year': u'2006'}]}),
#  (407,
#   {'author_name': 'Henry Riche, Nathalie',
#    'cl_bottom': '1:6',
#    'cl_top': '1',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Design Study of LineSets, a Novel Set Visualization Technique',
#      'year': u'2011'},
#     {'title': u'Edge Compression Techniques for Visualization of Dense Directed Graphs',
#      'year': u'2013'},
#     {'title': u'Untangling {Euler} diagrams', 'year': u'2010'}]}),
#  (408,
#   {'author_name': 'Wang, Xiaobo',
#    'cl_bottom': '60',
#    'cl_top': '60',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Generating customized layouts', 'year': u'1996'}]}),
#  (409,
#   {'author_name': 'Dragicevic, Pierre',
#    'cl_bottom': '45',
#    'cl_top': '45',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Interactive Graph Matching and Visual Comparison of Graphs and Clustered Graphs',
#      'year': u'2012'}]}),
#  (410,
#   {'author_name': 'Junker, Bjorn',
#    'cl_bottom': '1:5',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{VANTED}: A system for advanced data analysis and visualization in the context of biological networks',
#      'year': u'2006'}]}),
#  (411,
#   {'author_name': 'Cantareiro, Gabriel',
#    'cl_bottom': '11:1',
#    'cl_top': '11',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Skeleton-Based Edge Bundling for Graph Visualization',
#      'year': u'2011'}]}),
#  (412,
#   {'author_name': 'Hua, Jie',
#    'cl_bottom': '16:2',
#    'cl_top': '16',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Drawing Large Weighted Graphs Using Clustered Force-Directed Algorithm',
#      'year': u'2014'}]}),
#  (413,
#   {'author_name': 'John, Mathias',
#    'cl_bottom': '2:2:2',
#    'cl_top': '2',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Visual Analysis of Bipartite Biological Networks',
#      'year': u'2008'}]}),
#  (414,
#   {'author_name': 'Lewerentz, Claus',
#    'cl_bottom': '56',
#    'cl_top': '56',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'A space of layout styles for hierarchical graph models of software systems',
#      'year': u'2005'}]}),
#  (415,
#   {'author_name': 'Jirstrand, Mats',
#    'cl_bottom': '61',
#    'cl_top': '61',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Biochemical modeling with Systems Biology Graphical Notation',
#      'year': u'2010'}]}),
#  (416,
#   {'author_name': 'Heine, Christian',
#    'cl_bottom': '1:3',
#    'cl_top': '1',
#    'flow': 0.00184672,
#    'papers': [{'title': u'A Novel Grid-based Visualization Approach for Metabolic Networks with Advanced Focus\\&Context View',
#      'year': u'2010'}]}),
#  (417,
#   {'author_name': 'Baumbach, Jan',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  (418,
#   {'author_name': 'Kreveld, Marc',
#    'cl_bottom': '9',
#    'cl_top': '9',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{Kelp Diagrams}: Point Set Membership Visualization',
#      'year': u'2012'}]}),
#  (419,
#   {'author_name': 'Faber, Daniel',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  (420,
#   {'author_name': 'Kaufmann, Michael',
#    'cl_bottom': '14',
#    'cl_top': '14',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{BiNA}: a visual analytics tool for biological network data',
#      'year': u'2014'}]}),
#  (421,
#   {'author_name': 'Chiricota, Yves',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Multiscale visualization of small world networks',
#      'year': u'2003'}]}),
#  (422,
#   {'author_name': 'Simonetto, Paolo',
#    'cl_bottom': '2:1:1:3',
#    'cl_top': '2',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'Communities and hierarchical structures in dynamic social networks: analysis and visualization',
#      'year': u'2011'},
#     {'title': u'Node, Node-Link, and Node-Link-Group Diagrams: An Evaluation',
#      'year': u'2014'}]}),
#  (423,
#   {'author_name': 'Letunic, Ivica',
#    'cl_bottom': '5:2',
#    'cl_top': '5',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'{iPath}: interactive exploration of biochemical pathways and networks',
#      'year': u'2008'}]}),
#  (424,
#   {'author_name': 'Fuhry, David',
#    'cl_bottom': '29',
#    'cl_top': '29',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Overlapping Matrix Pattern Visualization: A Hypergraph Approach',
#      'year': u'2008'}]}),
#  (425,
#   {'author_name': 'Romeo, Salvatore',
#    'cl_bottom': '10',
#    'cl_top': '10',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Graph visualization techniques for conceptual Web site traffic analysis',
#      'year': u'2010'}]}),
#  (426,
#   {'author_name': 'Crnovrsanin, Tarik',
#    'cl_bottom': '2:1:2:1',
#    'cl_top': '2',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Visualization Techniques for Categorical Analysis of Social Networks with Multiple Edge Sets',
#      'year': u'2014'}]}),
#  (427,
#   {'author_name': 'Elzen, Stef',
#    'cl_bottom': '2:2:4',
#    'cl_top': '2',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'Multivariate Network Exploration and Presentation: From Detail to Overview via Selections and Aggregations',
#      'year': u'2014'}]}),
#  (428,
#   {'author_name': 'Phillips, Matthew',
#    'cl_bottom': '30',
#    'cl_top': '30',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Information Visualisation Using Composable Layouts and Visual Sets',
#      'year': u'2001'}]}),
#  (429,
#   {'author_name': 'Grocock, Russell',
#    'cl_bottom': '6',
#    'cl_top': '6',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Construction, Visualisation, and Clustering of Transcription Networks from Microarray Expression Data',
#      'year': u'2007'}]}),
#  (430,
#   {'author_name': 'Kuchinsky, Allan',
#    'cl_bottom': '19',
#    'cl_top': '19',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Mosaic: making biological sense of complex networks.',
#      'year': u'2012'}]}),
#  (431,
#   {'author_name': 'Lambert, Antoine',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Pathway Preserving Representation of Metabolic Networks',
#      'year': u'2011'},
#     {'title': u'Visualizing Patterns in Node-link Diagrams',
#      'year': u'2012'}]}),
#  (432,
#   {'author_name': 'Paris, Gilles',
#    'cl_bottom': '71',
#    'cl_top': '71',
#    'flow': 0.0,
#    'papers': [{'title': u'Automatic Drawing of Compound Digraphs for a Real-Time Power System Simulator',
#      'year': u'1996'}]}),
#  (433,
#   {'author_name': 'Dang, N.',
#    'cl_bottom': '4:3',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Overlaying Graph Links on Treemaps',
#      'year': u'2003'}]}),
#  (434,
#   {'author_name': 'Shi, Conglei',
#    'cl_bottom': '3:2',
#    'cl_top': '3',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual Analysis of Set Relations in a Graph',
#      'year': u'2013'}]}),
#  (435,
#   {'author_name': 'Jourdan, Fabien',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2',
#    'flow': 0.0073868900000000001,
#    'papers': [{'title': u'Multiscale visualization of small world networks',
#      'year': u'2003'},
#     {'title': u'Metabolic network visualization using constraint planar graph drawing algorithm',
#      'year': u'2006'},
#     {'title': u'Metabolic network visualization eliminating node redundance and preserving metabolic pathways',
#      'year': u'2007'},
#     {'title': u'Communities and hierarchical structures in dynamic social networks: analysis and visualization',
#      'year': u'2011'}]}),
#  (436,
#   {'author_name': 'Wybrow, Michael',
#    'cl_bottom': '1:2',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Exploration of Networks Using Overview+Detail with Constraint-based Cooperative Layout',
#      'year': u'2008'}]}),
#  (437,
#   {'author_name': 'Pohl, Mathias',
#    'cl_bottom': '1:1:4',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Focused Animation of Dynamic Compound Graphs',
#      'year': u'2009'}]}),
#  (438,
#   {'author_name': 'Sugiyama, Kozo',
#    'cl_bottom': '22:2',
#    'cl_top': '22',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Method for drawing intersecting clustered graphs and its application to web ontology language',
#      'year': u'2006'},
#     {'title': u'Force-directed drawing method for intersecting clustered graphs',
#      'year': u'2007'},
#     {'title': u'Visualization of structural information: automatic drawing of compound digraphs',
#      'year': u'1991'}]}),
#  (439,
#   {'author_name': 'Wang, Yan',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{VisANT} 3.5: multi-scale network visualization, analysis and inference based on the gene ontology',
#      'year': u'2009'}]}),
#  (440,
#   {'author_name': 'Specht, Michael',
#    'cl_bottom': '8',
#    'cl_top': '8',
#    'flow': 0.0036934400000000001,
#    'papers': [{'title': u'Graph-based analysis and visualization of experimental results with ONDEX',
#      'year': u'2006'}]}),
#  (441,
#   {'author_name': 'Stasko, John',
#    'cl_bottom': '15',
#    'cl_top': '15',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{GLO-STIX}: Graph-Level Operations for Specifying Techniques and Interactive eXploration',
#      'year': u'2014'}]}),
#  (442,
#   {'author_name': 'Zhu, Jun',
#    'cl_bottom': '3:5',
#    'cl_top': '3',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{TopicPanorama}: a full picture of relevant topics',
#      'year': u'2014'}]}),
#  (443,
#   {'author_name': 'Humayoun, Shah',
#    'cl_bottom': '43',
#    'cl_top': '43',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'{CluE}: An Algorithm for Expanding Clustered Graphs',
#      'year': u'2014'}]}),
#  (444,
#   {'author_name': 'Gao, Jie',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'A Multiple-Aspects Visualization Tool for Exploring Social Networks',
#      'year': u'2009'}]}),
#  (445,
#   {'author_name': 'Do, Thanh-Nghi',
#    'cl_bottom': '4:1',
#    'cl_top': '4',
#    'flow': 0.00184672,
#    'papers': [{'title': u'{ZAME}: Interactive Large-Scale Graph Visualization',
#      'year': u'2008'}]}),
#  (446,
#   {'author_name': 'El-Kebir, Mohammed',
#    'cl_bottom': '9',
#    'cl_top': '9',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{eXamine}: Exploring annotated modules in networks',
#      'year': u'2014'}]}),
#  (447,
#   {'author_name': 'Greilich, Martin',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Visualizing the Evolution of Compound Digraphs with {TimeArcTrees}',
#      'year': u'2009'}]}),
#  (448,
#   {'author_name': 'Huang, Chia-Ling',
#    'cl_bottom': '5:1',
#    'cl_top': '5',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{VisANT} 3.5: multi-scale network visualization, analysis and inference based on the gene ontology',
#      'year': u'2009'}]}),
#  (449,
#   {'author_name': 'Melville, A.G.',
#    'cl_bottom': '40',
#    'cl_top': '40',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Combined vs. Separate Views in Matrix-based Graph Analysis and Comparison',
#      'year': u'2011'}]}),
#  (450,
#   {'author_name': 'Ahmed, Adel',
#    'cl_bottom': '12',
#    'cl_top': '12',
#    'flow': 0.00184672,
#    'papers': [{'title': u'Visual Analysis of History of World Cup: A Dynamic Network with Dynamic Hierarchy and Geographic Clustering',
#      'year': u'2010'}]}),
#  (451,
#   {'author_name': 'Lin, Ching-Yung',
#    'cl_bottom': '3:1',
#    'cl_top': '3',
#    'flow': 0.0032317600000000002,
#    'papers': [{'title': u'{HiMap}: Adaptive visualization of large-scale online social networks',
#      'year': u'2009'}]}),
#  (452,
#   {'author_name': 'Hasselbring, Wilhelm',
#    'cl_bottom': '32',
#    'cl_top': '32',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Hierarchical Software Landscape Visualization for System Comprehension: A Controlled Experiment',
#      'year': u'2015'}]}),
#  (453,
#   {'author_name': 'Klau, Gunnar',
#    'cl_bottom': '9',
#    'cl_top': '9',
#    'flow': 0.0027700799999999999,
#    'papers': [{'title': u'{eXamine}: Exploring annotated modules in networks',
#      'year': u'2014'}]}),
#  (454,
#   {'author_name': 'Balakrishnan, Ravin',
#    'cl_bottom': '24:1',
#    'cl_top': '24',
#    'flow': 0.0013850399999999999,
#    'papers': [{'title': u'Interactive Exploration of Implicit and Explicit Relations in Faceted Datasets',
#      'year': u'2013'}]}),
#  (455,
#   {'author_name': 'Ito, Takao',
#    'cl_bottom': '22:1',
#    'cl_top': '22',
#    'flow': 0.00092336100000000004,
#    'papers': [{'title': u'Drawing Clustered Bipartite Graphs in Multi-circular Style',
#      'year': u'2010'}]}),
#  (456,
#   {'author_name': 'Paley, Suzanne',
#    'cl_bottom': '66',
#    'cl_top': '66',
#    'flow': 0.00046168099999999997,
#    'papers': [{'title': u'The Pathway Tools cellular overview diagram and Omics Viewer',
#      'year': u'2006'}]}),
#  (457,
#   {'author_name': 'Hunter, Lawrence',
#    'cl_bottom': '1:1:3',
#    'cl_top': '1',
#    'flow': 0.0023083999999999999,
#    'papers': [{'title': u'Visual analysis of biological data-knowledge networks',
#      'year': u'2015'}]})]

# %%
from networkx.readwrite import json_graph
import json

# %%
json_data = json_graph.node_link_data(G)
with open('coauthorship.json', 'w') as outf:
    json.dump(json_data, outf)

# %%
with open('coauthorship.json', 'r') as f:
    j = json.load(f)

# %%
ctypes = Counter()
for node in j['nodes']:
    ctypes[len(node)] += 1

# %%
ctypes
# Out:
# Counter({4: 457})

# %%
G.nodes(data=True)
# Out:
# [(1, {'author_name': 'Wu, Jie', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (2, {'author_name': 'Smith, Adam', 'cl_bottom': '20', 'cl_top': '20'}),
#  (3, {'author_name': 'Nakazawa, Rina', 'cl_bottom': '2:1:2:2', 'cl_top': '2'}),
#  (4, {'author_name': 'Mader, Martin', 'cl_bottom': '12', 'cl_top': '12'}),
#  (5, {'author_name': 'Sangal, Neeraj', 'cl_bottom': '27', 'cl_top': '27'}),
#  (6, {'author_name': 'Elmqvist, Niklas', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (7, {'author_name': 'Philippi, Stephan', 'cl_bottom': '8', 'cl_top': '8'}),
#  (8, {'author_name': 'Vernik, Rudi', 'cl_bottom': '30', 'cl_top': '30'}),
#  (9,
#   {'author_name': 'Goesmann, Alexander', 'cl_bottom': '21', 'cl_top': '21'}),
#  (10, {'author_name': 'Tanaka, Jiro', 'cl_bottom': '22:1', 'cl_top': '22'}),
#  (11, {'author_name': 'Mary, Patrick', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (12, {'author_name': 'Nguyen, QuanHoang', 'cl_bottom': '12', 'cl_top': '12'}),
#  (13, {'author_name': 'Kramer, Andrei', 'cl_bottom': '1:1:2', 'cl_top': '1'}),
#  (14, {'author_name': 'Jackson, Daniel', 'cl_bottom': '27', 'cl_top': '27'}),
#  (15, {'author_name': 'Mellor, Joe', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (16,
#   {'author_name': 'Sagot, Marie-France',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2'}),
#  (17, {'author_name': 'Roseman, Mark', 'cl_bottom': '13', 'cl_top': '13'}),
#  (18, {'author_name': 'Timmer, Jens', 'cl_bottom': '1:1:2', 'cl_top': '1'}),
#  (19,
#   {'author_name': 'Eliassi-Rad, Tina', 'cl_bottom': '2:1:2:1', 'cl_top': '2'}),
#  (20,
#   {'author_name': 'Krishnan, Neeraj', 'cl_bottom': '2:2:3', 'cl_top': '2'}),
#  (21,
#   {'author_name': 'Rucevskis, Peteris', 'cl_bottom': '23', 'cl_top': '23'}),
#  (22, {'author_name': 'Kalkofen, Denis', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (23,
#   {'author_name': "Rufiange, S{\\'e}bastien",
#    'cl_bottom': '4:4',
#    'cl_top': '4'}),
#  (24,
#   {'author_name': 'Termeer, Maurice', 'cl_bottom': '11:2', 'cl_top': '11'}),
#  (25, {'author_name': 'Ho, Joshua', 'cl_bottom': '12', 'cl_top': '12'}),
#  (26,
#   {'author_name': "Gilbert, Fr\\'ed\\'eric",
#    'cl_bottom': '2:1:1:3',
#    'cl_top': '2'}),
#  (27, {'author_name': 'Taubert, Jan', 'cl_bottom': '8', 'cl_top': '8'}),
#  (28,
#   {'author_name': 'Breitkreutz, Bobby-Joe',
#    'cl_bottom': '31',
#    'cl_top': '31'}),
#  (29,
#   {'author_name': 'Lenhof, Hans-Peter', 'cl_bottom': '14', 'cl_top': '14'}),
#  (30, {'author_name': 'Zachariah, R.', 'cl_bottom': '4:2', 'cl_top': '4'}),
#  (31, {'author_name': 'Krause, Alexander', 'cl_bottom': '32', 'cl_top': '32'}),
#  (32,
#   {'author_name': 'Junker, Bj\\QUOT_REPLACEorn',
#    'cl_bottom': '1:5',
#    'cl_top': '1'}),
#  (33, {'author_name': 'Kruijff, Ernst', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (34, {'author_name': 'Faith, Joe', 'cl_bottom': '45', 'cl_top': '45'}),
#  (35, {'author_name': 'Yan, Youliang', 'cl_bottom': '3:4', 'cl_top': '3'}),
#  (36, {'author_name': 'Bartram, Lyn', 'cl_bottom': '13', 'cl_top': '13'}),
#  (37, {'author_name': 'Wu, Yanhong', 'cl_bottom': '3:4', 'cl_top': '3'}),
#  (38, {'author_name': 'Greenberg, Saul', 'cl_bottom': '13', 'cl_top': '13'}),
#  (39, {'author_name': 'Fritz, Peter', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (40,
#   {'author_name': 'Munzner, Tamara', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (41, {'author_name': 'Chaturvedi, S.', 'cl_bottom': '4:2', 'cl_top': '4'}),
#  (42, {'author_name': 'Haubrock, Martin', 'cl_bottom': '21', 'cl_top': '21'}),
#  (43, {'author_name': 'Auber, David', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (44, {'author_name': 'Du, Xiaolin', 'cl_bottom': '17', 'cl_top': '17'}),
#  (45, {'author_name': 'Nguyen, Quang', 'cl_bottom': '16:2', 'cl_top': '16'}),
#  (46, {'author_name': 'Niermann, Peter', 'cl_bottom': '14', 'cl_top': '14'}),
#  (47, {'author_name': 'Zhou, Qi', 'cl_bottom': '22:1', 'cl_top': '22'}),
#  (48, {'author_name': 'Kao, David', 'cl_bottom': '1:1:3', 'cl_top': '1'}),
#  (49, {'author_name': 'Gansner, Emden', 'cl_bottom': '2:2:1', 'cl_top': '2'}),
#  (50, {'author_name': 'Liu, Shixia', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (51, {'author_name': 'Thornton, Janet', 'cl_bottom': '6', 'cl_top': '6'}),
#  (52,
#   {'author_name': 'Schmidt, Benjamin', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (53,
#   {'author_name': 'Hlawatsch, Marcel', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (54, {'author_name': 'Theis, Fabian', 'cl_bottom': '1:1:2', 'cl_top': '1'}),
#  (55, {'author_name': 'Yuan, Xiaoru', 'cl_bottom': '3:3', 'cl_top': '3'}),
#  (56, {'author_name': 'Xu, Panpan', 'cl_bottom': '3:2', 'cl_top': '3'}),
#  (57, {'author_name': 'Royer, Loic', 'cl_bottom': '28', 'cl_top': '28'}),
#  (58, {'author_name': 'Buzluca, Feza', 'cl_bottom': '33', 'cl_top': '33'}),
#  (59, {'author_name': 'Schaffer, Doug', 'cl_bottom': '13', 'cl_top': '13'}),
#  (60, {'author_name': 'Grilli, Luca', 'cl_bottom': '10', 'cl_top': '10'}),
#  (61, {'author_name': 'Tan, Li', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (62, {'author_name': 'Stark, Chris', 'cl_bottom': '31', 'cl_top': '31'}),
#  (63, {'author_name': 'Chau, Duen', 'cl_bottom': '15', 'cl_top': '15'}),
#  (64, {'author_name': 'Lin, Yu-Ru', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (65, {'author_name': 'Klukas, Christian', 'cl_bottom': '1:5', 'cl_top': '1'}),
#  (66, {'author_name': 'Barsky, Aaron', 'cl_bottom': '2:1:1:4', 'cl_top': '2'}),
#  (67, {'author_name': 'Wang, Taowei', 'cl_bottom': '4:3', 'cl_top': '4'}),
#  (68,
#   {'author_name': 'Saito, Takafumi', 'cl_bottom': '2:1:2:2', 'cl_top': '2'}),
#  (69, {'author_name': 'Jordan, Ev', 'cl_bottom': '27', 'cl_top': '27'}),
#  (70, {'author_name': 'Kasyanov, Victor', 'cl_bottom': '46', 'cl_top': '46'}),
#  (71,
#   {'author_name': 'Lange, Christian', 'cl_bottom': '11:2', 'cl_top': '11'}),
#  (72, {'author_name': 'Raitner, Marcus', 'cl_bottom': '67', 'cl_top': '67'}),
#  (73, {'author_name': 'Kahng, Minsuk', 'cl_bottom': '15', 'cl_top': '15'}),
#  (74, {'author_name': 'Zhang, Kang', 'cl_bottom': '34', 'cl_top': '34'}),
#  (75, {'author_name': 'Sun, Yao', 'cl_bottom': '20', 'cl_top': '20'}),
#  (76, {'author_name': 'Unger, Andrea', 'cl_bottom': '2:2:2', 'cl_top': '2'}),
#  (77, {'author_name': 'Beck, Fabian', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (78, {'author_name': 'Saga, Ryosuke', 'cl_bottom': '47', 'cl_top': '47'}),
#  (79,
#   {'author_name': 'Paduano, Francesco', 'cl_bottom': '48', 'cl_top': '48'}),
#  (80, {'author_name': 'Huang, Xiaohui', 'cl_bottom': '17', 'cl_top': '17'}),
#  (81, {'author_name': 'Heer, Jeffrey', 'cl_bottom': '49', 'cl_top': '49'}),
#  (82, {'author_name': 'Shi, Lei', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (83, {'author_name': 'Faris, Robert', 'cl_bottom': '2:1:2:1', 'cl_top': '2'}),
#  (84, {'author_name': 'Forster, Michael', 'cl_bottom': '68', 'cl_top': '68'}),
#  (85, {'author_name': 'Quigley, Aaron', 'cl_bottom': '16:1', 'cl_top': '16'}),
#  (86,
#   {'author_name': 'Archambault, Daniel',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2'}),
#  (87, {'author_name': 'Kumar, Pushpa', 'cl_bottom': '34', 'cl_top': '34'}),
#  (88, {'author_name': 'Civril, Ali', 'cl_bottom': '18', 'cl_top': '18'}),
#  (89, {'author_name': 'Fischer, Michael', 'cl_bottom': '26', 'cl_top': '26'}),
#  (90, {'author_name': 'Wang, Eric', 'cl_bottom': '50', 'cl_top': '50'}),
#  (91, {'author_name': 'Bach, Benjamin', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (92, {'author_name': 'Zhou, Hong', 'cl_bottom': '3:2', 'cl_top': '3'}),
#  (93,
#   {'author_name': 'Sallaberry, Arnaud',
#    'cl_bottom': '2:1:1:2',
#    'cl_top': '2'}),
#  (94, {'author_name': 'Liu, Qing', 'cl_bottom': '12', 'cl_top': '12'}),
#  (95,
#   {'author_name': 'Collins, Christopher',
#    'cl_bottom': '24:1',
#    'cl_top': '24'}),
#  (96, {'author_name': 'Fagnan, Justin', 'cl_bottom': '35', 'cl_top': '35'}),
#  (97, {'author_name': 'Marai, G.', 'cl_bottom': '20', 'cl_top': '20'}),
#  (98, {'author_name': 'Hong, Seok-Hee', 'cl_bottom': '12', 'cl_top': '12'}),
#  (99,
#   {'author_name': 'Queyroi, Francois', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (100, {'author_name': 'Goebel, Randy', 'cl_bottom': '35', 'cl_top': '35'}),
#  (101,
#   {'author_name': 'Palladino, Pietro', 'cl_bottom': '10', 'cl_top': '10'}),
#  (102, {'author_name': 'Hasenauer, Jan', 'cl_bottom': '1:1:2', 'cl_top': '1'}),
#  (103, {'author_name': 'Burch, Michael', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (104, {'author_name': 'Gibson, Helen', 'cl_bottom': '45', 'cl_top': '45'}),
#  (105, {'author_name': 'Krebs, Valdis', 'cl_bottom': '23', 'cl_top': '23'}),
#  (106,
#   {'author_name': 'Yoghourdjian, Vahan', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (107,
#   {'author_name': 'Paulovich, Fernando', 'cl_bottom': '11:1', 'cl_top': '11'}),
#  (108, {'author_name': 'Gratzl, Samuel', 'cl_bottom': '7:2', 'cl_top': '7'}),
#  (109, {'author_name': 'Liu, Yujie', 'cl_bottom': '3:3', 'cl_top': '3'}),
#  (110, {'author_name': 'Rusu, Adrian', 'cl_bottom': '2:2:5', 'cl_top': '2'}),
#  (111, {'author_name': 'Chang, Chin-Lung', 'cl_bottom': '36', 'cl_top': '36'}),
#  (112, {'author_name': 'Chang, Yi-Chien', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (113, {'author_name': 'Li, Yueping', 'cl_bottom': '17', 'cl_top': '17'}),
#  (114, {'author_name': 'Goodell, Howard', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (115,
#   {'author_name': 'Fekete, Jean-Daniel', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (116, {'author_name': 'Henry, Nathalie', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (117, {'author_name': 'Enright, Anton', 'cl_bottom': '6', 'cl_top': '6'}),
#  (118,
#   {'author_name': 'Itoh, Takayuki', 'cl_bottom': '2:1:2:2', 'cl_top': '2'}),
#  (119, {'author_name': 'Feng, Qing-Wen', 'cl_bottom': '16:1', 'cl_top': '16'}),
#  (120, {'author_name': 'Tal, Ayellet', 'cl_bottom': '37', 'cl_top': '37'}),
#  (121, {'author_name': 'Cruz, Juan', 'cl_bottom': '38', 'cl_top': '38'}),
#  (122, {'author_name': 'Gou, Liang', 'cl_bottom': '51', 'cl_top': '51'}),
#  (123,
#   {'author_name': 'Belviranli, Mehmet', 'cl_bottom': '18', 'cl_top': '18'}),
#  (124,
#   {'author_name': 'Kalinowski, J\\QUOT_REPLACEorn',
#    'cl_bottom': '21',
#    'cl_top': '21'}),
#  (125,
#   {'author_name': 'Liggesmeyer, Peter', 'cl_bottom': '25', 'cl_top': '25'}),
#  (126, {'author_name': 'Wuchner, Egon', 'cl_bottom': '25', 'cl_top': '25'}),
#  (127, {'author_name': 'Lisitsyn, Ivan', 'cl_bottom': '46', 'cl_top': '46'}),
#  (128, {'author_name': 'Staples, Mathew', 'cl_bottom': '52', 'cl_top': '52'}),
#  (129, {'author_name': 'Tollis, Ioannis', 'cl_bottom': '53', 'cl_top': '53'}),
#  (130,
#   {'author_name': 'Pinaud, Bruno', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (131, {'author_name': 'Xiang, Yang', 'cl_bottom': '29', 'cl_top': '29'}),
#  (132, {'author_name': 'Goldovsky, Leon', 'cl_bottom': '6', 'cl_top': '6'}),
#  (133, {'author_name': 'Sprenger, Thomas', 'cl_bottom': '39', 'cl_top': '39'}),
#  (134, {'author_name': 'Ramos, Gonzalo', 'cl_bottom': '1:6', 'cl_top': '1'}),
#  (135, {'author_name': 'Graham, M.', 'cl_bottom': '40', 'cl_top': '40'}),
#  (136, {'author_name': 'Diehl, Stephan', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (137, {'author_name': 'Wang, Xiting', 'cl_bottom': '3:5', 'cl_top': '3'}),
#  (138, {'author_name': 'Freeman, Tom', 'cl_bottom': '6', 'cl_top': '6'}),
#  (139, {'author_name': 'Mothe, Josiane', 'cl_bottom': '54', 'cl_top': '54'}),
#  (140, {'author_name': 'Pattison, Tim', 'cl_bottom': '30', 'cl_top': '30'}),
#  (141,
#   {'author_name': 'Bristow, Michael', 'cl_bottom': '1:1:3', 'cl_top': '1'}),
#  (142,
#   {'author_name': 'Weiskopf, Daniel', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (143,
#   {'author_name': 'Poulet, Fran\\c{c}ois', 'cl_bottom': '38', 'cl_top': '38'}),
#  (144, {'author_name': 'Wijk, Jarke', 'cl_bottom': '2:2:4', 'cl_top': '2'}),
#  (145, {'author_name': 'Sinha, Vineet', 'cl_bottom': '27', 'cl_top': '27'}),
#  (146, {'author_name': 'Frishman, Yaniv', 'cl_bottom': '37', 'cl_top': '37'}),
#  (147, {'author_name': 'Misue, Kazuo', 'cl_bottom': '22:1', 'cl_top': '22'}),
#  (148,
#   {'author_name': 'Salomonis, Nathan', 'cl_bottom': '19', 'cl_top': '19'}),
#  (149, {'author_name': 'Zaiane, Osmar', 'cl_bottom': '35', 'cl_top': '35'}),
#  (150, {'author_name': 'Omote, Hiroki', 'cl_bottom': '22:2', 'cl_top': '22'}),
#  (151,
#   {'author_name': 'Petkov, Radoslav', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (152,
#   {'author_name': 'Kwee, AgusTrisnajaya', 'cl_bottom': '41', 'cl_top': '41'}),
#  (153, {'author_name': 'Gall, Harald', 'cl_bottom': '26', 'cl_top': '26'}),
#  (154, {'author_name': 'Zhao, Ye', 'cl_bottom': '3:3', 'cl_top': '3'}),
#  (155, {'author_name': 'Deussen, Oliver', 'cl_bottom': '44', 'cl_top': '44'}),
#  (156, {'author_name': 'Goel, Aakash', 'cl_bottom': '15', 'cl_top': '15'}),
#  (157, {'author_name': 'Fittkau, Florian', 'cl_bottom': '32', 'cl_top': '32'}),
#  (158, {'author_name': 'Noack, Andreas', 'cl_bottom': '55', 'cl_top': '55'}),
#  (159,
#   {'author_name': 'Gardy, Jennifer', 'cl_bottom': '2:1:1:4', 'cl_top': '2'}),
#  (160,
#   {'author_name': 'Ghoniem, Mohammad', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (161,
#   {'author_name': 'Zimmer, Bj{\\QUOT_REPLACE{o}}rn',
#    'cl_bottom': '1:3',
#    'cl_top': '1'}),
#  (162, {'author_name': 'Abuthawabeh, Ala', 'cl_bottom': '1:4', 'cl_top': '1'}),
#  (163,
#   {'author_name': 'G\\QUOT_REPLACE{o}rg, Carsten',
#    'cl_bottom': '1:1:3',
#    'cl_top': '1'}),
#  (164,
#   {'author_name': 'Montecchiani, Fabrizio',
#    'cl_bottom': '10',
#    'cl_top': '10'}),
#  (165, {'author_name': 'Li, Liangyue', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (166, {'author_name': 'Peng, Wu', 'cl_bottom': '56', 'cl_top': '56'}),
#  (167, {'author_name': 'Knab, Patrick', 'cl_bottom': '26', 'cl_top': '26'}),
#  (168, {'author_name': 'Guo, Baining', 'cl_bottom': '3:5', 'cl_top': '3'}),
#  (169,
#   {'author_name': 'Veeramoni, Sankar', 'cl_bottom': '2:2:1', 'cl_top': '2'}),
#  (170, {'author_name': 'Jin, Ruoming', 'cl_bottom': '29', 'cl_top': '29'}),
#  (171, {'author_name': 'Kottler, Stephan', 'cl_bottom': '57', 'cl_top': '57'}),
#  (172, {'author_name': 'Lin, Zhiyuan', 'cl_bottom': '15', 'cl_top': '15'}),
#  (173, {'author_name': 'Abello, James', 'cl_bottom': '2:2:3', 'cl_top': '2'}),
#  (174, {'author_name': 'Dilek, Alptug', 'cl_bottom': '18', 'cl_top': '18'}),
#  (175, {'author_name': 'Tong, Hanghang', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (176, {'author_name': 'Wu, Wenbin', 'cl_bottom': '3:4', 'cl_top': '3'}),
#  (177, {'author_name': 'Smit, Martine', 'cl_bottom': '9', 'cl_top': '9'}),
#  (178,
#   {'author_name': 'Bezerianos, Anastasia', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (179, {'author_name': 'Radde, Nicole', 'cl_bottom': '1:1:2', 'cl_top': '1'}),
#  (180, {'author_name': 'Kitano, Hiroaki', 'cl_bottom': '69', 'cl_top': '69'}),
#  (181, {'author_name': 'Shneiderman, Ben', 'cl_bottom': '4:2', 'cl_top': '4'}),
#  (182,
#   {'author_name': 'Hasco\\QUOT_REPLACE{e}t, Mountaz',
#    'cl_bottom': '58',
#    'cl_top': '58'}),
#  (183, {'author_name': 'Wagner, Dorothea', 'cl_bottom': '59', 'cl_top': '59'}),
#  (184, {'author_name': 'Krieger, Michael', 'cl_bottom': '7:2', 'cl_top': '7'}),
#  (185,
#   {'author_name': 'B{\\QUOT_REPLACEo}rner, Katy',
#    'cl_bottom': '1:4',
#    'cl_top': '1'}),
#  (186, {'author_name': 'Didimo, Walter', 'cl_bottom': '10', 'cl_top': '10'}),
#  (187,
#   {'author_name': 'Woodward, Michael', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (188,
#   {'author_name': 'Chaudron, Michel', 'cl_bottom': '11:2', 'cl_top': '11'}),
#  (189,
#   {'author_name': 'Kalkusch, Michael', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (190, {'author_name': 'Hu, Yifan', 'cl_bottom': '2:2:1', 'cl_top': '2'}),
#  (191,
#   {'author_name': 'Purchase, Helen', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (192, {'author_name': 'Barlowe, Scott', 'cl_bottom': '3:3', 'cl_top': '3'}),
#  (193, {'author_name': 'Faeder, James', 'cl_bottom': '20', 'cl_top': '20'}),
#  (194, {'author_name': 'Chen, Ding-Yi', 'cl_bottom': '36', 'cl_top': '36'}),
#  (195, {'author_name': 'Dkaki, Taoufiq', 'cl_bottom': '54', 'cl_top': '54'}),
#  (196, {'author_name': 'Williams, Rohan', 'cl_bottom': '12', 'cl_top': '12'}),
#  (197, {'author_name': 'Zou, Futai', 'cl_bottom': '50', 'cl_top': '50'}),
#  (198, {'author_name': 'Dai, Bing', 'cl_bottom': '41', 'cl_top': '41'}),
#  (199, {'author_name': 'Forbes, Angus', 'cl_bottom': '48', 'cl_top': '48'}),
#  (200, {'author_name': 'Raue, Andreas', 'cl_bottom': '1:1:2', 'cl_top': '1'}),
#  (201, {'author_name': 'Demir, Emek', 'cl_bottom': '18', 'cl_top': '18'}),
#  (202, {'author_name': 'Yamada, Takuji', 'cl_bottom': '5:2', 'cl_top': '5'}),
#  (203,
#   {'author_name': 'K\\QUOT_REPLACEuntzer, Jan',
#    'cl_bottom': '14',
#    'cl_top': '14'}),
#  (204,
#   {'author_name': 'Giegerich, Robert', 'cl_bottom': '21', 'cl_top': '21'}),
#  (205, {'author_name': 'Brosch, Markus', 'cl_bottom': '6', 'cl_top': '6'}),
#  (206,
#   {'author_name': 'Reinhardt, Thomas', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (207, {'author_name': 'Wang, Yuke', 'cl_bottom': '34', 'cl_top': '34'}),
#  (208,
#   {'author_name': 'Sokolov, Konstantin', 'cl_bottom': '25', 'cl_top': '25'}),
#  (209,
#   {'author_name': 'Hanspers, Kristina', 'cl_bottom': '19', 'cl_top': '19'}),
#  (210, {'author_name': 'Fu, Xiaoyan', 'cl_bottom': '12', 'cl_top': '12'}),
#  (211, {'author_name': 'Dinkla, Kasper', 'cl_bottom': '9', 'cl_top': '9'}),
#  (212, {'author_name': 'Chen, Jianfei', 'cl_bottom': '3:5', 'cl_top': '3'}),
#  (213, {'author_name': 'Xu, Kai', 'cl_bottom': '12', 'cl_top': '12'}),
#  (214, {'author_name': 'Jusufi, Ilir', 'cl_bottom': '1:3', 'cl_top': '1'}),
#  (215, {'author_name': 'Saket, Bahador', 'cl_bottom': '2:2:1', 'cl_top': '2'}),
#  (216, {'author_name': 'Miyamoto, Isao', 'cl_bottom': '60', 'cl_top': '60'}),
#  (217, {'author_name': 'Dekker, Anthony', 'cl_bottom': '70', 'cl_top': '70'}),
#  (218, {'author_name': 'Skusa, Andre', 'cl_bottom': '8', 'cl_top': '8'}),
#  (219,
#   {'author_name': 'Schmalstieg, Dieter', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (220, {'author_name': 'Zaidi, Faraz', 'cl_bottom': '2:1:1:2', 'cl_top': '2'}),
#  (221, {'author_name': 'Shen, Zeqian', 'cl_bottom': '2:1:2:1', 'cl_top': '2'}),
#  (222, {'author_name': 'Schreiber, Falk', 'cl_bottom': '1:5', 'cl_top': '1'}),
#  (223, {'author_name': 'Yang, Jing', 'cl_bottom': '3:3', 'cl_top': '3'}),
#  (224, {'author_name': 'Sese, Jun', 'cl_bottom': '2:1:2:2', 'cl_top': '2'}),
#  (225,
#   {'author_name': "Bothorel, C{\\'e}cile", 'cl_bottom': '38', 'cl_top': '38'}),
#  (226,
#   {'author_name': 'Reimann, Matthias', 'cl_bottom': '28', 'cl_top': '28'}),
#  (227,
#   {'author_name': 'Melan\\c{c}on, Guy',
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2'}),
#  (228, {'author_name': 'Partl, Christian', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (229, {'author_name': 'Kieffer, Steve', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (230,
#   {'author_name': 'Theocharidis, Athanasios',
#    'cl_bottom': '6',
#    'cl_top': '6'}),
#  (231, {'author_name': 'Yang, Sixiao', 'cl_bottom': '3:4', 'cl_top': '3'}),
#  (232, {'author_name': 'Daniel, Donny', 'cl_bottom': '25', 'cl_top': '25'}),
#  (233, {'author_name': 'Ham, Frank', 'cl_bottom': '2:2:3', 'cl_top': '2'}),
#  (234, {'author_name': 'Gerasch, Andreas', 'cl_bottom': '14', 'cl_top': '14'}),
#  (235, {'author_name': 'Liotta, Giuseppe', 'cl_bottom': '10', 'cl_top': '10'}),
#  (236,
#   {'author_name': 'Ogawa, Michael', 'cl_bottom': '2:1:2:1', 'cl_top': '2'}),
#  (237, {'author_name': 'Dragan, Feodor', 'cl_bottom': '29', 'cl_top': '29'}),
#  (238, {'author_name': 'Efrat, Alon', 'cl_bottom': '2:2:1', 'cl_top': '2'}),
#  (239,
#   {'author_name': 'Renoust, Benjamin', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (240, {'author_name': 'Lin, Xuemin', 'cl_bottom': '16:1', 'cl_top': '16'}),
#  (241, {'author_name': 'Jansson, Andreas', 'cl_bottom': '61', 'cl_top': '61'}),
#  (242,
#   {'author_name': 'Pietriga, Emmanuel', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (243, {'author_name': 'Klein, Karsten', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (244, {'author_name': 'Gotz, David', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (245,
#   {'author_name': 'Carpendale, Sheelagh',
#    'cl_bottom': '24:2',
#    'cl_top': '24'}),
#  (246,
#   {'author_name': 'Byelas, Heorhiy', 'cl_bottom': '11:1', 'cl_top': '11'}),
#  (247, {'author_name': 'Hung, Jui-Hung', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (248, {'author_name': 'Hu, Zhenjun', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (249, {'author_name': 'Kumar, Gautam', 'cl_bottom': '62', 'cl_top': '62'}),
#  (250,
#   {'author_name': 'Kobourov, Stephen', 'cl_bottom': '2:2:1', 'cl_top': '2'}),
#  (251, {'author_name': 'Cetintas, Ahmet', 'cl_bottom': '18', 'cl_top': '18'}),
#  (252, {'author_name': 'Pinzger, Martin', 'cl_bottom': '26', 'cl_top': '26'}),
#  (253, {'author_name': 'Terada, Aika', 'cl_bottom': '2:1:2:2', 'cl_top': '2'}),
#  (254, {'author_name': 'Qu, Huamin', 'cl_bottom': '3:2', 'cl_top': '3'}),
#  (255,
#   {'author_name': 'Kincaid, Robert', 'cl_bottom': '2:1:1:4', 'cl_top': '2'}),
#  (256,
#   {'author_name': 'Tsigas, Philippas', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (257, {'author_name': 'Speckmann, Bettina', 'cl_bottom': '9', 'cl_top': '9'}),
#  (258, {'author_name': 'Neumann, Petra', 'cl_bottom': '24:2', 'cl_top': '24'}),
#  (259, {'author_name': 'Kerren, Andreas', 'cl_bottom': '1:3', 'cl_top': '1'}),
#  (260, {'author_name': 'Jianu, Radu', 'cl_bottom': '2:2:5', 'cl_top': '2'}),
#  (261, {'author_name': 'Giral, Erhan', 'cl_bottom': '18', 'cl_top': '18'}),
#  (262, {'author_name': 'Six, Janet', 'cl_bottom': '53', 'cl_top': '53'}),
#  (263, {'author_name': 'Dunne, Cody', 'cl_bottom': '4:2', 'cl_top': '4'}),
#  (264, {'author_name': 'Stal, Michael', 'cl_bottom': '25', 'cl_top': '25'}),
#  (265,
#   {'author_name': 'Schulz, Hans-J\\QUOT_REPLACE{o}rg',
#    'cl_bottom': '2:2:2',
#    'cl_top': '2'}),
#  (266,
#   {'author_name': 'Foerster, Florian', 'cl_bottom': '15', 'cl_top': '15'}),
#  (267,
#   {'author_name': 'Kohlbacher, Oliver', 'cl_bottom': '14', 'cl_top': '14'}),
#  (268, {'author_name': 'Ersoy, Ozan', 'cl_bottom': '11:1', 'cl_top': '11'}),
#  (269,
#   {'author_name': 'Pupyrev, Sergey', 'cl_bottom': '2:2:1', 'cl_top': '2'}),
#  (270, {'author_name': 'Pico, Alexander', 'cl_bottom': '19', 'cl_top': '19'}),
#  (271, {'author_name': 'Perer, Adam', 'cl_bottom': '4:2', 'cl_top': '4'}),
#  (272,
#   {'author_name': 'Vihrovs, Jevgenijs', 'cl_bottom': '23', 'cl_top': '23'}),
#  (273, {'author_name': 'Lex, Alexander', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (274, {'author_name': 'Davis, Darcy', 'cl_bottom': '63', 'cl_top': '63'}),
#  (275, {'author_name': 'Dimicco, Joan', 'cl_bottom': '2:2:2', 'cl_top': '2'}),
#  (276,
#   {'author_name': 'Vehlow, Corinna', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (277,
#   {'author_name': 'Hurter, Christophe', 'cl_bottom': '11:1', 'cl_top': '11'}),
#  (278, {'author_name': 'Cao, Nan', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (279, {'author_name': 'Meyer, Folker', 'cl_bottom': '21', 'cl_top': '21'}),
#  (280,
#   {'author_name': 'B\\QUOT_REPLACEorner, Katy',
#    'cl_bottom': '2:2:1',
#    'cl_top': '2'}),
#  (281, {'author_name': 'Pretorius, A.', 'cl_bottom': '2:2:4', 'cl_top': '2'}),
#  (282, {'author_name': 'DeLisi, Charles', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (283,
#   {'author_name': 'Schumann, Heidrun', 'cl_bottom': '2:2:2', 'cl_top': '2'}),
#  (284,
#   {'author_name': 'Grafenhain, Katja', 'cl_bottom': '26', 'cl_top': '26'}),
#  (285, {'author_name': 'Ashktorab, Zahra', 'cl_bottom': '4:2', 'cl_top': '4'}),
#  (286,
#   {'author_name': 'Telea, Alexandru', 'cl_bottom': '11:1', 'cl_top': '11'}),
#  (287,
#   {'author_name': 'Di Giacomo, Emilio', 'cl_bottom': '10', 'cl_top': '10'}),
#  (288,
#   {'author_name': 'Wattenberg, Michael', 'cl_bottom': '2:2:3', 'cl_top': '2'}),
#  (289, {'author_name': 'Dill, John', 'cl_bottom': '13', 'cl_top': '13'}),
#  (290, {'author_name': 'Stuckey, Peter', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (291, {'author_name': 'Balzer, Michael', 'cl_bottom': '44', 'cl_top': '44'}),
#  (292, {'author_name': 'Zhang, Xiaolong', 'cl_bottom': '51', 'cl_top': '51'}),
#  (293, {'author_name': 'Dinkla, K.', 'cl_bottom': '42', 'cl_top': '42'}),
#  (294,
#   {'author_name': 'Rohrschneider, Markus', 'cl_bottom': '1:3', 'cl_top': '1'}),
#  (295, {'author_name': 'Du, Fan', 'cl_bottom': '3:2', 'cl_top': '3'}),
#  (296, {'author_name': 'Marriott, Kim', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (297,
#   {'author_name': 'H\\QUOT_REPLACEoferlin, Markus',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1'}),
#  (298, {'author_name': 'Kanehisa, Minoru', 'cl_bottom': '5:2', 'cl_top': '5'}),
#  (299,
#   {'author_name': 'McGuffin, Michael', 'cl_bottom': '4:4', 'cl_top': '4'}),
#  (300,
#   {'author_name': "Lalanne, Fr\\'ed\\'eric",
#    'cl_bottom': '2:1:1:1',
#    'cl_top': '2'}),
#  (301,
#   {'author_name': 'Dubois, Jonathan', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (302,
#   {'author_name': 'Nagamochi, Hiroshi', 'cl_bottom': '16:1', 'cl_top': '16'}),
#  (303, {'author_name': 'Huang, Mao', 'cl_bottom': '16:2', 'cl_top': '16'}),
#  (304,
#   {'author_name': 'Yeang, Chen-Hsiang', 'cl_bottom': '64', 'cl_top': '64'}),
#  (305, {'author_name': 'Dubs, Shelli', 'cl_bottom': '13', 'cl_top': '13'}),
#  (306, {'author_name': 'Garland, Michael', 'cl_bottom': '62', 'cl_top': '62'}),
#  (307, {'author_name': 'Liu, Jiayi', 'cl_bottom': '1:3', 'cl_top': '1'}),
#  (308,
#   {'author_name': "Mazi\\'{e}re, Pierre", 'cl_bottom': '6', 'cl_top': '6'}),
#  (309,
#   {'author_name': 'Taggart, Douglas', 'cl_bottom': '2:2:5', 'cl_top': '2'}),
#  (310,
#   {'author_name': 'Cottret, Ludovic', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (311,
#   {'author_name': "Santamar\\'ia, Rodrigo",
#    'cl_bottom': '65',
#    'cl_top': '65'}),
#  (312, {'author_name': 'Hug, Sabine', 'cl_bottom': '1:1:2', 'cl_top': '1'}),
#  (313, {'author_name': 'Cohen, Robert', 'cl_bottom': '16:1', 'cl_top': '16'}),
#  (314, {'author_name': 'Ratzinger, Jacek', 'cl_bottom': '26', 'cl_top': '26'}),
#  (315, {'author_name': 'Tekin, Umut', 'cl_bottom': '33', 'cl_top': '33'}),
#  (316, {'author_name': 'Qian, Weihong', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (317, {'author_name': 'Madden, Patrick', 'cl_bottom': '18', 'cl_top': '18'}),
#  (318, {'author_name': 'Huyck, Matt', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (319, {'author_name': 'Vingron, Martin', 'cl_bottom': '64', 'cl_top': '64'}),
#  (320, {'author_name': 'Tyers, Mike', 'cl_bottom': '31', 'cl_top': '31'}),
#  (321,
#   {'author_name': 'Felmlee, Diane', 'cl_bottom': '2:1:2:1', 'cl_top': '2'}),
#  (322, {'author_name': 'Koren, Yehuda', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (323, {'author_name': 'Holten, Danny', 'cl_bottom': '2:2:4', 'cl_top': '2'}),
#  (324, {'author_name': 'Streit, Marc', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (325, {'author_name': 'Brandes, Ulrik', 'cl_bottom': '59', 'cl_top': '59'}),
#  (326,
#   {'author_name': 'Yamashita, Takafumi', 'cl_bottom': '47', 'cl_top': '47'}),
#  (327, {'author_name': 'Lim, Ee-Peng', 'cl_bottom': '41', 'cl_top': '41'}),
#  (328,
#   {'author_name': 'K\\QUOT_REPLACE{o}hler, Jacob',
#    'cl_bottom': '8',
#    'cl_top': '8'}),
#  (329, {'author_name': 'Holloway, Dustin', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (330, {'author_name': 'Riche, N.', 'cl_bottom': '42', 'cl_top': '42'}),
#  (331, {'author_name': 'Brunella, R', 'cl_bottom': '39', 'cl_top': '39'}),
#  (332, {'author_name': 'Kennedy, J.B.', 'cl_bottom': '40', 'cl_top': '40'}),
#  (333, {'author_name': 'Karp, Peter', 'cl_bottom': '66', 'cl_top': '66'}),
#  (334, {'author_name': 'Czerwinski, Mary', 'cl_bottom': '1:6', 'cl_top': '1'}),
#  (335, {'author_name': 'Chawla, Nitesh', 'cl_bottom': '63', 'cl_top': '63'}),
#  (336, {'author_name': 'Yusufov, Roman', 'cl_bottom': '2:2:3', 'cl_top': '2'}),
#  (337, {'author_name': 'Zatloukal, Kurt', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (338,
#   {'author_name': 'Plaisant, Catherine', 'cl_bottom': '4:3', 'cl_top': '4'}),
#  (339,
#   {'author_name': 'McPherson, Jonathan',
#    'cl_bottom': '2:1:2:1',
#    'cl_top': '2'}),
#  (340, {'author_name': 'Siderius, Marco', 'cl_bottom': '9', 'cl_top': '9'}),
#  (341,
#   {'author_name': "Ther\\'on, Roberto", 'cl_bottom': '65', 'cl_top': '65'}),
#  (342, {'author_name': 'Zhang, Xin', 'cl_bottom': '3:3', 'cl_top': '3'}),
#  (343, {'author_name': 'Freilich, Shiri', 'cl_bottom': '6', 'cl_top': '6'}),
#  (344,
#   {'author_name': 'Bourqui, Romain', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (345, {'author_name': 'Zhao, Jian', 'cl_bottom': '24:1', 'cl_top': '24'}),
#  (346, {'author_name': 'Xu, Dong', 'cl_bottom': '19', 'cl_top': '19'}),
#  (347,
#   {'author_name': 'Schroeder, Michael', 'cl_bottom': '28', 'cl_top': '28'}),
#  (348, {'author_name': 'Munz, Tanja', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (349,
#   {'author_name': 'AlTarawneh, Ragaad', 'cl_bottom': '43', 'cl_top': '43'}),
#  (350, {'author_name': 'Boyd, Danah', 'cl_bottom': '49', 'cl_top': '49'}),
#  (351,
#   {'author_name': 'Muelder, Chris', 'cl_bottom': '2:1:2:1', 'cl_top': '2'}),
#  (352, {'author_name': 'Zuo, Zhengping', 'cl_bottom': '13', 'cl_top': '13'}),
#  (353, {'author_name': 'Verrier, Paul', 'cl_bottom': '8', 'cl_top': '8'}),
#  (354, {'author_name': 'Ma, Kwan-Liu', 'cl_bottom': '2:1:2:1', 'cl_top': '2'}),
#  (355, {'author_name': 'Si-Kun, Li', 'cl_bottom': '56', 'cl_top': '56'}),
#  (356,
#   {'author_name': 'Lacroix, Vincent', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (357,
#   {'author_name': 'Prusis, Krisjanis', 'cl_bottom': '23', 'cl_top': '23'}),
#  (358, {'author_name': 'Hagen, Hans', 'cl_bottom': '1:4', 'cl_top': '1'}),
#  (359, {'author_name': 'Sun, Jimeng', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (360,
#   {'author_name': 'Schlechtweg, Stefan', 'cl_bottom': '24:2', 'cl_top': '24'}),
#  (361, {'author_name': 'Bieman, James', 'cl_bottom': '52', 'cl_top': '52'}),
#  (362,
#   {'author_name': 'Lehmann, Katharina', 'cl_bottom': '57', 'cl_top': '57'}),
#  (363,
#   {'author_name': 'Andreopoulos, Bill', 'cl_bottom': '28', 'cl_top': '28'}),
#  (364, {'author_name': 'Bork, Peer', 'cl_bottom': '5:2', 'cl_top': '5'}),
#  (365, {'author_name': 'Xu, Wen', 'cl_bottom': '20', 'cl_top': '20'}),
#  (366, {'author_name': 'Wang, Guodong', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (367, {'author_name': 'Alper, Basak', 'cl_bottom': '1:6', 'cl_top': '1'}),
#  (368, {'author_name': 'Gross, Markus', 'cl_bottom': '39', 'cl_top': '39'}),
#  (369, {'author_name': 'Stolper, Charles', 'cl_bottom': '15', 'cl_top': '15'}),
#  (370,
#   {'author_name': "Reichenbach, Andr{\\'e}",
#    'cl_bottom': '1:3',
#    'cl_top': '1'}),
#  (371,
#   {'author_name': 'Scheidegger, Carlos', 'cl_bottom': '2:2:1', 'cl_top': '2'}),
#  (372, {'author_name': 'Zeckzer, Dirk', 'cl_bottom': '1:4', 'cl_top': '1'}),
#  (373, {'author_name': 'Westenberg, Michel', 'cl_bottom': '9', 'cl_top': '9'}),
#  (374, {'author_name': 'Ye, Yunming', 'cl_bottom': '17', 'cl_top': '17'}),
#  (375, {'author_name': 'Reitz, Florian', 'cl_bottom': '1:1:4', 'cl_top': '1'}),
#  (376,
#   {'author_name': 'Cornelissen, Bas', 'cl_bottom': '2:2:4', 'cl_top': '2'}),
#  (377, {'author_name': 'Madden, Brendan', 'cl_bottom': '18', 'cl_top': '18'}),
#  (378,
#   {'author_name': 'Chuang, Tyng-Ruey', 'cl_bottom': '36', 'cl_top': '36'}),
#  (379,
#   {'author_name': 'Schultz, Johannes', 'cl_bottom': '43', 'cl_top': '43'}),
#  (380,
#   {'author_name': 'Bucur, Cristina-Iulia', 'cl_bottom': '9', 'cl_top': '9'}),
#  (381, {'author_name': 'Gao, Jie', 'cl_bottom': '22:1', 'cl_top': '22'}),
#  (382,
#   {'author_name': 'Sansen, Joris', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (383,
#   {'author_name': 'Melancon, Guy', 'cl_bottom': '2:1:1:2', 'cl_top': '2'}),
#  (384,
#   {'author_name': 'Pich, Christian', 'cl_bottom': '2:1:1:2', 'cl_top': '2'}),
#  (385, {'author_name': 'Erdemir, Ural', 'cl_bottom': '33', 'cl_top': '33'}),
#  (386, {'author_name': 'Dogrusoz, Ugur', 'cl_bottom': '18', 'cl_top': '18'}),
#  (387, {'author_name': 'Stitz, Holger', 'cl_bottom': '7:2', 'cl_top': '7'}),
#  (388, {'author_name': 'Dwyer, Tim', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (389, {'author_name': 'Eades, Peter', 'cl_bottom': '16:1', 'cl_top': '16'}),
#  (390, {'author_name': 'Rawlings, Chris', 'cl_bottom': '8', 'cl_top': '8'}),
#  (391,
#   {'author_name': 'Fuhrman, Christopher', 'cl_bottom': '4:4', 'cl_top': '4'}),
#  (392,
#   {'author_name': 'Chevalier, Fanny', 'cl_bottom': '24:1', 'cl_top': '24'}),
#  (393, {'author_name': 'Meidiana, Amyra', 'cl_bottom': '12', 'cl_top': '12'}),
#  (394, {'author_name': 'Lau, Raymond', 'cl_bottom': '17', 'cl_top': '17'}),
#  (395, {'author_name': 'Dongen, Stijn', 'cl_bottom': '6', 'cl_top': '6'}),
#  (396,
#   {'author_name': 'Scheuermann, Gerik', 'cl_bottom': '1:3', 'cl_top': '1'}),
#  (397,
#   {'author_name': 'Freivalds, Karlis', 'cl_bottom': '23', 'cl_top': '23'}),
#  (398, {'author_name': 'Zhang, Chao', 'cl_bottom': '19', 'cl_top': '19'}),
#  (399, {'author_name': 'Westenberg, M.A.', 'cl_bottom': '42', 'cl_top': '42'}),
#  (400, {'author_name': 'Aris, Aleks', 'cl_bottom': '4:3', 'cl_top': '4'}),
#  (401, {'author_name': 'Kashofer, Karl', 'cl_bottom': '7:1', 'cl_top': '7'}),
#  (402, {'author_name': 'Zhang, Ji', 'cl_bottom': '12', 'cl_top': '12'}),
#  (403,
#   {'author_name': 'Schmauder, Hansj{\\QUOT_REPLACE{o}}rg',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1'}),
#  (404, {'author_name': 'Gange, Graeme', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (405, {'author_name': 'Bondarev, Egor', 'cl_bottom': '11:1', 'cl_top': '11'}),
#  (406,
#   {'author_name': 'Henry Riche, Nathalie', 'cl_bottom': '1:6', 'cl_top': '1'}),
#  (407, {'author_name': 'Wang, Xiaobo', 'cl_bottom': '60', 'cl_top': '60'}),
#  (408,
#   {'author_name': 'Dragicevic, Pierre', 'cl_bottom': '58', 'cl_top': '58'}),
#  (409,
#   {'author_name': 'Mears, Christopher', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (410,
#   {'author_name': 'Cantareiro, Gabriel', 'cl_bottom': '11:1', 'cl_top': '11'}),
#  (411, {'author_name': 'Hua, Jie', 'cl_bottom': '16:2', 'cl_top': '16'}),
#  (412, {'author_name': 'John, Mathias', 'cl_bottom': '2:2:2', 'cl_top': '2'}),
#  (413, {'author_name': 'Lewerentz, Claus', 'cl_bottom': '55', 'cl_top': '55'}),
#  (414, {'author_name': 'Jirstrand, Mats', 'cl_bottom': '61', 'cl_top': '61'}),
#  (415, {'author_name': 'Heine, Christian', 'cl_bottom': '1:3', 'cl_top': '1'}),
#  (416, {'author_name': 'Baumbach, Jan', 'cl_bottom': '8', 'cl_top': '8'}),
#  (417, {'author_name': 'Kreveld, Marc', 'cl_bottom': '9', 'cl_top': '9'}),
#  (418, {'author_name': 'Faber, Daniel', 'cl_bottom': '14', 'cl_top': '14'}),
#  (419,
#   {'author_name': 'Kaufmann, Michael', 'cl_bottom': '14', 'cl_top': '14'}),
#  (420,
#   {'author_name': 'Chiricota, Yves', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (421,
#   {'author_name': 'Simonetto, Paolo', 'cl_bottom': '2:1:1:3', 'cl_top': '2'}),
#  (422, {'author_name': 'Letunic, Ivica', 'cl_bottom': '5:2', 'cl_top': '5'}),
#  (423, {'author_name': 'Fuhry, David', 'cl_bottom': '29', 'cl_top': '29'}),
#  (424, {'author_name': 'Romeo, Salvatore', 'cl_bottom': '10', 'cl_top': '10'}),
#  (425,
#   {'author_name': 'Crnovrsanin, Tarik',
#    'cl_bottom': '2:1:2:1',
#    'cl_top': '2'}),
#  (426, {'author_name': 'Elzen, Stef', 'cl_bottom': '2:2:4', 'cl_top': '2'}),
#  (427,
#   {'author_name': 'Phillips, Matthew', 'cl_bottom': '30', 'cl_top': '30'}),
#  (428, {'author_name': 'Grocock, Russell', 'cl_bottom': '6', 'cl_top': '6'}),
#  (429, {'author_name': 'Kuchinsky, Allan', 'cl_bottom': '19', 'cl_top': '19'}),
#  (430,
#   {'author_name': 'Lambert, Antoine', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (431, {'author_name': 'Paris, Gilles', 'cl_bottom': '71', 'cl_top': '71'}),
#  (432,
#   {'author_name': 'Auw{\\QUOT_REPLACEa}rter, Patrick',
#    'cl_bottom': '1:1:1',
#    'cl_top': '1'}),
#  (433, {'author_name': 'Dang, N.', 'cl_bottom': '4:3', 'cl_top': '4'}),
#  (434, {'author_name': 'Shi, Conglei', 'cl_bottom': '3:2', 'cl_top': '3'}),
#  (435,
#   {'author_name': 'Jourdan, Fabien', 'cl_bottom': '2:1:1:1', 'cl_top': '2'}),
#  (436, {'author_name': 'Wybrow, Michael', 'cl_bottom': '1:2', 'cl_top': '1'}),
#  (437, {'author_name': 'Pohl, Mathias', 'cl_bottom': '1:1:4', 'cl_top': '1'}),
#  (438, {'author_name': 'Sugiyama, Kozo', 'cl_bottom': '22:2', 'cl_top': '22'}),
#  (439, {'author_name': 'Wang, Yan', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (440, {'author_name': 'Specht, Michael', 'cl_bottom': '8', 'cl_top': '8'}),
#  (441, {'author_name': 'Stasko, John', 'cl_bottom': '15', 'cl_top': '15'}),
#  (442, {'author_name': 'Zhu, Jun', 'cl_bottom': '3:5', 'cl_top': '3'}),
#  (443, {'author_name': 'Humayoun, Shah', 'cl_bottom': '43', 'cl_top': '43'}),
#  (444,
#   {'author_name': 'R\\QUOT_REPLACE{u}egg, Alexander',
#    'cl_bottom': '8',
#    'cl_top': '8'}),
#  (445, {'author_name': 'Do, Thanh-Nghi', 'cl_bottom': '4:1', 'cl_top': '4'}),
#  (446, {'author_name': 'El-Kebir, Mohammed', 'cl_bottom': '9', 'cl_top': '9'}),
#  (447,
#   {'author_name': 'Greilich, Martin', 'cl_bottom': '1:1:1', 'cl_top': '1'}),
#  (448, {'author_name': 'Huang, Chia-Ling', 'cl_bottom': '5:1', 'cl_top': '5'}),
#  (449, {'author_name': 'Melville, A.G.', 'cl_bottom': '40', 'cl_top': '40'}),
#  (450, {'author_name': 'Ahmed, Adel', 'cl_bottom': '12', 'cl_top': '12'}),
#  (451, {'author_name': 'Lin, Ching-Yung', 'cl_bottom': '3:1', 'cl_top': '3'}),
#  (452,
#   {'author_name': 'Hasselbring, Wilhelm', 'cl_bottom': '32', 'cl_top': '32'}),
#  (453, {'author_name': 'Klau, Gunnar', 'cl_bottom': '9', 'cl_top': '9'}),
#  (454,
#   {'author_name': 'Balakrishnan, Ravin', 'cl_bottom': '24:1', 'cl_top': '24'}),
#  (455, {'author_name': 'Ito, Takao', 'cl_bottom': '22:1', 'cl_top': '22'}),
#  (456, {'author_name': 'Paley, Suzanne', 'cl_bottom': '66', 'cl_top': '66'}),
#  (457,
#   {'author_name': 'Hunter, Lawrence', 'cl_bottom': '1:1:3', 'cl_top': '1'})]

# %%
deg = pd.DataFrame.from_dict(G.degree(), orient='index').rename(columns={0: 'degree'})

# %%
deg.degree.value_counts()
# Out:
# 2     91
# 4     75
# 3     70
# 1     60
# 6     50
# 5     37
# 8     29
# 7     13
# 11     7
# 9      5
# 0      5
# 10     4
# 12     4
# 13     2
# 20     1
# 14     1
# 16     1
# 18     1
# 22     1
# Name: degree, dtype: int64

# %%
df['cl_depth'] = df.cl_bottom.apply(lambda x: len(x.split(':')))

# %%
df[df.cl_depth>1].cl_bottom.value_counts().shape
# Out:
# (41,)
